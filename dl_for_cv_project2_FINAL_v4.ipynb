# %% [markdown]
# # **Deep Learning for Computer Vision**
#
# ## **Project 2** - Use of Data Augmentation and Transfer Learning
#
# CRISP-DM Phase 1 to 5
#
# ---
#
# Authors: **António Cruz** (140129), **David Isaac** (120064), **Erik Daskalyuk** (120062), **Ivan Magalhães** (106586), **Ricardo Pereira** (120052)
#
# Date: **2025-11-30**

# %% [markdown]
# &#160;

# %% [markdown]
# # 0. Environment Setup
#
# ---

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

from tqdm import tqdm
tqdm.pandas()

import cv2
from scipy.stats import entropy, kurtosis, skew
from sklearn.utils import class_weight as sk_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import tensorflow as tf
import keras
from keras import Input, Model, models, regularizers
from keras.optimizers import AdamW
from keras.metrics import AUC, Recall
from keras.applications import EfficientNetV2B0, ResNet50V2
from keras.layers import GlobalAveragePooling2D, Dense, Concatenate, Dropout, Input
from keras import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping
from keras.models import Model

from keras.callbacks import ModelCheckpoint
from keras.utils import image_dataset_from_directory
from keras.layers import (
    RandomRotation, RandomTranslation, RandomZoom, 
    RandomFlip, RandomBrightness, RandomContrast, GaussianNoise
)
# Out:
# 2025-11-29 00:41:58.990285: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-29 00:41:59.021868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-29 00:41:59.683278: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Global configuration
SEED = 42                                           # Fixed random seed for reproducibility
DATASET_ROOT = "./chest_xray/"                      # Set the dataset location base path
TRAIN_DIR = DATASET_ROOT + "train"                  # Train samples folder
TEST_DIR = DATASET_ROOT + "test"                    # Test samples folder
CHECKPOINT_PATH = "best_model_checkpoint.keras"     # File path to save the best model
ACTIVE_SCENARIO = "STAGING"                     # Active scenario selected: "DEVELOPMENT", "STAGING", "PRODUCTION"

# %%
# Set random seeds for reproducibility across libraries
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Helper function to check the active scenario
def scenario(*modes):
    # If in PRODUCTION, everything is allowed
    if ACTIVE_SCENARIO == "PRODUCTION":
        return True
    # Otherwise only allow explicitly listed modes
    return ACTIVE_SCENARIO in modes

# Utility: parse dataset folders into a DataFrame
def load_dataset_df(train_root, test_root):
    """Build a DataFrame with columns: image_path, label, split."""
    records = []

    # Parse training split folders
    for label_name in os.listdir(train_root):
        label_dir = os.path.join(train_root, label_name)
        if not os.path.isdir(label_dir):
            continue

        for f in os.listdir(label_dir):
            if f.lower().endswith((".png", ".jpg", ".jpeg")):
                records.append({
                    "image_path": os.path.join(label_dir, f),
                    "label": label_name,
                    "split": "train"
                })

    # Parse test split folders
    for label_name in os.listdir(test_root):
        label_dir = os.path.join(test_root, label_name)
        if not os.path.isdir(label_dir):
            continue

        for f in os.listdir(label_dir):
            if f.lower().endswith((".png", ".jpg", ".jpeg")):
                records.append({
                    "image_path": os.path.join(label_dir, f),
                    "label": label_name,
                    "split": "test"
                })

    return pd.DataFrame(records)

# %%
# Create DF_ORIGIN, the immutable reference DataFrame
DF_ORIGIN = load_dataset_df(TRAIN_DIR, TEST_DIR)

print("DF_ORIGIN created:")
display(DF_ORIGIN.head())
print(f"Total images: {len(DF_ORIGIN)}")

# DF_VIEW, it will only be used for Business and Data Understanding
DF_VIEW = DF_ORIGIN.copy()

# DF_MODEL, it will only be used for Data Preparation and Modeling
DF_MODEL = DF_ORIGIN.copy()

print("\nDataset copies created:")
print(f"DF_VIEW : {len(DF_VIEW)} rows")
print(f"DF_MODEL: {len(DF_MODEL)} rows")
# Out:
# DF_ORIGIN created:
#                                           image_path   label  split
# 0  ./chest_xray/train/NORMAL/NORMAL2-IM-0911-0001...  NORMAL  train
# 1        ./chest_xray/train/NORMAL/IM-0477-0001.jpeg  NORMAL  train
# 2  ./chest_xray/train/NORMAL/NORMAL2-IM-0974-0001...  NORMAL  train
# 3        ./chest_xray/train/NORMAL/IM-0548-0001.jpeg  NORMAL  train
# 4  ./chest_xray/train/NORMAL/NORMAL2-IM-0917-0001...  NORMAL  train
# Total images: 5856
#
# Dataset copies created:
# DF_VIEW : 5856 rows
# DF_MODEL: 5856 rows

# %% [markdown]
# &#160;

# %% [markdown]
# # 1. Business Understanding
#
# ---

# %% [markdown]
# ## Scope
#
# This project focuses on developing an AI-powered classification model using transfer learning to analyze chest X-ray images and identify patients with pneumonia. Building on the foundational work of Project 1, this project explores advanced deep learning techniques to improve model performance, generalization, and clinical utility.
#
# The project leverages pre-trained convolutional neural networks (CNNs), such as VGG16, ResNet50, and EfficientNet, to extract meaningful features from chest X-ray images. By fine-tuning these models and applying data augmentation, the goal is to enhance the model's ability to generalize to unseen data while maintaining a strong focus on high recall, ensuring that pneumonia cases are not missed.
#
# The system will:
# - Classify chest X-ray images into Normal and Pneumonia categories.
# - Enable healthcare professionals to retrospectively identify at-risk patients for targeted preventive care, reducing the risk of pneumonia recurrence and complications.
#
# ## Objectives
#
# 1. Implement Transfer Learning
#    Develop a classification model using pre-trained CNNs (e.g., VGG16, ResNet50, EfficientNet) as a baseline, leveraging their ability to extract high-level features from medical images.
#
# 2. Experiment with Data Augmentation
#    Apply transformations such as rotation, zoom, and flipping to artificially expand the training dataset, improving model robustness and reducing overfitting.
#
# 3. Explore Feature Extraction and Fine-Tuning
#    - Feature Extraction: Use pre-trained models as fixed feature extractors, training only the top classifier layers.
#    - Fine-Tuning: Unfreeze and retrain later layers of the pre-trained models to adapt them specifically to the chest X-ray classification task.
#
# 4. Evaluate Model Performance
#    Compare the performance of different architectures and techniques using clinically relevant metrics, including accuracy, precision, recall, F1-score, and AUC-ROC, with an emphasis on recall to ensure that pneumonia cases are not overlooked.
#
# 5. Justify the Best-Performing Model
#    Provide a detailed analysis of why the selected model (e.g., ResNet50 with fine-tuning) outperforms others, considering trade-offs such as training time, computational resources, and clinical utility.
#
# 6. Deliver a Functional and Documented Solution
#    Provide a well-documented Python codebase and a comprehensive report detailing the dataset, methodology, model architecture, training process, evaluation results, and the rationale behind the selected model and techniques.
#
# ## Clinical and Operational Impact
#
# The project aims to deliver a practical, recall-focused AI model that assists healthcare professionals in identifying patients with a history of pneumonia from historical X-ray records. By enabling targeted preventive interventions, the model supports secondary prevention efforts, reducing the risk of recurrence and improving patient outcomes.

# %% [markdown]
# &#160;

# %% [markdown]
# # 2. Data Understanding
# ---

# %%
# Global Contrast (std)
def compute_global_std(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan
    return float(np.std(img.astype(np.float32)))

# Dynamic Range (max - min)
def compute_dynamic_range(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan
    img = img.astype(np.float32)
    return float(np.max(img) - np.min(img))

# Histogram Entropy
def compute_hist_entropy(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan
    hist = cv2.calcHist([img], [0], None, [256], [0, 256])
    p = hist.ravel().astype(np.float32)
    p = p / np.sum(p)
    p[p == 0] = 1e-12
    return float(entropy(p, base=2))

# Kurtosis and Skewness
def compute_kurtosis_skew(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan, np.nan
    vals = img.astype(np.float32).ravel()
    return float(kurtosis(vals)), float(skew(vals))

# Local Contrast Uniformity (tile std mean & variance)
def compute_local_contrast(path, tiles=8):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan, np.nan

    img = img.astype(np.float32)
    h, w = img.shape
    tile_h = h // tiles
    tile_w = w // tiles

    stds = []
    for i in range(tiles):
        for j in range(tiles):
            tile = img[i * tile_h:(i + 1) * tile_h,
                       j * tile_w:(j + 1) * tile_w]
            stds.append(np.std(tile))

    stds = np.array(stds)
    return float(stds.mean()), float(stds.var())

# High-Frequency Content (mean Laplacian)
def compute_high_freq_energy(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan
    lap = cv2.Laplacian(img.astype(np.float32), cv2.CV_32F)
    return float(np.mean(np.abs(lap)))

# Geometric Metrics: Centering and Content Analysis
def compute_geometric_metrics(path):
    """
    Compute geometric metrics for augmentation parameter estimation.
    
    Returns:
        centering_offset_x, centering_offset_y, 
        content_width_ratio, content_height_ratio,
        aspect_ratio
    """
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return np.nan, np.nan, np.nan, np.nan, np.nan
    
    h, w = img.shape
    aspect_ratio = w / h  # ADD THIS
    
    # Find content bounding box (non-black pixels)
    mask = img > 10
    rows = np.any(mask, axis=1)
    cols = np.any(mask, axis=0)
    
    if not (rows.any() and cols.any()):
        return 0.0, 0.0, 1.0, 1.0, aspect_ratio  # UPDATE THIS
    
    y_min, y_max = np.where(rows)[0][[0, -1]]
    x_min, x_max = np.where(cols)[0][[0, -1]]
    
    # Compute content center
    content_center_x = (x_min + x_max) / 2
    content_center_y = (y_min + y_max) / 2
    
    # Compute image center
    image_center_x = w / 2
    image_center_y = h / 2
    
    # Compute centering offsets (normalized by image dimensions)
    offset_x = (content_center_x - image_center_x) / w
    offset_y = (content_center_y - image_center_y) / h
    
    # Compute content size ratios
    content_width = x_max - x_min + 1
    content_height = y_max - y_min + 1
    width_ratio = content_width / w
    height_ratio = content_height / h
    
    return float(offset_x), float(offset_y), float(width_ratio), float(height_ratio), float(aspect_ratio)

# %% [markdown]
# ## 2.1 Global Contrast
#
# A stable model performance requires a dataset with relatively consistent exposure and contrast characteristics. Large fluctuations in global contrast, whether caused by acquisition variability, compression artifacts, or post-processing, can lead to heterogeneous feature distributions during training. Such variability increases the risk of the model focusing on contrast artifacts rather than clinically relevant patterns. Quantifying global contrast supports the identification of low-quality or overprocessed images that may require correction, filtering, or consistent preprocessing prior to model training.
#
# Global contrast, expressed as the standard deviation of pixel intensities, is a fundamental indicator of image quality in chest radiography. Diagnostic information in X-ray images depends heavily on subtle grayscale variations that delineate lung fields, soft-tissue boundaries, vascular structures, and osseous anatomy. Low global contrast typically indicates underexposure or suboptimal acquisition, which can obscure anatomical details and reduce the discriminative capacity available to a learning algorithm. Conversely, excessively high global contrast often suggests overprocessing or artificial enhancement, potentially introducing edges and textures not present in standard clinical imaging.
#
# As part of dataset characterization, this metric establishes a baseline reference for expected exposure and contrast levels across the available images. This baseline assists in determining whether contrast normalization methods (e.g., histogram normalization, CLAHE, or no enhancement) are necessary or potentially counterproductive. It also provides a reference against which future inference-time images can be compared, helping to detect contrast outliers that may result from differing acquisition settings, device variability, or prior preprocessing.

# %%
# Compute Global Contrast (standard deviation of pixel intensities)
if scenario("DEVELOPMENT"):

    DF_VIEW["global_std"] = DF_VIEW["image_path"].apply(compute_global_std)

    print("Global contrast computation completed.")
    display(DF_VIEW["global_std"].describe())

# %%
# Plot Lowest, Median and Highest Contrast Images
if scenario("DEVELOPMENT"):

    # Sort DF_VIEW by global contrast
    df_sorted = DF_VIEW.sort_values(by="global_std")

    # Select lowest, median, highest contrast samples
    low_row  = df_sorted.iloc[0]
    mid_row  = df_sorted.iloc[len(df_sorted) // 2]
    high_row = df_sorted.iloc[-1]

    selected = [
        ("Lowest Contrast",  low_row["image_path"],  low_row["global_std"]),
        ("Median Contrast",  mid_row["image_path"],  mid_row["global_std"]),
        ("Highest Contrast", high_row["image_path"], high_row["global_std"])
    ]

    plt.figure(figsize=(16, 7))

    for idx, (label, path, std_val) in enumerate(selected):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            raise ValueError(f"Image could not be read: {path}")

        filename = os.path.basename(path)

        plt.subplot(1, 3, idx + 1)
        plt.imshow(img, cmap="gray")
        plt.title(f"{label}\nStd = {std_val:.2f}", fontsize=12)
        plt.axis("off")

        plt.text(
            0.5, -0.10,
            filename,
            fontsize=10,
            ha="center", va="top",
            transform=plt.gca().transAxes
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.1** - Lowest, Median and Highest Contrast Images

# %%
# Plot Global Contrast Distribution
if scenario("DEVELOPMENT"):

    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["global_std"].dropna(), bins=40, edgecolor='black')

    plt.title("Global Contrast (Pixel Std) Distribution")
    plt.xlabel("Global Std Value")
    plt.ylabel("Number of Images")
    plt.grid(True)

    plt.show()

# %% [markdown]
# **Figure 2.2** - Global Contrast Distribution

# %% [markdown]
# The distribution of global contrast values shows a well-formed, approximately Gaussian shape centered around the expected range for standard chest radiographs. This suggests that the majority of images share similar exposure and contrast characteristics, which is desirable for model training. The presence of a small number of low-contrast images at the left tail likely reflects instances of mild underexposure or limited dynamic range. Likewise, the small number of high-contrast cases at the right tail may correspond to images that have undergone stronger post-processing or contrast amplification.
#
# Overall, the dataset appears broadly consistent in terms of contrast quality. The core of the distribution indicates that most images fall within a stable and clinically plausible contrast band, which supports robust model learning. The few outliers observed at the extremes do not dominate the dataset and may be reviewed individually during preprocessing decisions, but they do not suggest any structural imbalance or heterogeneous mixing of incompatible imaging sources.

# %% [markdown]
# ## 2.2 Dynamic Range
#
# Dynamic range, defined as the difference between the maximum and minimum pixel intensities in an image, serves as a measure of how fully the grayscale space is utilized during acquisition. Chest X-ray imaging relies on a broad representation of intensities to preserve the visibility of both low-attenuation regions such as lung fields and high-attenuation structures such as ribs or the mediastinum. An image with a limited dynamic range may appear washed out or uniformly gray, which reduces the visibility of diagnostically relevant structures. Conversely, an abnormally wide dynamic range may indicate strong post-processing, unusual acquisition parameters, or inconsistent normalization steps applied before dataset construction.
#
# A dataset with large variability in dynamic range can introduce significant inconsistency in the distribution of pixel intensities seen during training. This inconsistency makes it more difficult for a model to learn reliable patterns, as the same anatomical structure may appear substantially lighter or darker depending on acquisition conditions rather than actual physiology. Monitoring this metric makes it possible to identify images that deviate from standard radiographic appearance and that may require normalization or exclusion. A stable and well-defined dynamic range across samples contributes to more predictable model behavior and reduces the risk of learning contrast artifacts.
#
# Dynamic range analysis complements global contrast analysis by providing a direct measurement of the span of intensities present in each image. Whereas the global standard deviation characterizes the distribution’s spread, dynamic range assesses the actual minimum and maximum gray levels used by the imaging system. Together, these metrics assist in determining whether preprocessing steps such as intensity clipping, histogram normalization, or contrast equalization are necessary to achieve a consistent representation of the dataset. They also support the identification of outliers that may result from non-standard imaging devices or prior enhancement.

# %%
# Compute Dynamic Range (max intensity minus min intensity)
if scenario("DEVELOPMENT"):

    # Create the column
    DF_VIEW["dynamic_range"] = DF_VIEW["image_path"].apply(compute_dynamic_range)

    print("Dynamic Range computation completed.")
    display(DF_VIEW["dynamic_range"].describe())

# %%
# Plot distribution of Dynamic Range values
if scenario("DEVELOPMENT"):

    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["dynamic_range"].dropna(), bins=40, edgecolor="black")

    plt.title("Dynamic Range Distribution")
    plt.xlabel("Dynamic Range (Max - Min)")
    plt.ylabel("Number of Images")
    plt.grid(True)

    plt.show()

# %% [markdown]
# **Figure 2.3** - Dynamic Range Distribution

# %% [markdown]
# Overall, the dataset appears highly uniform in terms of dynamic range. The dominant peak at 255 indicates consistent handling of intensity rescaling across images, which is advantageous for downstream modelling, as the input space remains stable. The small tail of lower dynamic-range images can be inspected individually during the data-quality review phase, but the distribution does not suggest any systemic inconsistency in acquisition or preprocessing.

# %% [markdown]
# ## 2.3 Histogram Entropy
#
# Histogram entropy measures the complexity and variability of the grayscale distribution in an image. Higher entropy values indicate that pixel intensities are more uniformly distributed across the available range, reflecting greater diversity in tonal values. Lower entropy values occur when intensities are concentrated in a narrower subset of values, producing flatter or more uniform images. In the context of chest radiography, entropy provides an aggregate view of how much tonal information the acquisition contains. Images with low entropy may be underexposed, washed out, or lacking structural definition, while images with very high entropy may have undergone strong contrast equalization or other enhancement steps.
#
# Stable entropy levels across a dataset contribute to consistent feature extraction during training. Variations in entropy reflect differences in perceptual complexity, structural prominence, and contrast distribution, all of which influence how convolutional layers respond to radiographic textures. An image with unusually low entropy may lack sufficient local variation for robust learning, while an image with unusually high entropy may contain contrast artifacts that do not represent normal anatomy. By quantifying entropy across the dataset, it becomes possible to detect samples that deviate from the expected radiographic appearance and that may benefit from targeted normalization or exclusion.
#
# Histogram entropy complements the global standard deviation and dynamic range metrics by capturing the distributional shape of image intensities rather than only the spread or the minimum and maximum values. Together, these metrics help characterize the global exposure profile of the dataset and guide decisions regarding preprocessing steps such as histogram normalization or contrast equalization. Entropy also establishes a reference distribution against which future inference-time inputs can be compared, supporting the identification of atypical acquisition conditions or unexpected preprocessing in production data.

# %%
# Compute Histogram Entropy
if scenario("DEVELOPMENT"):
    DF_VIEW["hist_entropy"] = DF_VIEW["image_path"].apply(compute_hist_entropy)
    display(DF_VIEW["hist_entropy"].describe())

# %%
# Plot representative images for Histogram Entropy
if scenario("DEVELOPMENT"):

    df_sorted = DF_VIEW.sort_values(by="hist_entropy")

    low_row  = df_sorted.iloc[0]
    mid_row  = df_sorted.iloc[len(df_sorted) // 2]
    high_row = df_sorted.iloc[-1]

    examples = [
        ("Lowest Entropy",  low_row["image_path"],  low_row["hist_entropy"]),
        ("Median Entropy",  mid_row["image_path"],  mid_row["hist_entropy"]),
        ("Highest Entropy", high_row["image_path"], high_row["hist_entropy"])
    ]

    plt.figure(figsize=(16, 7))

    for idx, (label, path, value) in enumerate(examples):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue

        filename = os.path.basename(path)

        plt.subplot(1, 3, idx + 1)
        plt.imshow(img, cmap="gray")
        plt.title(f"{label}\nEntropy = {value:.2f} bits", fontsize=12)
        plt.axis("off")

        plt.text(
            0.5, -0.10, filename,
            fontsize=10,
            ha="center", va="top",
            transform=plt.gca().transAxes
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.4** - Lowest, Median, and Highest Entropy Images

# %%
# Plot distribution of Histogram Entropy values
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["hist_entropy"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Entropy (bits)")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.5** - Histogram Entropy Distribution

# %% [markdown]
# The entropy distribution shows a well-defined concentration around values between approximately 6.9 and 7.6 bits, indicating that most images exhibit a balanced spread of pixel intensities across the grayscale range. This range reflects an expected level of tonal complexity for chest radiographs in which both low-attenuation and high-attenuation structures are adequately represented. The presence of a smooth, unimodal shape suggests a consistent image formation process across the dataset, with no major groups of images derived from markedly different acquisition or post-processing pipelines.
#
# A smaller number of images appear in the lower-entropy tail, with values between 6.0 and 6.5 bits. These cases may correspond to underexposed or low-contrast scans in which intensity values are compressed into a narrow portion of the grayscale space. Conversely, the images near the upper end of the distribution reach entropy values close to 7.8 bits, which may indicate stronger histogram equalization or more pronounced tonal variation introduced during preprocessing. Despite these isolated outliers, the overall profile of the entropy distribution reflects a dataset with broadly consistent radiographic complexity, supporting stable feature extraction and learning during model development.

# %% [markdown]
# ### 2.3.1 Histogram Entropy Outliers
#
# Images with unusually low or high histogram entropy, indicating abnormal pixel-value distributions. Low-entropy examples correspond to radiographs with reduced textural variability or mild posterization, while high-entropy examples reflect excessive noise or aggressive post-processing. These samples lie statistically outside the expected entropy range of the dataset.

# %%
# Detect Histogram Entropy outliers
if scenario("DEVELOPMENT"):
    mean_val = DF_VIEW["hist_entropy"].mean()
    std_val = DF_VIEW["hist_entropy"].std()
    DF_VIEW["hist_entropy_z"] = (DF_VIEW["hist_entropy"] - mean_val) / std_val
    DF_VIEW["hist_entropy_outlier"] = DF_VIEW["hist_entropy_z"].abs() > 3
    
    n_outliers = DF_VIEW["hist_entropy_outlier"].sum()
    pct = (n_outliers / len(DF_VIEW)) * 100
    print(f"Histogram Entropy outliers: {n_outliers} ({pct:.2f}%)")

# %%
# Outlier images for Histogram Entropy
if scenario("DEVELOPMENT"):

    outliers = DF_VIEW[DF_VIEW["hist_entropy_outlier"]]

    if len(outliers) > 0:
        examples = outliers.head(3)

        plt.figure(figsize=(16, 7))

        for idx, (_, row) in enumerate(examples.iterrows()):
            img = cv2.imread(row["image_path"], cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            filename = os.path.basename(row["image_path"])

            plt.subplot(1, 3, idx + 1)
            plt.imshow(img, cmap="gray")
            plt.title(f"Outlier\nEntropy = {row['hist_entropy']:.2f}", fontsize=12)
            plt.axis("off")

            plt.text(
                0.5, -0.10, filename,
                fontsize=10,
                ha="center", va="top",
                transform=plt.gca().transAxes
            )

        plt.tight_layout()
        plt.show()

# %% [markdown]
# **Figure 2.6** - Histogram Entropy Outliers

# %% [markdown]
# ## 2.4 Kurtosis and Skewness
#
# Kurtosis and skewness provide statistical descriptions of the shape of the grayscale intensity distribution. Kurtosis quantifies the heaviness of the histogram tails relative to a normal distribution, while skewness measures the asymmetry of the histogram. In chest radiography, the grayscale distribution is typically skewed toward lower intensities due to the predominance of air-filled lung regions. Abnormally low kurtosis may indicate a flatter distribution caused by contrast equalization or smoothing, while unusually high kurtosis suggests a histogram dominated by sharp peaks or extreme intensity clustering.
#
# Atypical kurtosis or skewness values may signal that certain images have undergone nonstandard processing, contain noise patterns, or result from acquisition variations not present in the majority of the dataset. These deviations alter the histogram shape in ways that can mislead convolutional filters during training, especially in the earliest layers where pixel-level distributions influence the learned feature maps. By measuring kurtosis and skewness across the dataset, it becomes possible to detect images whose tonal composition differs substantially from typical chest radiographs and that might warrant further inspection.
#
# Together with global contrast, dynamic range, and entropy, kurtosis and skewness offer a complementary view of image quality by characterizing the higher-order properties of the intensity distribution. These statistics allow the dataset’s overall histogram shape to be compared against expected radiographic norms, supporting the identification of histograms that are unusually flat, unusually peaked, or strongly asymmetric. As part of the data understanding phase, these metrics contribute to determining whether preprocessing steps should normalize intensity distributions or whether the dataset already exhibits stable and consistent characteristics.

# %%
# Compute image shape statistics (kurtosis and skewness)
if scenario("DEVELOPMENT"):
    DF_VIEW["kurtosis"], DF_VIEW["skewness"] = zip(*DF_VIEW["image_path"].apply(compute_kurtosis_skew))
    display(DF_VIEW[["kurtosis", "skewness"]].describe())

# %%
# Plot distribution of kurtosis values
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["kurtosis"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Kurtosis")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.7** - Kurtosis Distribution

# %% [markdown]
# The kurtosis values form a distribution concentrated primarily between approximately -1.5 and +1.0, with a mean near -0.49. This pattern indicates that most images exhibit flatter histograms than a normal distribution would suggest, which is expected for chest radiographs. Air-filled lung fields occupy a substantial portion of the image area and contribute to a large concentration of darker pixel values, while anatomical structures with higher attenuation appear less frequently. A limited number of images show higher kurtosis values extending above 2.0, and a few outliers reach values above 5.0. These cases may correspond to scans with pronounced intensity clustering, possibly caused by strong smoothing, localized contrast amplification, or specific acquisition characteristics. However, these remain isolated and do not indicate systemic inconsistency within the dataset.

# %%
# Plot distribution of skewness values
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["skewness"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Skewness")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.8** - Skewness Distribution

# %% [markdown]
# The skewness distribution is centered around negative values, with a mean near -0.56 and the majority of images falling between approximately -1.2 and -0.3. Negative skewness reflects the expected dominance of lower intensities in chest radiographs, as the lungs represent the largest anatomical region and naturally appear darker relative to bones and mediastinal structures. This asymmetry is characteristic of properly acquired radiographs and confirms that the dataset exhibits the typical tonal bias found in clinical imaging. A small number of images approach or exceed symmetric or positive skewness values, which may indicate unusual exposure conditions, differing preprocessing pipelines, or reduced representation of darker regions. These cases can be reviewed individually but do not appear frequently enough to affect the overall dataset composition.

# %% [markdown]
# ### 2.4.1 Kurtosis Outliers
#
# Radiographs exhibiting extreme kurtosis values, representing atypical tail behavior in intensity distributions. High-kurtosis images often contain sharp peaks or heavy-tailed noise patterns, while low-kurtosis images show overly flattened histograms. These deviations suggest non-standard imaging characteristics or post-acquisition alterations.

# %%
# Detect Kurtosis outliers
if scenario("DEVELOPMENT"):
    mean_val = DF_VIEW["kurtosis"].mean()
    std_val = DF_VIEW["kurtosis"].std()
    DF_VIEW["kurtosis_z"] = (DF_VIEW["kurtosis"] - mean_val) / std_val
    DF_VIEW["kurtosis_outlier"] = DF_VIEW["kurtosis_z"].abs() > 3
    
    n_outliers = DF_VIEW["kurtosis_outlier"].sum()
    pct = (n_outliers / len(DF_VIEW)) * 100
    print(f"Kurtosis outliers: {n_outliers} ({pct:.2f}%)")

# %%
# Outlier images for Kurtosis
if scenario("DEVELOPMENT"):

    outliers = DF_VIEW[DF_VIEW["kurtosis_outlier"]]

    if len(outliers) > 0:
        examples = outliers.head(3)

        plt.figure(figsize=(16, 7))

        for idx, (_, row) in enumerate(examples.iterrows()):
            img = cv2.imread(row["image_path"], cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            filename = os.path.basename(row["image_path"])

            plt.subplot(1, 3, idx + 1)
            plt.imshow(img, cmap="gray")
            plt.title(f"Outlier\nKurtosis = {row['kurtosis']:.2f}", fontsize=12)
            plt.axis("off")

            plt.text(
                0.5, -0.10, filename,
                fontsize=10,
                ha="center", va="top",
                transform=plt.gca().transAxes
            )

        plt.tight_layout()
        plt.show()

# %% [markdown]
# **Figure 2.9** - Kurtosis Outliers

# %% [markdown]
# ## 2.5 Local Contrast Uniformity
#
# Local contrast uniformity describes how contrast varies across different regions of an image. It is computed by dividing the image into smaller tiles and calculating the standard deviation of pixel intensities within each tile. These tile-level measurements reveal how much local structure and intensity variation is present in different parts of the radiograph. Chest X-rays naturally contain heterogeneous regions: lung fields exhibit soft-tissue textures, the mediastinum is denser, and bony structures introduce sharp boundaries. A realistic radiograph therefore displays moderate variation in local contrast between regions.
#
# Significant deviations in local contrast uniformity may indicate that an image has undergone strong local enhancement or smoothing. For example, local histogram equalization methods such as CLAHE (Contrast Limited Adaptive Histogram Equalization) increase local contrast uniformly across the entire image, which reduces the variability between tiles and often raises the average local contrast. Conversely, excessive smoothing lowers local contrast and may disproportionately affect diagnostically important areas. Monitoring this metric helps identify images that display atypical spatial contrast patterns, either due to acquisition characteristics or prior preprocessing, preventing such outliers from influencing the learned feature representations.
#
# Local contrast analysis provides a spatially aware extension of the earlier global metrics. While global contrast and entropy measure aggregation over the entire intensity distribution, local contrast uniformity reveals whether the radiograph preserves appropriate regional differences. This information is especially useful when deciding whether the dataset requires additional normalization steps or whether any images need to be excluded. The metric also establishes a reference for assessing future inference images, helping detect preprocessed or enhanced scans that may not align with the training distribution.

# %%
# Compute Local Contrast Uniformity (mean and variance of tile-level standard deviations)
if scenario("DEVELOPMENT"):
    DF_VIEW["local_std_mean"], DF_VIEW["local_std_var"] = zip(*DF_VIEW["image_path"].apply(compute_local_contrast))
    display(DF_VIEW[["local_std_mean", "local_std_var"]].describe())

# %%
# Plot representative images by local contrast variance
if scenario("DEVELOPMENT"):

    df_sorted = DF_VIEW.sort_values(by="local_std_var")

    low_row  = df_sorted.iloc[0]
    mid_row  = df_sorted.iloc[len(df_sorted) // 2]
    high_row = df_sorted.iloc[-1]

    examples = [
        ("Lowest Local Contrast Variance",  low_row["image_path"],  low_row["local_std_var"]),
        ("Median Local Contrast Variance",  mid_row["image_path"],  mid_row["local_std_var"]),
        ("Highest Local Contrast Variance", high_row["image_path"], high_row["local_std_var"])
    ]

    plt.figure(figsize=(16, 7))

    for idx, (label, path, value) in enumerate(examples):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue

        filename = os.path.basename(path)

        plt.subplot(1, 3, idx + 1)
        plt.imshow(img, cmap="gray")
        plt.title(f"{label}\nVariance = {value:.2f}", fontsize=12)
        plt.axis("off")

        plt.text(
            0.5, -0.10, filename,
            fontsize=10,
            ha="center", va="top",
            transform=plt.gca().transAxes
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.10** - Lowest, Median, and Highest Local Contrast Variance Images

# %%
# Plot distribution of local contrast variance
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["local_std_var"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Variance of Local Standard Deviations")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.11** - Local Contrast Variance Distribution

# %% [markdown]
# The distribution of local contrast variance displays a broad range of values, with most images concentrated between approximately 80 and 300. This behaviour is consistent with chest radiographs, which naturally contain regional differences in contrast: lung fields present relatively homogeneous textures, bony structures introduce strong edges, and the mediastinum contains dense tissue with intermediate variability. The long tail extending toward higher variance suggests that a subset of images exhibits unusually heterogeneous local contrast. These outliers may correspond to radiographs with sharper boundaries, stronger acquisition noise, or more pronounced tonal differences, but they do not form a cluster that would indicate systematic overprocessing or local equalization.

# %%
# Plot distribution of local contrast mean
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["local_std_mean"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Mean of Local Standard Deviations")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.12** - Local Contrast Mean Distribution

# %% [markdown]
# The distribution of mean local contrast shows a dense peak between roughly 20 and 32, reflecting a stable representation of structural detail across the dataset. This profile is characteristic of radiographs that preserve adequate local variation without excessive enhancement. Only a small number of images appear at the lower end of the scale near 11 or at the higher end near 40, which likely represent underexposed scans or images with unusually strong spatial contrast characteristics. These extremes are isolated and do not suggest the presence of a distinct subgroup of preprocessed or contrast-equalized images.

# %% [markdown]
# ### 2.5.1 Local Contrast Variance Outliers
#
# Images with unusually high or low variance in tile-level standard deviations. High-variance samples typically indicate regions of intensified noise or sharpness inconsistencies, whereas low-variance samples correspond to overly smoothed or low-detail radiographs. These outliers reflect local structural irregularities not representative of the dataset’s general behavior.

# %%
# Detect Local Contrast Variance outliers
if scenario("DEVELOPMENT"):
    mean_val = DF_VIEW["local_std_var"].mean()
    std_val = DF_VIEW["local_std_var"].std()
    DF_VIEW["local_std_var_z"] = (DF_VIEW["local_std_var"] - mean_val) / std_val
    DF_VIEW["local_std_var_outlier"] = DF_VIEW["local_std_var_z"].abs() > 3
    
    n_outliers = DF_VIEW["local_std_var_outlier"].sum()
    pct = (n_outliers / len(DF_VIEW)) * 100
    print(f"Local Contrast Variance outliers: {n_outliers} ({pct:.2f}%)")

# %%
# Outlier images for Local Contrast Variance
if scenario("DEVELOPMENT"):

    outliers = DF_VIEW[DF_VIEW["local_std_var_outlier"]]

    if len(outliers) > 0:
        examples = outliers.head(3)

        plt.figure(figsize=(16, 7))

        for idx, (_, row) in enumerate(examples.iterrows()):
            img = cv2.imread(row["image_path"], cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            filename = os.path.basename(row["image_path"])

            plt.subplot(1, 3, idx + 1)
            plt.imshow(img, cmap="gray")
            plt.title(f"Outlier\nVar = {row['local_std_var']:.2f}", fontsize=12)
            plt.axis("off")

            plt.text(
                0.5, -0.10, filename,
                fontsize=10,
                ha="center", va="top",
                transform=plt.gca().transAxes
            )

        plt.tight_layout()
        plt.show()

# %% [markdown]
# **Figure 2.13** - Local Contrast Variance Outliers

# %% [markdown]
# ## 2.6 High-Frequency Content
#
# High-frequency Content (Edge Energy) measures the amount of rapid intensity variation present in an image. It is typically computed by applying a high-pass operator, such as the Laplacian filter, and quantifying the average magnitude of the resulting response. In chest radiography, high-frequency information corresponds to edges and fine structural details such as rib boundaries, vascular markings, clavicle contours, and soft-tissue texture. A well-formed radiograph maintains a balanced level of high-frequency content: excessive smoothing significantly reduces edge energy, while aggressive sharpening or noise amplification increases it.
#
# Large deviations in high-frequency content indicate potential issues in image acquisition or preprocessing. Overly smoothed images may result from denoising pipelines, motion blur, or low-dose acquisition, all of which suppress clinically relevant textural cues. Conversely, images with unusually high edge energy may exhibit strong sharpening, residual noise, or compression artifacts. These variations affect the early convolutional layers of a neural network, which rely heavily on the presence and stability of local gradients to extract meaningful features. By characterizing high-frequency behaviour across the dataset, it becomes possible to identify images whose sharpness profile differs substantially from standard radiographic texture.
#
# High-frequency analysis acts as a complementary measure to the earlier contrast-related metrics by focusing on structural detail rather than tonal distribution. Examining edge energy helps determine whether the dataset contains imaging outliers that may need normalization, exclusion, or preprocessing adjustments. It also establishes a reference for future inference images, enabling the identification of scans that underwent different noise-reduction or sharpening pipelines. Taken together with the preceding metrics, high-frequency content provides a comprehensive overview of the dataset’s radiographic fidelity.

# %%
# Compute high-frequency content using the mean absolute Laplacian response
if scenario("DEVELOPMENT"):
    DF_VIEW["high_freq_energy"] = DF_VIEW["image_path"].apply(compute_high_freq_energy)
    display(DF_VIEW["high_freq_energy"].describe())

# %%
# Plot distribution of high-frequency content values
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["high_freq_energy"].dropna(), bins=40, edgecolor="black")
    plt.xlabel("Mean Absolute Laplacian Value")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Figure 2.14** - Lowest, Median, and Highest High-Frequency Content Images

# %%
# Plot representative images by high-frequency content
if scenario("DEVELOPMENT"):

    df_sorted = DF_VIEW.sort_values(by="high_freq_energy")

    low_row  = df_sorted.iloc[0]
    mid_row  = df_sorted.iloc[len(df_sorted) // 2]
    high_row = df_sorted.iloc[-1]

    examples = [
        ("Lowest High-Frequency Content",  low_row["image_path"],  low_row["high_freq_energy"]),
        ("Median High-Frequency Content",  mid_row["image_path"],  mid_row["high_freq_energy"]),
        ("Highest High-Frequency Content", high_row["image_path"], high_row["high_freq_energy"])
    ]

    plt.figure(figsize=(16, 7))

    for idx, (label, path, value) in enumerate(examples):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue

        filename = os.path.basename(path)

        plt.subplot(1, 3, idx + 1)
        plt.imshow(img, cmap="gray")
        plt.title(f"{label}\nHF = {value:.2f}", fontsize=12)
        plt.axis("off")

        plt.text(
            0.5, -0.10, filename,
            fontsize=10,
            ha="center", va="top",
            transform=plt.gca().transAxes
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.15** - High-Frequency Content Distribution

# %% [markdown]
# The distribution of high-frequency content is concentrated between roughly 3.0 and 7.0, indicating that most images exhibit a normal level of structural detail and edge sharpness consistent with standard chest radiographs. This pattern suggests a uniform acquisition process with stable preservation of fine anatomical boundaries. A smaller number of images fall below this range, which may reflect smoothing, reduced dose, or minor motion effects, while a long upper tail contains isolated cases with unusually strong edges or noise. These outliers remain rare and can be reviewed individually if needed.
#
# Overall, the dataset presents a coherent sharpness profile with only limited deviations, indicating that the radiographs are largely consistent in their high-frequency characteristics and appropriate for further analysis without major preprocessing adjustments.

# %% [markdown]
# The image quality metrics collectively indicate that the dataset exhibits a high degree of tonal and structural consistency. Global contrast and dynamic range measurements show that most radiographs maintain appropriate exposure levels, covering nearly the full available grayscale range with limited variation. Histogram entropy reinforces this finding by demonstrating that grayscale complexity remains stable across the dataset, with only a small number of images displaying reduced or unusually elevated entropy.
#
# The distribution of skewness and kurtosis further supports the conclusion that the dataset adheres to typical radiographic intensity profiles. The negative skewness values reflect the expected predominance of darker lung regions, while kurtosis values indicate slightly flattened but otherwise normal histogram shapes. Together, these global metrics suggest that the images have not undergone diverse or aggressive post-processing procedures and that acquisition characteristics are relatively homogeneous.
#
# Spatial metrics derived from local contrast and high-frequency content show comparable stability. Tile-based measures reveal appropriate regional variability in contrast without signs of widespread local enhancement, and the high-frequency content distribution indicates consistent sharpness and preservation of anatomical detail. Only a small number of images deviate noticeably from these patterns, and these cases appear isolated rather than systematic. Overall, the metrics suggest that the dataset is well suited for downstream modelling without the need for substantial corrective preprocessing.

# %% [markdown]
# ### 2.6.1 High-Frequency Content Outliers
#
# Radiographs with extreme high-frequency responses based on the mean absolute Laplacian. These samples exhibit disproportionate levels of edge enhancement or high-frequency noise, often indicating non-standard sharpening, low-dose acquisition artifacts, or compression effects. Their frequency profiles fall well outside the distribution observed in the dataset.

# %%
# Detect High-Frequency Energy outliers
if scenario("DEVELOPMENT"):
    mean_val = DF_VIEW["high_freq_energy"].mean()
    std_val = DF_VIEW["high_freq_energy"].std()
    DF_VIEW["high_freq_energy_z"] = (DF_VIEW["high_freq_energy"] - mean_val) / std_val
    DF_VIEW["high_freq_energy_outlier"] = DF_VIEW["high_freq_energy_z"].abs() > 3
    
    n_outliers = DF_VIEW["high_freq_energy_outlier"].sum()
    pct = (n_outliers / len(DF_VIEW)) * 100
    print(f"High-Frequency Energy outliers: {n_outliers} ({pct:.2f}%)")

# %%
# Outlier images for High-Frequency Content
if scenario("DEVELOPMENT"):

    outliers = DF_VIEW[DF_VIEW["high_freq_energy_outlier"]]

    if len(outliers) > 0:
        examples = outliers.head(3)

        plt.figure(figsize=(16, 7))

        for idx, (_, row) in enumerate(examples.iterrows()):
            img = cv2.imread(row["image_path"], cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            filename = os.path.basename(row["image_path"])

            plt.subplot(1, 3, idx + 1)
            plt.imshow(img, cmap="gray")
            plt.title(f"Outlier\nHF = {row['high_freq_energy']:.2f}", fontsize=12)
            plt.axis("off")

            plt.text(
                0.5, -0.10, filename,
                fontsize=10,
                ha="center", va="top",
                transform=plt.gca().transAxes
            )

        plt.tight_layout()
        plt.show()

# %% [markdown]
# **Figure 2.16** - High-Frequency Content Outliers

# %% [markdown]
# ## 2.7 Geometric Metrics

# %% [markdown]
# The preceding contrast and frequency domain metrics characterize tonal and textural properties of the dataset but do not address spatial positioning or image composition. Geometric metrics quantify how X-ray content is positioned and framed within each image, capturing variations in patient centering, field of view, and anatomical coverage. These measurements are essential for deriving data-driven augmentation parameters, particularly for spatial transformations such as translation, zoom, and rotation.
#
# Chest radiographs naturally exhibit variability in patient positioning during acquisition. Even with standardized protocols, factors such as patient cooperation, technician technique, and equipment constraints introduce small deviations in centering and framing. Quantifying these natural geometric variations establishes realistic bounds for augmentation: transformations that exceed the dataset's observed variability risk generating implausible training samples, while transformations that fall short of natural variation fail to improve model robustness.
#
# The computed geometric metrics include horizontal and vertical centering offsets, which measure how far the radiographic content deviates from the image center, and content width and height ratios, which indicate what fraction of the image frame is occupied by actual diagnostic information. Additionally, the aspect ratio of each image is recorded to support quality control and to inform decisions regarding resizing or padding strategies during preprocessing. Together, these metrics enable the derivation of translation and zoom augmentation parameters that reflect the dataset's intrinsic spatial characteristics rather than arbitrary defaults.

# %%
if scenario("DEVELOPMENT"):
    print("Computing geometric metrics...")
    
    (DF_VIEW["centering_offset_x"],
     DF_VIEW["centering_offset_y"],
     DF_VIEW["content_width_ratio"],
     DF_VIEW["content_height_ratio"],
     DF_VIEW["aspect_ratio"]) = zip(*DF_VIEW["image_path"].progress_apply(compute_geometric_metrics))  # ADD aspect_ratio
    
    print("\nGeometric metrics computation completed.")
    display(DF_VIEW[["centering_offset_x", "centering_offset_y", 
                     "content_width_ratio", "content_height_ratio",
                     "aspect_ratio"]].describe())

# %%
# Plot centering offset distributions
if scenario("DEVELOPMENT"):
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    axes[0].hist(DF_VIEW["centering_offset_x"].dropna(), bins=40, edgecolor="black")
    axes[0].set_title("Horizontal Centering Offset Distribution")
    axes[0].set_xlabel("Offset (fraction of width)")
    axes[0].set_ylabel("Number of Images")
    axes[0].grid(True)
    axes[0].axvline(0, color='red', linestyle='--', label='Perfect Center')
    axes[0].legend()
    
    axes[1].hist(DF_VIEW["centering_offset_y"].dropna(), bins=40, edgecolor="black")
    axes[1].set_title("Vertical Centering Offset Distribution")
    axes[1].set_xlabel("Offset (fraction of height)")
    axes[1].set_ylabel("Number of Images")
    axes[1].grid(True)
    axes[1].axvline(0, color='red', linestyle='--', label='Perfect Center')
    axes[1].legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.17** - Horizontal and Vertical Centering Offset Distribution

# %% [markdown]
# The horizontal and vertical centering offset distributions show that most images are well-centered, with offsets concentrated tightly around zero. The standard deviations of 0.5% horizontally and near 0% vertically indicate highly consistent patient positioning across the dataset, suggesting minimal natural variation in image composition.

# %%
# Plot content size ratio distributions
if scenario("DEVELOPMENT"):
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    axes[0].hist(DF_VIEW["content_width_ratio"].dropna(), bins=40, edgecolor="black")
    axes[0].set_title("Content Width Ratio Distribution")
    axes[0].set_xlabel("Width Ratio (content / image)")
    axes[0].set_ylabel("Number of Images")
    axes[0].grid(True)
    
    axes[1].hist(DF_VIEW["content_height_ratio"].dropna(), bins=40, edgecolor="black")
    axes[1].set_title("Content Height Ratio Distribution")
    axes[1].set_xlabel("Height Ratio (content / image)")
    axes[1].set_ylabel("Number of Images")
    axes[1].grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Figure 2.18** - Content Width and Height Ratio Distributions

# %% [markdown]
# Content width and height ratios reveal that radiographic content occupies approximately 95-98% of the frame in most images, indicating minimal black borders or empty space. This consistency simplifies preprocessing decisions and suggests that the dataset was acquired with standardized framing protocols.

# %%
# Plot aspect ratio distribution
if scenario("DEVELOPMENT"):
    plt.figure(figsize=(10, 5))
    plt.hist(DF_VIEW["aspect_ratio"].dropna(), bins=40, edgecolor="black")
    plt.title("Aspect Ratio Distribution")
    plt.xlabel("Aspect Ratio (width / height)")
    plt.ylabel("Number of Images")
    plt.grid(True)
    plt.axvline(1.0, color='red', linestyle='--', label='Square (1:1)')
    plt.legend()
    plt.show()

# %% [markdown]
# **Figure 2.19** - Aspect Ratio Distribution

# %% [markdown]
# The aspect ratio distribution is concentrated around 1.0-1.4, with most images being roughly square or slightly wider than tall. The tight distribution without extreme outliers confirms consistent image acquisition geometry across the dataset, reducing the need for aspect-ratio-specific preprocessing strategies.

# %% [markdown]
# ## 2.8 Data Understanding Metrics Export

# %% [markdown]
# After computing image-level characteristics in the Data Understanding phase, the notebook exports a consolidated JSON file that contains these metrics for every image in the dataset. The file includes the image path, class label, dataset split, all computed quantitative metrics, and the corresponding outlier indicators. It serves as an external representation of the dataset’s quality profile, derived directly from the analytical steps documented in this section.
#
# This exported file is consumed by **_cxray_**, an interactive preprocessing exploration tool developed specifically for this project. The tool is available online at: [https://logus2k.com/cxray](https://logus2k.com/cxray). It provides a visual environment for examining the effects of different preprocessing operations, such as cropping strategies, zoom adjustments, and contrast modifications. When supplied with the exported metrics, the tool allows the user to relate visual inspection to the quantitative properties measured during Data Understanding. This connection supports more informed and consistent Data Preparation decisions, helping ensure that the preprocessing applied during model training is both statistically justified and visually validated.

# %%
# Export DF_VIEW (DU metrics) to JSON for use by the preprocessing UI
if scenario("DEVELOPMENT", "PRODUCTION"):

    export_dir = "./static"
    os.makedirs(export_dir, exist_ok=True)

    export_path = os.path.join(export_dir, "du_metrics.json")

    # Select DU-relevant fields
    DU_EXPORT_COLUMNS = [
        "image_path",
        "label",
        "split",
        "global_std",
        "dynamic_range",
        "hist_entropy",
        "kurtosis",
        "skewness",
        "local_std_mean",
        "local_std_var",
        "high_freq_energy",
        "centering_offset_x",
        "centering_offset_y",
        "content_width_ratio",
        "content_height_ratio",
        "aspect_ratio"
    ]

    # If outlier columns exist, include them automatically
    outlier_cols = [c for c in DF_VIEW.columns if c.endswith("_outlier")]
    DU_EXPORT_COLUMNS.extend(outlier_cols)

    df_export = DF_VIEW[DU_EXPORT_COLUMNS].copy()

    # Normalize file paths for frontend
    df_export["image_path"] = df_export["image_path"].str.replace("\\", "/")

    # Export to JSON
    df_export.to_json(export_path, orient="records", indent=2)

    print(f"DU metrics exported to: {export_path}")

# %% [markdown]
# &#160;

# %% [markdown]
# # 3. Data Preparation
#
# ---

# %% [markdown]
# ## 3.1 Data Splitting Strategy
#
# The dataset’s predefined train and test partitions are preserved to avoid leakage.
# A validation set is created by reserving a fixed proportion of the training data, using a deterministic random seed to ensure reproducibility.
# Split sizes and class distributions are documented to support transparent evaluation and to confirm that each subset remains representative of the overall dataset.

# %%
# Isolate the Original Train and Test Data using "split" column
# The Test set is the original data from the TEST_DIR
DF_TEST = DF_MODEL[DF_MODEL['split'] == 'test'].copy()
# The data used for training and validation is the original data from the TRAIN_DIR
DF_TRAIN = DF_MODEL[DF_MODEL['split'] == 'train'].copy()

# Final Test set extraction
X_test = DF_TEST['image_path']
y_test = DF_TEST['label']

# Split the Original Training Data into New Train and Validation Sets
X_train_original = DF_TRAIN['image_path']
y_train_original = DF_TRAIN['label']

# Encode the training labels (0 and 1) for stratification and class weight calculation
y_train_original_encoded = y_train_original.apply(lambda x: 1 if x == 'PNEUMONIA' else 0)

# Split the original training set into the new Training (90%) and Validation (10%) sets
X_train, X_val, y_train, y_val, y_train_encoded, y_val_encoded = train_test_split(
    X_train_original, y_train_original, y_train_original_encoded,
    # 10% of the original training pool is allocated to validation
    test_size=0.10,
    random_state=42, 
    shuffle=True, 
    # Stratify by original label
    stratify=y_train_original
)

# Calculate the class weights using the new training set labels
classes = np.unique(y_train_encoded)
class_weights_array = sk_class_weight.compute_class_weight('balanced', classes=classes, y=y_train_encoded)

# Convert to a dictionary for Keras: {0: weight_for_NORMAL, 1: weight_for_PNEUMONIA}
class_weights_dict = {
    i: class_weights_array[i] for i in range(len(classes))
}

# Variable Summary
print("=" * 70)
print("DATA SPLIT SUMMARY")
print("=" * 70)
print(f"Training set size:   {len(X_train)}")
print(f"Validation set size: {len(X_val)}")
print(f"Test set size:       {len(X_test)}")
print("-" * 70)
print(f"Final Class Weights (for model.fit): {class_weights_dict}")

# CORRECTED PRINT STATEMENTS USING F-STRINGS:
print(f"   Weight for NORMAL (Class 0): {class_weights_dict[0]:.2f}")
print(f"   Weight for PNEUMONIA (Class 1): {class_weights_dict[1]:.2f}")

print("=" * 70)
# Out:
# ======================================================================
# DATA SPLIT SUMMARY
# ======================================================================
# Training set size:   4708
# Validation set size: 524
# Test set size:       624
# ----------------------------------------------------------------------
# Final Class Weights (for model.fit): {0: np.float64(1.9390444810543657), 1: np.float64(0.6737263880938752)}
#    Weight for NORMAL (Class 0): 1.94
#    Weight for PNEUMONIA (Class 1): 0.67
# ======================================================================

# %% [markdown]
# ## 3.2 Data-Driven Augmentation Parameter Analysis

# %% [markdown]
# Data augmentation is a critical component of deep learning pipelines for medical imaging, particularly when working with datasets of limited size or class imbalance. However, the selection of augmentation parameters is often based on ad-hoc experimentation, domain conventions, or arbitrary defaults rather than on systematic analysis of the dataset's inherent characteristics. This approach risks introducing either insufficient variation, failing to improve model generalization, or excessive distortion, creating unrealistic samples that mislead the learning process and degrade performance on genuine clinical data.
#
# The metrics computed in the preceding sections provide a quantitative foundation for deriving augmentation parameters directly from the dataset's natural variation. By measuring the statistical properties of brightness, contrast, spatial positioning, content framing, and noise across the existing images, it becomes possible to establish augmentation ranges that reflect realistic variability rather than speculative guesses. This data-driven approach ensures that augmented samples remain within the distribution of plausible radiographic appearances while still introducing sufficient diversity to prevent overfitting.
#
# Class-specific analysis is particularly important for imbalanced datasets such as this one, where the PNEUMONIA class outnumbers the NORMAL class by a ratio of approximately 2.7:1. Applying uniform augmentation to both classes may not address the representational asymmetry effectively. Instead, examining each class independently allows for tailored augmentation strategies: more aggressive transformation of the minority class to increase its effective sample size, and conservative augmentation of the majority class to preserve its existing diversity without introducing artifacts. This targeted approach supports more balanced learning and reduces the risk of the model developing a systematic bias toward the overrepresented class.
#
# The following analysis computes coefficient of variation (CV) for brightness, contrast, and noise metrics, and standard deviation for geometric positioning and content framing. These statistics are then translated into recommended parameter ranges for Keras preprocessing layers (`RandomRotation`, `RandomTranslation`, `RandomZoom`, `RandomBrightness`, `RandomContrast`, and `GaussianNoise`), providing concrete, defensible values that can be directly applied during model training through a `Sequential` augmentation pipeline. The analysis is performed separately for NORMAL and PNEUMONIA images, and concludes with strategic recommendations for handling class imbalance through either differential augmentation or class weighting.

# %%
if scenario("DEVELOPMENT"):
    print("=" * 70)
    print("DATA-DRIVEN AUGMENTATION PARAMETER ANALYSIS (PER CLASS)")
    print("=" * 70)
    print()
    
    for class_name in ["NORMAL", "PNEUMONIA"]:
        df_class = DF_VIEW[DF_VIEW["label"] == class_name]
        n_samples = len(df_class)
        
        print(f"\n{'='*70}")
        print(f"CLASS: {class_name} ({n_samples} images)")
        print(f"{'='*70}\n")
        
        # ===== BRIGHTNESS/CONTRAST AUGMENTATION =====
        global_stds = df_class["global_std"].dropna()
        # CV calculation is correct: std / mean
        brightness_cv = global_stds.std() / global_stds.mean()
        
        # This becomes the factor for RandomBrightness, capped at 0.5
        brightness_var_recommended = min(0.5, brightness_cv)
        
        # This old-style range is informative but not directly used in modern Keras factor
        brightness_range_old_style = (max(0.5, 1 - brightness_var_recommended), 
                                      min(1.5, 1 + brightness_var_recommended))
        
        print("BRIGHTNESS AUGMENTATION:")
        print(f"  Natural variation (CV): {brightness_cv:.2%}")
        # Show recommended factor for RandomBrightness
        print(f"  Recommended brightness_factor: {brightness_var_recommended:.2f}")
        print(f"  (Approximate old-style range: {brightness_range_old_style})")
        print()
        
        # ===== CONTRAST AUGMENTATION =====
        hist_entropies = df_class["hist_entropy"].dropna()
        contrast_cv = hist_entropies.std() / hist_entropies.mean()
        
        # This becomes the factor for RandomContrast
        contrast_var_recommended = min(0.5, contrast_cv)
        
        print("CONTRAST AUGMENTATION:")
        print(f"  Natural variation (CV): {contrast_cv:.2%}")
        print(f"  Recommended contrast_factor: {contrast_var_recommended:.2f}")
        print()
        
        # ===== GEOMETRIC AUGMENTATION =====
        offset_x_std = df_class["centering_offset_x"].dropna().std()
        offset_y_std = df_class["centering_offset_y"].dropna().std()
        
        width_ratio_std = df_class["content_width_ratio"].dropna().std()
        height_ratio_std = df_class["content_height_ratio"].dropna().std()
        
        # This becomes the height_factor for RandomZoom (symmetric zoom)
        zoom_var_recommended = max(width_ratio_std, height_ratio_std)
        
        print("GEOMETRIC AUGMENTATION:")
        print(f"  Horizontal centering std: {offset_x_std:.3f}")
        print(f"  Vertical centering std: {offset_y_std:.3f}")
        # Show recommended factors for RandomTranslation
        print(f"  Recommended width_factor (Translation): {offset_x_std:.3f}")
        print(f"  Recommended height_factor (Translation): {offset_y_std:.3f}")
        # Show recommended factor for RandomZoom
        print(f"  Recommended zoom_height_factor: {zoom_var_recommended:.3f}")
        print()
        
        # ===== NOISE AUGMENTATION =====
        high_freq = df_class["high_freq_energy"].dropna()
        noise_cv = high_freq.std() / high_freq.mean()

        if noise_cv > 0.3:
            gaussian_noise_recommended = min(0.05, noise_cv * 0.1)  # Changed: 0.05 cap, 0.1 scale
        else:
            gaussian_noise_recommended = 0
            print("NOISE AUGMENTATION:")
            print(f"  Recommended gaussian_noise (stddev): 0 (low variation)")
        print()
        
        # ===== CLASS-SPECIFIC RECOMMENDATIONS (MODERN KERAS API) =====
        print("-" * 70)
        print(f"RECOMMENDED CONFIGURATION FOR {class_name} (Modern Keras Layers):")
        print("-" * 70)
        # Use factor (fraction of 2*PI, or 1/360th of the degrees)
        print(f"RandomRotation(factor={10/360.0:.3f}),  # 10 degrees") 
        # width_factor and height_factor for RandomTranslation
        print(f"RandomTranslation(width_factor={offset_x_std:.3f}, height_factor={offset_y_std:.3f}),")
        # factor for RandomBrightness
        print(f"RandomBrightness(factor={brightness_var_recommended:.2f}),") 
        # height_factor for RandomZoom (symmetric zoom)
        print(f"RandomZoom(height_factor={zoom_var_recommended:.3f}),")
        print(f"GaussianNoise(stddev={gaussian_noise_recommended:.4f})")
        print()
    
    # ===== BALANCING STRATEGY =====
    print("\n" + "=" * 70)
    print("CLASS IMBALANCE HANDLING STRATEGY")
    print("=" * 70)
    print()
    
    normal_count = len(DF_VIEW[DF_VIEW["label"] == "NORMAL"])
    pneumonia_count = len(DF_VIEW[DF_VIEW["label"] == "PNEUMONIA"])
    imbalance_ratio = pneumonia_count / normal_count
    
    print(f"NORMAL: {normal_count} images")
    print(f"PNEUMONIA: {pneumonia_count} images")
    print(f"Imbalance ratio: {imbalance_ratio:.2f}:1")
    print()
    
    print("RECOMMENDED APPROACH:")
    print()
    
    # --- Corrected Option 1: Separate Keras Sequential Models ---
    print("Option 1: Separate Keras Sequential Augmentation (More Aggressive for NORMAL)")
    print("-" * 70)
    print("# More aggressive augmentation for minority class (NORMAL)")
    print("normal_augmentation_pipeline = Sequential([")
    print("    # Rotation: More than natural 15 degrees (~0.042 factor)")
    print("    RandomRotation(factor=0.042, fill_mode='constant', fill_value=0.0),") 
    print("    # Translation: More aggressive (0.10 factor)")
    print("    RandomTranslation(height_factor=0.10, width_factor=0.10, fill_mode='constant'),") 
    print("    # Brightness: More aggressive (0.20 factor)")
    print("    RandomBrightness(factor=0.20, value_range=(0, 1)),") 
    print("    # Zoom: More aggressive (0.10 factor)")
    print("    RandomZoom(height_factor=0.10, fill_mode='constant', fill_value=0.0),")
    print("    RandomFlip(mode='horizontal')")
    print("])")
    print()
    
    print("# Conservative augmentation for majority class (PNEUMONIA)")
    print("pneumonia_augmentation_pipeline = Sequential([")
    print("    # Rotation: Moderate (10 degrees ~0.028 factor)")
    print("    RandomRotation(factor=0.028, fill_mode='constant', fill_value=0.0),") 
    print("    # Translation: Match natural variation (~0.005 factor)")
    print("    RandomTranslation(height_factor=0.005, width_factor=0.005, fill_mode='constant'),")
    print("    # Brightness: Moderate (0.15 factor)")
    print("    RandomBrightness(factor=0.15, value_range=(0, 1))")
    print("])")
    print()
    
    # --- Corrected Option 2: Unified Generator + Class Weights ---
    print("Option 2: Unified Keras Sequential Augmentation + Class Weights (Recommended)")
    print("-" * 70)
    print("# Single pipeline with moderate augmentation")
    print("unified_augmentation_pipeline = Sequential([")
    print("    RandomRotation(factor=0.028),  # 10 degrees")
    print("    RandomTranslation(width_factor=0.05, height_factor=0.05),")
    print("    RandomBrightness(factor=0.15, value_range=(0, 1)),")
    print("    RandomFlip(mode='horizontal')")
    print("])")
    print()
    
    print("# Use class weights to handle imbalance (applied in model.fit)")
    print("class_weights = sk_class_weight.compute_class_weight(")
    print("    'balanced',")
    print("    classes=np.unique(y_train),")
    print("    y=y_train")
    print(")")
    print(f"# Estimated weights: NORMAL={imbalance_ratio:.2f}, PNEUMONIA=1.0")

# %% [markdown]
# ## 3.2 Data Augmentation
#
# Augmentation is applied exclusively to the training set and kept consistent across all models to enable fair comparison.
# Transformations are limited to clinically realistic variations that simulate routine acquisition differences, such as small rotations, translations, mild zoom, and conservative brightness adjustments.
# Anatomically implausible transformations, including vertical flips or aggressive geometric distortions, are avoided.
# Augmentation ranges are selected to preserve diagnostic content while improving generalization under typical real-world imaging variability.

# %%
if scenario("DEVELOPMENT"):
    print("=" * 70)
    print("DATA-DRIVEN AUGMENTATION PARAMETER ANALYSIS AND VARIABLE INITIALIZATION")
    print("=" * 70)

    # 1. INITIALIZE DICTIONARIES TO STORE CLASS-SPECIFIC RESULTS
    class_results = {}
    
    # Static parameters are initialized here
    # 10 degrees
    CALCULATED_ROTATION_FACTOR = 10 / 360.0
    # Only horizontal makes sense in this case
    CALCULATED_FLIP_MODE = 'horizontal'
    
    # 2. CALCULATE AND STORE CLASS-SPECIFIC VALUES
    for class_name in ["NORMAL", "PNEUMONIA"]:

        df_class = DF_VIEW[DF_VIEW["label"] == class_name]
        
        # BRIGHTNESS/CONTRAST
        global_stds = df_class["global_std"].dropna()
        brightness_cv = global_stds.std() / global_stds.mean()
        brightness_var_recommended = min(0.5, brightness_cv)
        
        hist_entropies = df_class["hist_entropy"].dropna()
        contrast_cv = hist_entropies.std() / hist_entropies.mean()
        contrast_var_recommended = min(0.5, contrast_cv)
        
        # GEOMETRIC
        offset_x_std = df_class["centering_offset_x"].dropna().std()
        offset_y_std = df_class["centering_offset_y"].dropna().std()
        width_ratio_std = df_class["content_width_ratio"].dropna().std()
        height_ratio_std = df_class["content_height_ratio"].dropna().std()
        zoom_var_recommended = max(width_ratio_std, height_ratio_std)
        
        # NOISE - More conservative calculation
        high_freq = df_class["high_freq_energy"].dropna()
        noise_cv = high_freq.std() / high_freq.mean()

        if noise_cv > 0.5:  # Only if variation is very high
            gaussian_noise_recommended = min(0.05, noise_cv * 0.1)  # Cap at 5%, scale by 0.1
        else:
            gaussian_noise_recommended = 0
            
        # Store results
        class_results[class_name] = {
            'brightness_factor': brightness_var_recommended,
            'contrast_factor': contrast_var_recommended,
            'offset_x_std': offset_x_std,
            'offset_y_std': offset_y_std,
            'zoom_factor': zoom_var_recommended,
            'gaussian_stddev': gaussian_noise_recommended,
            'count': len(df_class)
        }
        
        # Printing for development environment confirmation
        print(f"\n--- {class_name} Parameters ---")
        print(f"Brightness Factor: {brightness_var_recommended:.3f}")
        print(f"Contrast Factor: {contrast_var_recommended:.3f}")
        print(f"Shift X/Y Std: {offset_x_std:.3f} / {offset_y_std:.3f}")
        print(f"Zoom Factor: {zoom_var_recommended:.3f}")
        print(f"Gaussian Noise: {gaussian_noise_recommended:.3f}")

    # 3. ARTIFACT DETECTION: Calculate class difference ratios
    print("\n" + "=" * 70)
    print("ARTIFACT DETECTION: Analyzing Class Distribution Differences")
    print("=" * 70)
    
    def safe_ratio(a, b, epsilon=0.001):
        """Calculate ratio, avoiding division by zero"""
        return max(a, b) / max(min(a, b), epsilon)
    
    brightness_ratio = safe_ratio(
        class_results['NORMAL']['brightness_factor'],
        class_results['PNEUMONIA']['brightness_factor']
    )
    
    contrast_ratio = safe_ratio(
        class_results['NORMAL']['contrast_factor'],
        class_results['PNEUMONIA']['contrast_factor']
    )
    
    offset_x_ratio = safe_ratio(
        class_results['NORMAL']['offset_x_std'],
        class_results['PNEUMONIA']['offset_x_std']
    )
    
    offset_y_ratio = safe_ratio(
        class_results['NORMAL']['offset_y_std'],
        class_results['PNEUMONIA']['offset_y_std']
    )
    
    zoom_ratio = safe_ratio(
        class_results['NORMAL']['zoom_factor'],
        class_results['PNEUMONIA']['zoom_factor']
    )
    
    print(f"Brightness variation ratio: {brightness_ratio:.2f}x")
    print(f"Contrast variation ratio: {contrast_ratio:.2f}x")
    print(f"Horizontal centering ratio: {offset_x_ratio:.2f}x")
    print(f"Vertical centering ratio: {offset_y_ratio:.2f}x")
    print(f"Zoom/framing ratio: {zoom_ratio:.2f}x")
    
    # 4. ENHANCED REGULARIZATION: Boost augmentation where classes differ
    print("\n" + "=" * 70)
    print("REGULARIZATION STRATEGY: Artifact-Aware Augmentation")
    print("=" * 70)
    
    # BRIGHTNESS: If classes differ significantly, boost augmentation
    base_brightness = max(
        class_results['NORMAL']['brightness_factor'], 
        class_results['PNEUMONIA']['brightness_factor']
    )
    
    if brightness_ratio > 1.5:
        CALCULATED_BRIGHTNESS_FACTOR = min(0.3, base_brightness * 1.2)
        print(f"⚠️  Brightness: {brightness_ratio:.1f}x class difference detected")
        print(f"   → Boosting from {base_brightness:.3f} to {CALCULATED_BRIGHTNESS_FACTOR:.3f} (20% increase)")
    else:
        CALCULATED_BRIGHTNESS_FACTOR = base_brightness
        print(f"✅ Brightness: No significant class difference ({brightness_ratio:.1f}x)")
        print(f"   → Using base value: {CALCULATED_BRIGHTNESS_FACTOR:.3f}")
    
    # CONTRAST: If classes differ significantly, boost augmentation
    base_contrast = max(
        class_results['NORMAL']['contrast_factor'], 
        class_results['PNEUMONIA']['contrast_factor']
    )
    
    if contrast_ratio > 1.5:
        CALCULATED_CONTRAST_FACTOR = min(0.3, base_contrast * 1.2)
        print(f"⚠️  Contrast: {contrast_ratio:.1f}x class difference detected")
        print(f"   → Boosting from {base_contrast:.3f} to {CALCULATED_CONTRAST_FACTOR:.3f} (20% increase)")
    else:
        CALCULATED_CONTRAST_FACTOR = base_contrast
        print(f"✅ Contrast: No significant class difference ({contrast_ratio:.1f}x)")
        print(f"   → Using base value: {CALCULATED_CONTRAST_FACTOR:.3f}")
    
    # TRANSLATION: If centering differs significantly, force stronger augmentation
    base_offset_x = max(
        class_results['NORMAL']['offset_x_std'],
        class_results['PNEUMONIA']['offset_x_std']
    )
    base_offset_y = max(
        class_results['NORMAL']['offset_y_std'],
        class_results['PNEUMONIA']['offset_y_std']
    )
    base_translation = max(base_offset_x, base_offset_y)
    
    if offset_x_ratio > 2.0:
        CALCULATED_WIDTH_FACTOR = max(base_translation, 0.05)
        print(f"⚠️  Horizontal centering: {offset_x_ratio:.1f}x class difference detected")
        print(f"   → Forcing minimum 5% translation (was {base_translation:.3f})")
        print(f"   → This destroys spurious centering correlation")
    elif offset_x_ratio > 1.5:
        CALCULATED_WIDTH_FACTOR = max(base_translation, 0.03)
        print(f"⚠️  Horizontal centering: {offset_x_ratio:.1f}x class difference detected")
        print(f"   → Boosting to minimum 3% translation (was {base_translation:.3f})")
    else:
        CALCULATED_WIDTH_FACTOR = base_translation
        print(f"✅ Horizontal centering: No significant class difference ({offset_x_ratio:.1f}x)")
        print(f"   → Using base value: {CALCULATED_WIDTH_FACTOR:.3f}")
    
    # ZOOM: If framing differs significantly, boost augmentation
    base_zoom = max(
        class_results['NORMAL']['zoom_factor'],
        class_results['PNEUMONIA']['zoom_factor']
    )
    
    if zoom_ratio > 1.5:
        CALCULATED_ZOOM_FACTOR = min(0.15, base_zoom * 1.3)
        print(f"⚠️  Zoom/framing: {zoom_ratio:.1f}x class difference detected")
        print(f"   → Boosting from {base_zoom:.3f} to {CALCULATED_ZOOM_FACTOR:.3f} (30% increase)")
    else:
        CALCULATED_ZOOM_FACTOR = base_zoom
        print(f"✅ Zoom/framing: No significant class difference ({zoom_ratio:.1f}x)")
        print(f"   → Using base value: {CALCULATED_ZOOM_FACTOR:.3f}")
    
    # NOISE: Use conservative approach (cap at 5%)
    CALCULATED_GAUSSIAN_STDDEV = max(
        class_results['NORMAL']['gaussian_stddev'], 
        class_results['PNEUMONIA']['gaussian_stddev']
    )
    
    if CALCULATED_GAUSSIAN_STDDEV > 0:
        print(f"⚠️  Noise: Detected sensor noise variation")
        print(f"   → Adding conservative {CALCULATED_GAUSSIAN_STDDEV:.3f} Gaussian noise")
    else:
        print(f"✅ Noise: No significant noise variation detected")
        print(f"   → No noise augmentation needed")

    # 5. CALCULATE CLASS WEIGHTS FOR IMBALANCE HANDLING
    normal_count = class_results['NORMAL']['count']
    pneumonia_count = class_results['PNEUMONIA']['count']
    imbalance_ratio = pneumonia_count / normal_count
    
    # Store the required counts
    NORMAL_COUNT = normal_count
    PNEUMONIA_COUNT = pneumonia_count
    
    print("\n" + "=" * 70)
    print("FINAL TRAINING VARIABLES INITIALIZED:")
    print("=" * 70)
    
    print(f"\nAUGMENTATION PARAMETERS:")
    print(f"CALCULATED_ROTATION_FACTOR     = {CALCULATED_ROTATION_FACTOR:.4f} (10°)")
    print(f"CALCULATED_WIDTH_FACTOR        = {CALCULATED_WIDTH_FACTOR:.4f}")
    print(f"CALCULATED_ZOOM_FACTOR         = {CALCULATED_ZOOM_FACTOR:.4f}")
    print(f"CALCULATED_BRIGHTNESS_FACTOR   = {CALCULATED_BRIGHTNESS_FACTOR:.4f}")
    print(f"CALCULATED_CONTRAST_FACTOR     = {CALCULATED_CONTRAST_FACTOR:.4f}")
    print(f"CALCULATED_GAUSSIAN_STDDEV     = {CALCULATED_GAUSSIAN_STDDEV:.4f}")
    print(f"CALCULATED_FLIP_MODE           = '{CALCULATED_FLIP_MODE}'")
    
    print(f"\nCLASS BALANCE:")
    print(f"NORMAL_COUNT    = {NORMAL_COUNT}")
    print(f"PNEUMONIA_COUNT = {PNEUMONIA_COUNT}")
    print(f"Imbalance Ratio = {imbalance_ratio:.2f}:1 (PNEUMONIA:NORMAL)")

# %%
"""
CALCULATED_ROTATION_FACTOR = 10 / 360
CALCULATED_CONTRAST_FACTOR = 0.08
CALCULATED_GAUSSIAN_STDDEV = 0.001
CALCULATED_FLIP_MODE = 'horizontal'
CALCULATED_BRIGHTNESS_FACTOR = 0.20
CALCULATED_WIDTH_FACTOR = 0.02
CALCULATED_ZOOM_FACTOR = 0.01
"""

"""
# Conservative Geometric Transformations (Less aggressive)
CALCULATED_ROTATION_FACTOR = 5 / 360  # Approx 0.0138
CALCULATED_WIDTH_FACTOR = 0.02
CALCULATED_ZOOM_FACTOR = 0.01
CALCULATED_FLIP_MODE = 'horizontal'

# Conservative Photometric Transformations (Minimal disturbance)
CALCULATED_BRIGHTNESS_FACTOR = 0.05 # Reduced from 0.20
CALCULATED_CONTRAST_FACTOR = 0.04  # Reduced from 0.08
CALCULATED_GAUSSIAN_STDDEV = 0.0005 # Reduced from 0.001


# Use the variables initialized in DATA-DRIVEN AUGMENTATION PARAMETER ANALYSIS
unified_augmentation_pipeline = Sequential([
    RandomRotation(factor=CALCULATED_ROTATION_FACTOR),
    RandomTranslation(
        # Using same factor for both (aggregated from max of all offsets)
        height_factor=CALCULATED_WIDTH_FACTOR,
        width_factor=CALCULATED_WIDTH_FACTOR,
        fill_mode='constant',
        fill_value=0.0
    ),
    RandomZoom(height_factor=CALCULATED_ZOOM_FACTOR),
    RandomFlip(mode=CALCULATED_FLIP_MODE),
    RandomBrightness(factor=CALCULATED_BRIGHTNESS_FACTOR, value_range=(0, 1)),
    RandomContrast(factor=CALCULATED_CONTRAST_FACTOR, value_range=(0, 1)),
    GaussianNoise(stddev=CALCULATED_GAUSSIAN_STDDEV)
])
"""

# --- CONSERVATIVE AUGMENTATION PIPELINE ---
# Goal: Geometric invariance without destroying grayscale diagnostic features

unified_augmentation_pipeline = Sequential([
    # Slight rotation (+/- 5 degrees)
    RandomRotation(factor=5/360), 
    
    # Slight shift (2%)
    RandomTranslation(height_factor=0.02, width_factor=0.02),
    
    # Slight zoom (Keep lungs in frame)
    RandomZoom(height_factor=0.02),
    
    # Standard horizontal flip
    RandomFlip(mode='horizontal'),
    
    # DISABLED: RandomBrightness, RandomContrast, GaussianNoise
    # We remove these to preserve the original Hounsfield-like intensity relationships
])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764376920.160466 1658967 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21456 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ## 3.3 Model-Specific Preprocessing Pipelines
#
# Each model architecture employs a defined preprocessing pipeline, including resizing, channel arrangement, and normalization.
# Augmentation is applied before model-specific normalization to avoid altering standardized distributions.
# Pipelines for convolutional networks replicate grayscale images into three channels and apply ImageNet normalization when pretrained backbones are used.
# Transformers follow similar pipelines with model-appropriate input resolutions.
# All steps are implemented within tf.data for efficiency and consistency.

# %%
# Define global constants consistent with each model expected input
IMG_SIZE = 256
BATCH_SIZE = 8
LEARNING_RATE = 1e-6
WEIGHT_DECAY = 1e-6
USE_AUGMENTATION = False

# %%
def load_and_preprocess_image(filepath, label):
    """Loads image, resizes, converts to grayscale, and normalizes."""
    # Load image file
    img = tf.io.read_file(filepath)
    
    # Decode to tensor (3 channels is a safe default for decoding)
    img = tf.image.decode_jpeg(img, channels=3)
    
    # Resize image to model input size
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    
    # Convert to grayscale (1 channel)
    img = tf.image.rgb_to_grayscale(img)
    
    # Normalize to [0, 1] range (CRITICAL for RandomBrightness/Contrast layers)
    img = img / 255.0
    
    # Convert label to float if using binary_crossentropy/sigmoid output
    label = tf.cast(label == 'PNEUMONIA', tf.float32)
    
    return img, label

# %%
# Training Dataset (augmentated)
TRAIN_DS = tf.data.Dataset.from_tensor_slices((X_train, y_train))
TRAIN_DS = TRAIN_DS.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# 2. Conditionally Apply Data Augmentation
if USE_AUGMENTATION:
    print("Training dataset is being augmented.")
    TRAIN_DS = TRAIN_DS.map(
        lambda x, y: (unified_augmentation_pipeline(x), y), 
        num_parallel_calls=tf.data.AUTOTUNE
    )
else:
    print("Training dataset is NOT being augmented.")

# Optimization chain (batching and prefetching)
TRAIN_DS = (
    TRAIN_DS
    .cache()         
    .shuffle(len(X_train)) 
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE) 
)

# Validation dataset (not augmentated)
VAL_DS = tf.data.Dataset.from_tensor_slices((X_val, y_val))
VAL_DS = VAL_DS.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# Optimization chain
VAL_DS = (
    VAL_DS
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# Test dataset (not augmentated)
TEST_DS = tf.data.Dataset.from_tensor_slices((X_test, y_test))
TEST_DS = TEST_DS.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# Optimization chain
TEST_DS = (
    TEST_DS
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# Training dataset is NOT being augmented.

# %% [markdown]
# ## 3.4 Dataset Pipeline Validation

# %%
print("\n" + "=" * 70)
print("DATASET PIPELINE VALIDATION")
print("=" * 70)

# Check Training Dataset
for images, labels in TRAIN_DS.take(1): # type: ignore
    print("\n--- Training Dataset (TRAIN_DS) ---")
    print(f"Batch Shape: {images.shape} (Expected: [{BATCH_SIZE}, {IMG_SIZE}, {IMG_SIZE}, 1])")
    print(f"Labels Shape: {labels.shape} (Expected: [{BATCH_SIZE},])")
    print(f"Pixel Range: [{tf.reduce_min(images):.3f}, {tf.reduce_max(images):.3f}] (Should be close to [0.0, 1.0])")
    print(f"Labels (First 5): {labels.numpy()[:5]}")
    break

# Check Validation Dataset
for images, labels in VAL_DS.take(1): # type: ignore
    print("\n--- Validation Dataset (VAL_DS) ---")
    print(f"Batch Shape: {images.shape} (Expected: [{BATCH_SIZE}, {IMG_SIZE}, {IMG_SIZE}, 1])")
    print(f"Labels Shape: {labels.shape} (Expected: [{BATCH_SIZE},])")
    print(f"Pixel Range: [{tf.reduce_min(images):.3f}, {tf.reduce_max(images):.3f}] (Should be [0.0, 1.0])")
    print(f"Labels (First 5): {labels.numpy()[:5]}")
    break

# Check Test Dataset
for images, labels in TEST_DS.take(1): # type: ignore
    print("\n--- Test Dataset (TEST_DS) ---")
    print(f"Batch Shape: {images.shape} (Expected: [{BATCH_SIZE}, {IMG_SIZE}, {IMG_SIZE}, 1])")
    print(f"Labels Shape: {labels.shape} (Expected: [{BATCH_SIZE},])")
    print(f"Pixel Range: [{tf.reduce_min(images):.3f}, {tf.reduce_max(images):.3f}] (Should be [0.0, 1.0])")
    print(f"Labels (First 5): {labels.numpy()[:5]}")
    break
# Out:
# ======================================================================
# DATASET PIPELINE VALIDATION
# ======================================================================
#
# --- Training Dataset (TRAIN_DS) ---
# Batch Shape: (8, 256, 256, 1) (Expected: [8, 256, 256, 1])
# Labels Shape: (8,) (Expected: [8,])
# Pixel Range: [0.000, 1.000] (Should be close to [0.0, 1.0])
# Labels (First 5): [1. 1. 1. 1. 0.]
#
# --- Validation Dataset (VAL_DS) ---
# Batch Shape: (8, 256, 256, 1) (Expected: [8, 256, 256, 1])
# Labels Shape: (8,) (Expected: [8,])
# Pixel Range: [0.000, 1.000] (Should be [0.0, 1.0])
# Labels (First 5): [1. 1. 0. 1. 1.]
#
# --- Test Dataset (TEST_DS) ---
# Batch Shape: (8, 256, 256, 1) (Expected: [8, 256, 256, 1])
# Labels Shape: (8,) (Expected: [8,])
# Pixel Range: [0.000, 1.000] (Should be [0.0, 1.0])
# Labels (First 5): [0. 0. 0. 0. 0.]
# 2025-11-29 00:42:03.286189: W tensorflow/core/kernels/data/cache_dataset_ops.cc:917] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-11-29 00:42:03.324885: W tensorflow/core/kernels/data/cache_dataset_ops.cc:917] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# &#160;

# %% [markdown]
# # 4. Modeling
#
# ---

# %% [markdown]
# ## 4.1 Model Checkpoint Saving
#
# We set up a callback to save the best model during training based on validation PR-AUC rather than raw accuracy. This is more appropriate for an imbalanced, clinically oriented problem where the balance between precision and recall is more important than overall accuracy.
#
# The ModelCheckpoint callback:
#
# * Saves the model to the file path defined by `CHECKPOINT_PATH`.
# * Monitors the `val_pr_auc` metric on the validation set.
# * Keeps only the model corresponding to the highest observed `val_pr_auc` during training.
#
# By saving the best validation-PR-AUC checkpoint instead of simply using the weights from the final epoch, we reduce the risk of overfitting. If performance on the validation set starts to degrade after a certain point, we still retain the version of the model that showed the best generalization according to the chosen metric.

# %%
# Model checkpoint saving
best_model_callback = ModelCheckpoint(
    filepath=CHECKPOINT_PATH,
    monitor="val_pr_auc",
    mode="max",
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

# %% [markdown]
# ## 4.2 Early Stopping
#
# We also use an EarlyStopping callback to automatically stop training when further epochs no longer improve the model’s performance on the validation set.
#
# In this project:
#
# * EarlyStopping monitors the validation PR-AUC (`val_pr_auc`), not the training metrics.
# * If `val_pr_auc` does not improve for a specified number of epochs (the patience value), training is stopped.
# * With `restore_best_weights=True`, the model weights are rolled back to those from the epoch with the highest `val_pr_auc`.
#
# This prevents wasting epochs once the model has effectively converged and reduces overfitting by avoiding continued training after validation performance has stopped improving, while still keeping the best-performing version of the model for subsequent evaluation.

# %%
# Early stopping
early_stopping = EarlyStopping(
    monitor="val_loss",
    mode="min",
    # Generous patience because training with AdamW and LR scheduling can be slow
    patience=20,
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# ## 4.3 Learning Rate
#
# The learning rate is a key hyperparameter that controls how much the model weights are updated during training. If it is too high, the optimizer may overshoot good minima and converge to a suboptimal solution; if it is too low, training can become very slow or get stuck.
#
# In this project, we use the AdamW optimizer with an initial learning rate defined by `LEARNING_RATE`, together with a learning rate scheduler based on the `ReduceLROnPlateau` callback. The scheduler:
#
# * Monitors the validation loss (`val_loss`).
# * If `val_loss` does not improve for a certain number of epochs (patience), it reduces the learning rate by a given factor.
# * Ensures that the learning rate never goes below a specified minimum (`min_lr`).
#
# This strategy allows the model to make relatively large updates in the early stages of training, then gradually switch to smaller, finer updates once progress slows. In practice, this helps the model converge more reliably and can improve final validation performance without manual tuning of the learning rate schedule.

# %%
# Learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    mode="min",
    factor=0.5,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

# %% [markdown]
# ## 4.4 Build

# %%
# EfficientNetV2-B0 Model Definition

# Input Layer (256×256×1 grayscale)
input_tensor = Input(shape=(256, 256, 1))

# Grayscale to RGB (without using a lambda)
x = Concatenate(axis=-1)([input_tensor, input_tensor, input_tensor])

# Load EfficientNetV2-B0 backbone
base_model = EfficientNetV2B0(
    include_top=False,
    weights="imagenet",
    input_tensor=x
)

# 4. Freeze backbone
base_model.trainable = False

# 5. Classification Head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(
    128,
    activation="relu",
    kernel_regularizer=regularizers.l2(1e-4)
)(x)
x = Dropout(0.4)(x)
output = Dense(1, activation="sigmoid")(x)

# 6. Assemble model
model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256, 256,  │          0 │ input_layer[0][0… │
# │ (Concatenate)       │ 3)                │            │ input_layer[0][0… │
# │                     │                   │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ concatenate[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 256, 256,  │          0 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 128, 128,  │        864 │ normalization[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 128, 128,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 128, 128,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 128, 128,  │      4,608 │ stem_activation[… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 128, 128,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_ac… │ (None, 128, 128,  │          0 │ block1a_project_… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 64, 64,    │      9,216 │ block1a_project_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 64, 64,    │        256 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 64, 64,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 64, 64,    │      2,048 │ block2a_expand_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 64, 64,    │        128 │ block2a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 64, 64,    │     36,864 │ block2a_project_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 64, 64,    │        512 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 64, 64,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 64, 64,    │      4,096 │ block2b_expand_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 64, 64,    │        128 │ block2b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 64, 64,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 64, 64,    │          0 │ block2b_drop[0][… │
# │                     │ 32)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 32, 32,    │     36,864 │ block2b_add[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 32, 32,    │        512 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 32, 32,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 32, 32,    │      6,144 │ block3a_expand_a… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 32, 32,    │        192 │ block3a_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 32, 32,    │     82,944 │ block3a_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 32, 32,    │        768 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 32, 32,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 32, 32,    │      9,216 │ block3b_expand_a… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 32, 32,    │        192 │ block3b_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 32, 32,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 32, 32,    │          0 │ block3b_drop[0][… │
# │                     │ 48)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 32, 32,    │      9,216 │ block3b_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 32, 32,    │        768 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 32, 32,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv2     │ (None, 16, 16,    │      1,728 │ block4a_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 16, 16,    │        768 │ block4a_dwconv2[… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 16, 16,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 192)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 192) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 12)  │      2,316 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 192) │      2,496 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 16, 16,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 192)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 16, 16,    │     18,432 │ block4a_se_excit… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 16, 16,    │        384 │ block4a_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 16, 16,    │     36,864 │ block4a_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 16, 16,    │      1,536 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 16, 16,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv2     │ (None, 16, 16,    │      3,456 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 16, 16,    │      1,536 │ block4b_dwconv2[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 16, 16,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 384)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 384) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 24)  │      9,240 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 384) │      9,600 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 16, 16,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 384)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 16, 16,    │     36,864 │ block4b_se_excit… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 16, 16,    │        384 │ block4b_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 16, 16,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 16, 16,    │          0 │ block4b_drop[0][… │
# │                     │ 96)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 16, 16,    │     36,864 │ block4b_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 16, 16,    │      1,536 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 16, 16,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv2     │ (None, 16, 16,    │      3,456 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 16, 16,    │      1,536 │ block4c_dwconv2[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 16, 16,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 384)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 384) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 24)  │      9,240 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 384) │      9,600 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 16, 16,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 384)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 16, 16,    │     36,864 │ block4c_se_excit… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 16, 16,    │        384 │ block4c_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 16, 16,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 16, 16,    │          0 │ block4c_drop[0][… │
# │                     │ 96)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 16, 16,    │     55,296 │ block4c_add[0][0] │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 16, 16,    │      2,304 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 16, 16,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv2     │ (None, 16, 16,    │      5,184 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 16, 16,    │      2,304 │ block5a_dwconv2[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 16, 16,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 576)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 576) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 576) │     14,400 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 16, 16,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 576)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 16, 16,    │     64,512 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 16, 16,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 16, 16,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 16, 16,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 16, 16,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv2     │ (None, 16, 16,    │      6,048 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 16, 16,    │      2,688 │ block5b_dwconv2[… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 16, 16,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 16, 16,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 16, 16,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 16, 16,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 16, 16,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 16, 16,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 16, 16,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 16, 16,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 16, 16,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv2     │ (None, 16, 16,    │      6,048 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 16, 16,    │      2,688 │ block5c_dwconv2[… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 16, 16,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 16, 16,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 16, 16,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 16, 16,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 16, 16,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 16, 16,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_conv │ (None, 16, 16,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_bn   │ (None, 16, 16,    │      2,688 │ block5d_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_act… │ (None, 16, 16,    │          0 │ block5d_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_dwconv2     │ (None, 16, 16,    │      6,048 │ block5d_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_bn          │ (None, 16, 16,    │      2,688 │ block5d_dwconv2[… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_activation  │ (None, 16, 16,    │          0 │ block5d_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_squeeze  │ (None, 672)       │          0 │ block5d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_reshape  │ (None, 1, 1, 672) │          0 │ block5d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_excite   │ (None, 16, 16,    │          0 │ block5d_activati… │
# │ (Multiply)          │ 672)              │            │ block5d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_project_co… │ (None, 16, 16,    │     75,264 │ block5d_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_project_bn  │ (None, 16, 16,    │        448 │ block5d_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_drop        │ (None, 16, 16,    │          0 │ block5d_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_add (Add)   │ (None, 16, 16,    │          0 │ block5d_drop[0][… │
# │                     │ 112)              │            │ block5c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_conv │ (None, 16, 16,    │     75,264 │ block5d_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_bn   │ (None, 16, 16,    │      2,688 │ block5e_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_act… │ (None, 16, 16,    │          0 │ block5e_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_dwconv2     │ (None, 16, 16,    │      6,048 │ block5e_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_bn          │ (None, 16, 16,    │      2,688 │ block5e_dwconv2[… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_activation  │ (None, 16, 16,    │          0 │ block5e_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_squeeze  │ (None, 672)       │          0 │ block5e_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_reshape  │ (None, 1, 1, 672) │          0 │ block5e_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5e_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5e_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_excite   │ (None, 16, 16,    │          0 │ block5e_activati… │
# │ (Multiply)          │ 672)              │            │ block5e_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_project_co… │ (None, 16, 16,    │     75,264 │ block5e_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_project_bn  │ (None, 16, 16,    │        448 │ block5e_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_drop        │ (None, 16, 16,    │          0 │ block5e_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_add (Add)   │ (None, 16, 16,    │          0 │ block5e_drop[0][… │
# │                     │ 112)              │            │ block5d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 16, 16,    │     75,264 │ block5e_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 16, 16,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 16, 16,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv2     │ (None, 8, 8, 672) │      6,048 │ block6a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 8, 8, 672) │      2,688 │ block6a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 8, 8, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 8, 8, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 8, 8, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 8, 8, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 8, 8,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 8, 8,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 8, 8,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv2     │ (None, 8, 8,      │     10,368 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 8, 8,      │      4,608 │ block6b_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 8, 8,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 8, 8,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 8, 8, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 8, 8, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 8, 8, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 8, 8, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 8, 8,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 8, 8,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 8, 8,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv2     │ (None, 8, 8,      │     10,368 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 8, 8,      │      4,608 │ block6c_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 8, 8,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 8, 8,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 8, 8, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 8, 8, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 8, 8, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 8, 8, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 8, 8,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 8, 8,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 8, 8,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv2     │ (None, 8, 8,      │     10,368 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 8, 8,      │      4,608 │ block6d_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 8, 8,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 8, 8,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 8, 8, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 8, 8, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 8, 8, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 8, 8, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_expand_conv │ (None, 8, 8,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_expand_bn   │ (None, 8, 8,      │      4,608 │ block6e_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_expand_act… │ (None, 8, 8,      │          0 │ block6e_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_dwconv2     │ (None, 8, 8,      │     10,368 │ block6e_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_bn          │ (None, 8, 8,      │      4,608 │ block6e_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_activation  │ (None, 8, 8,      │          0 │ block6e_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_se_squeeze  │ (None, 1152)      │          0 │ block6e_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_se_reshape  │ (None, 1, 1,      │          0 │ block6e_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6e_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_se_expand   │ (None, 1, 1,      │     56,448 │ block6e_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_se_excite   │ (None, 8, 8,      │          0 │ block6e_activati… │
# │ (Multiply)          │ 1152)             │            │ block6e_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_project_co… │ (None, 8, 8, 192) │    221,184 │ block6e_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_project_bn  │ (None, 8, 8, 192) │        768 │ block6e_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_drop        │ (None, 8, 8, 192) │          0 │ block6e_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6e_add (Add)   │ (None, 8, 8, 192) │          0 │ block6e_drop[0][… │
# │                     │                   │            │ block6d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_expand_conv │ (None, 8, 8,      │    221,184 │ block6e_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_expand_bn   │ (None, 8, 8,      │      4,608 │ block6f_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_expand_act… │ (None, 8, 8,      │          0 │ block6f_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_dwconv2     │ (None, 8, 8,      │     10,368 │ block6f_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_bn          │ (None, 8, 8,      │      4,608 │ block6f_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_activation  │ (None, 8, 8,      │          0 │ block6f_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_squeeze  │ (None, 1152)      │          0 │ block6f_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_reshape  │ (None, 1, 1,      │          0 │ block6f_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6f_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_expand   │ (None, 1, 1,      │     56,448 │ block6f_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_excite   │ (None, 8, 8,      │          0 │ block6f_activati… │
# │ (Multiply)          │ 1152)             │            │ block6f_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_project_co… │ (None, 8, 8, 192) │    221,184 │ block6f_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_project_bn  │ (None, 8, 8, 192) │        768 │ block6f_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_drop        │ (None, 8, 8, 192) │          0 │ block6f_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_add (Add)   │ (None, 8, 8, 192) │          0 │ block6f_drop[0][… │
# │                     │                   │            │ block6e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_conv │ (None, 8, 8,      │    221,184 │ block6f_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_bn   │ (None, 8, 8,      │      4,608 │ block6g_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_act… │ (None, 8, 8,      │          0 │ block6g_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_dwconv2     │ (None, 8, 8,      │     10,368 │ block6g_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_bn          │ (None, 8, 8,      │      4,608 │ block6g_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_activation  │ (None, 8, 8,      │          0 │ block6g_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_squeeze  │ (None, 1152)      │          0 │ block6g_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_reshape  │ (None, 1, 1,      │          0 │ block6g_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6g_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_expand   │ (None, 1, 1,      │     56,448 │ block6g_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_excite   │ (None, 8, 8,      │          0 │ block6g_activati… │
# │ (Multiply)          │ 1152)             │            │ block6g_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_project_co… │ (None, 8, 8, 192) │    221,184 │ block6g_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_project_bn  │ (None, 8, 8, 192) │        768 │ block6g_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_drop        │ (None, 8, 8, 192) │          0 │ block6g_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_add (Add)   │ (None, 8, 8, 192) │          0 │ block6g_drop[0][… │
# │                     │                   │            │ block6f_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_conv │ (None, 8, 8,      │    221,184 │ block6g_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_bn   │ (None, 8, 8,      │      4,608 │ block6h_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_act… │ (None, 8, 8,      │          0 │ block6h_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_dwconv2     │ (None, 8, 8,      │     10,368 │ block6h_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_bn          │ (None, 8, 8,      │      4,608 │ block6h_dwconv2[… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_activation  │ (None, 8, 8,      │          0 │ block6h_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_squeeze  │ (None, 1152)      │          0 │ block6h_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_reshape  │ (None, 1, 1,      │          0 │ block6h_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6h_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_expand   │ (None, 1, 1,      │     56,448 │ block6h_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_excite   │ (None, 8, 8,      │          0 │ block6h_activati… │
# │ (Multiply)          │ 1152)             │            │ block6h_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_project_co… │ (None, 8, 8, 192) │    221,184 │ block6h_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_project_bn  │ (None, 8, 8, 192) │        768 │ block6h_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_drop        │ (None, 8, 8, 192) │          0 │ block6h_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_add (Add)   │ (None, 8, 8, 192) │          0 │ block6h_drop[0][… │
# │                     │                   │            │ block6g_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 8, 8,      │    245,760 │ block6h_add[0][0] │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 8, 8,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 8, 8,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,083,409 (23.21 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 5,919,312 (22.58 MB)

# %% [markdown]
# ## 4.5 Two-Stage Training: Feature Extraction and Fine-Tuning

# %% [markdown]
# To leverage the power of pre-trained models like EfficientNet, we employ a **Two-Stage Transfer Learning** strategy. This approach maximizes performance while protecting the knowledge learned from the massive ImageNet dataset.
#
# 1.  **Stage 1: Feature Extraction (Base Frozen):** The pre-trained convolutional base (EfficientNet) is **frozen** to lock its weights. Only the newly added classification head is trained. This "warms up" the dense layers to interpret the base's features using a standard learning rate.
# 2.  **Stage 2: Fine-Tuning (Base Unfrozen):** After the head is stable, the entire model is **unfrozen**, but the learning rate is dramatically reduced ($\mathbf{10^{-5}}$). This allows the base model to slightly adapt its features specifically to the texture and anatomy of X-ray images, ensuring stable convergence and optimal results.

# %% [markdown]
# ### 4.5.1 Feature Extraction (Base Frozen)
#
# In this initial stage, the base model (`EfficientNetV2B0` or `ResNet50V2`) is set to **un-trainable**. We compile the model and train it for a small number of epochs (15 in this case) using a standard learning rate ($\mathbf{10^{-3}}$).
#
# The primary goal is to **train the new classification head** (GlobalAveragePooling + Dense layers) to correctly map the frozen features produced by the base to our specific binary labels (Normal/Pneumonia). This stabilizes the head before we attempt fine-tuning.

# %%
print("--- STAGE 1: Feature Extraction (Base Frozen) ---")

model.compile(
    optimizer=AdamW(learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY),   # type: ignore
    loss="binary_crossentropy",
    metrics=["accuracy", AUC(name="auc"), AUC(curve="PR", name="pr_auc"), Recall(name="recall")]
)

history_stage1 = model.fit(
    TRAIN_DS,
    validation_data=VAL_DS,
    epochs=100, # Shorter run
    callbacks=[best_model_callback, early_stopping], # Reuse callbacks
    # class_weight=class_weights_dict
)
# Out:
# --- STAGE 1: Feature Extraction (Base Frozen) ---
# Epoch 1/100
# 2025-11-29 00:42:08.450039: I external/local_xla/xla/service/service.cc:163] XLA service 0x749ca4014640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-29 00:42:08.450062: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-11-29 00:42:08.614957: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-29 00:42:09.535500: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-11-29 00:42:13.340187: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:13.476506: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:14.120474: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:14.291425: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1764376937.691869 1659074 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6843 - auc: 0.5251 - loss: 0.6576 - pr_auc: 0.7724 - recall: 0.8571
# 2025-11-29 00:42:25.726817: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:25.864045: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:26.007118: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:26.156106: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:26.297657: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:28.851640: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=0} for conv (f32[4,1152,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,8,8]{3,2,1,0}, f32[1152,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-11-29 00:42:28.869051: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:29.034597: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:29.191023: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:42:29.192566: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.510039324s
# Trying algorithm eng3{k11=0} for conv (f32[4,1152,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,8,8]{3,2,1,0}, f32[1152,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6844 - auc: 0.5250 - loss: 0.6575 - pr_auc: 0.7723 - recall: 0.8575
# Epoch 1: val_pr_auc improved from None to 0.74082, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.7079 - auc: 0.5047 - loss: 0.6441 - pr_auc: 0.7507 - recall: 0.9247 - val_accuracy: 0.7424 - val_auc: 0.4960 - val_loss: 0.6105 - val_pr_auc: 0.7408 - val_recall: 1.0000
# Epoch 2/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7355 - auc: 0.5085 - loss: 0.6164 - pr_auc: 0.7481 - recall: 0.9946
# Epoch 2: val_pr_auc improved from 0.74082 to 0.87466, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7398 - auc: 0.5048 - loss: 0.6107 - pr_auc: 0.7454 - recall: 0.9966 - val_accuracy: 0.7424 - val_auc: 0.7436 - val_loss: 0.5956 - val_pr_auc: 0.8747 - val_recall: 1.0000
# Epoch 3/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7363 - auc: 0.5013 - loss: 0.6083 - pr_auc: 0.7402 - recall: 0.9989
# Epoch 3: val_pr_auc did not improve from 0.87466
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7415 - auc: 0.4992 - loss: 0.6031 - pr_auc: 0.7427 - recall: 0.9989 - val_accuracy: 0.7424 - val_auc: 0.5000 - val_loss: 0.5928 - val_pr_auc: 0.7424 - val_recall: 1.0000
# Epoch 4/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7414 - auc: 0.5008 - loss: 0.6019 - pr_auc: 0.7441 - recall: 1.0000
# Epoch 4: val_pr_auc did not improve from 0.87466
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5020 - loss: 0.6011 - pr_auc: 0.7410 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6994 - val_loss: 0.5923 - val_pr_auc: 0.8365 - val_recall: 1.0000
# Epoch 5/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - auc: 0.4907 - loss: 0.5982 - pr_auc: 0.7382 - recall: 1.0000
# Epoch 5: val_pr_auc did not improve from 0.87466
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7424 - auc: 0.4817 - loss: 0.6033 - pr_auc: 0.7318 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.4987 - val_loss: 0.5922 - val_pr_auc: 0.7419 - val_recall: 1.0000
# Epoch 6/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7404 - auc: 0.5088 - loss: 0.6000 - pr_auc: 0.7494 - recall: 1.0000
# Epoch 6: val_pr_auc did not improve from 0.87466
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5168 - loss: 0.5975 - pr_auc: 0.7499 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.4961 - val_loss: 0.5919 - val_pr_auc: 0.7409 - val_recall: 1.0000
# Epoch 7/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7349 - auc: 0.4972 - loss: 0.6071 - pr_auc: 0.7383 - recall: 1.0000
# Epoch 7: val_pr_auc did not improve from 0.87466
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7421 - auc: 0.5045 - loss: 0.5986 - pr_auc: 0.7472 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6478 - val_loss: 0.5918 - val_pr_auc: 0.8666 - val_recall: 1.0000
# Epoch 8/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7431 - auc: 0.5013 - loss: 0.5982 - pr_auc: 0.7432 - recall: 1.0000
# Epoch 8: val_pr_auc improved from 0.87466 to 0.91334, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5121 - loss: 0.5971 - pr_auc: 0.7496 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7736 - val_loss: 0.5916 - val_pr_auc: 0.9133 - val_recall: 1.0000
# Epoch 9/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7347 - auc: 0.5125 - loss: 0.6041 - pr_auc: 0.7462 - recall: 1.0000
# Epoch 9: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5008 - loss: 0.5986 - pr_auc: 0.7480 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.5023 - val_loss: 0.5915 - val_pr_auc: 0.7432 - val_recall: 1.0000
# Epoch 10/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7449 - auc: 0.4867 - loss: 0.5987 - pr_auc: 0.7383 - recall: 1.0000
# Epoch 10: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.4985 - loss: 0.5998 - pr_auc: 0.7393 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7502 - val_loss: 0.5911 - val_pr_auc: 0.8699 - val_recall: 1.0000
# Epoch 11/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7512 - auc: 0.5165 - loss: 0.5870 - pr_auc: 0.7578 - recall: 1.0000
# Epoch 11: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5036 - loss: 0.5984 - pr_auc: 0.7455 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.5011 - val_loss: 0.5909 - val_pr_auc: 0.7495 - val_recall: 1.0000
# Epoch 12/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7314 - auc: 0.5068 - loss: 0.6094 - pr_auc: 0.7442 - recall: 1.0000
# Epoch 12: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5089 - loss: 0.5974 - pr_auc: 0.7468 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7212 - val_loss: 0.5908 - val_pr_auc: 0.9010 - val_recall: 1.0000
# Epoch 13/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - auc: 0.4917 - loss: 0.5958 - pr_auc: 0.7427 - recall: 1.0000
# Epoch 13: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.4952 - loss: 0.5995 - pr_auc: 0.7363 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7213 - val_loss: 0.5906 - val_pr_auc: 0.9012 - val_recall: 1.0000
# Epoch 14/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7395 - auc: 0.4830 - loss: 0.6041 - pr_auc: 0.7276 - recall: 1.0000
# Epoch 14: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.4906 - loss: 0.5996 - pr_auc: 0.7352 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6414 - val_loss: 0.5904 - val_pr_auc: 0.8644 - val_recall: 1.0000
# Epoch 15/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7382 - auc: 0.5209 - loss: 0.5989 - pr_auc: 0.7521 - recall: 1.0000
# Epoch 15: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5069 - loss: 0.5969 - pr_auc: 0.7456 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7849 - val_loss: 0.5903 - val_pr_auc: 0.9004 - val_recall: 1.0000
# Epoch 16/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7454 - auc: 0.5152 - loss: 0.5920 - pr_auc: 0.7492 - recall: 1.0000
# Epoch 16: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5094 - loss: 0.5958 - pr_auc: 0.7459 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6889 - val_loss: 0.5901 - val_pr_auc: 0.8884 - val_recall: 1.0000
# Epoch 17/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7335 - auc: 0.5084 - loss: 0.6053 - pr_auc: 0.7389 - recall: 1.0000
# Epoch 17: val_pr_auc did not improve from 0.91334
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7421 - auc: 0.5013 - loss: 0.5975 - pr_auc: 0.7417 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7923 - val_loss: 0.5900 - val_pr_auc: 0.9055 - val_recall: 1.0000
# Epoch 18/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7514 - auc: 0.5215 - loss: 0.5830 - pr_auc: 0.7704 - recall: 1.0000
# Epoch 18: val_pr_auc improved from 0.91334 to 0.91457, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5221 - loss: 0.5932 - pr_auc: 0.7581 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7937 - val_loss: 0.5898 - val_pr_auc: 0.9146 - val_recall: 1.0000
# Epoch 19/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7374 - auc: 0.5058 - loss: 0.6012 - pr_auc: 0.7411 - recall: 1.0000
# Epoch 19: val_pr_auc did not improve from 0.91457
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5188 - loss: 0.5939 - pr_auc: 0.7551 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7322 - val_loss: 0.5897 - val_pr_auc: 0.8586 - val_recall: 1.0000
# Epoch 20/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7506 - auc: 0.5226 - loss: 0.5843 - pr_auc: 0.7609 - recall: 1.0000
# Epoch 20: val_pr_auc improved from 0.91457 to 0.91672, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5215 - loss: 0.5936 - pr_auc: 0.7528 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7911 - val_loss: 0.5894 - val_pr_auc: 0.9167 - val_recall: 1.0000
# Epoch 21/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7432 - auc: 0.5051 - loss: 0.5951 - pr_auc: 0.7440 - recall: 1.0000
# Epoch 21: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5084 - loss: 0.5958 - pr_auc: 0.7455 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6069 - val_loss: 0.5893 - val_pr_auc: 0.7879 - val_recall: 1.0000
# Epoch 22/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7340 - auc: 0.5291 - loss: 0.6008 - pr_auc: 0.7561 - recall: 1.0000
# Epoch 22: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5178 - loss: 0.5936 - pr_auc: 0.7552 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.5693 - val_loss: 0.5892 - val_pr_auc: 0.8122 - val_recall: 1.0000
# Epoch 23/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7412 - auc: 0.5136 - loss: 0.5956 - pr_auc: 0.7525 - recall: 1.0000
# Epoch 23: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5217 - loss: 0.5931 - pr_auc: 0.7553 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6685 - val_loss: 0.5890 - val_pr_auc: 0.8190 - val_recall: 1.0000
# Epoch 24/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7325 - auc: 0.4913 - loss: 0.6069 - pr_auc: 0.7295 - recall: 1.0000
# Epoch 24: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5015 - loss: 0.5955 - pr_auc: 0.7443 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7333 - val_loss: 0.5888 - val_pr_auc: 0.8597 - val_recall: 1.0000
# Epoch 25/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7315 - auc: 0.4880 - loss: 0.6096 - pr_auc: 0.7226 - recall: 1.0000
# Epoch 25: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5018 - loss: 0.5955 - pr_auc: 0.7411 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6055 - val_loss: 0.5887 - val_pr_auc: 0.7980 - val_recall: 1.0000
# Epoch 26/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7414 - auc: 0.5337 - loss: 0.5920 - pr_auc: 0.7579 - recall: 1.0000
# Epoch 26: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5240 - loss: 0.5926 - pr_auc: 0.7535 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7179 - val_loss: 0.5885 - val_pr_auc: 0.8484 - val_recall: 1.0000
# Epoch 27/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7461 - auc: 0.4903 - loss: 0.5936 - pr_auc: 0.7395 - recall: 1.0000
# Epoch 27: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7421 - auc: 0.4941 - loss: 0.5967 - pr_auc: 0.7400 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7487 - val_loss: 0.5883 - val_pr_auc: 0.9071 - val_recall: 1.0000
# Epoch 28/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7337 - auc: 0.5218 - loss: 0.6007 - pr_auc: 0.7475 - recall: 1.0000
# Epoch 28: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5168 - loss: 0.5931 - pr_auc: 0.7539 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7125 - val_loss: 0.5883 - val_pr_auc: 0.8446 - val_recall: 1.0000
# Epoch 29/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7437 - auc: 0.5215 - loss: 0.5905 - pr_auc: 0.7637 - recall: 1.0000
# Epoch 29: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5208 - loss: 0.5924 - pr_auc: 0.7569 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6950 - val_loss: 0.5882 - val_pr_auc: 0.8343 - val_recall: 1.0000
# Epoch 30/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7385 - auc: 0.5199 - loss: 0.5966 - pr_auc: 0.7458 - recall: 1.0000
# Epoch 30: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5118 - loss: 0.5938 - pr_auc: 0.7450 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6228 - val_loss: 0.5881 - val_pr_auc: 0.8332 - val_recall: 1.0000
# Epoch 31/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7464 - auc: 0.5290 - loss: 0.5865 - pr_auc: 0.7617 - recall: 1.0000
# Epoch 31: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5205 - loss: 0.5921 - pr_auc: 0.7538 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6967 - val_loss: 0.5879 - val_pr_auc: 0.8356 - val_recall: 1.0000
# Epoch 32/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - auc: 0.5016 - loss: 0.5885 - pr_auc: 0.7522 - recall: 1.0000
# Epoch 32: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5005 - loss: 0.5945 - pr_auc: 0.7437 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7859 - val_loss: 0.5877 - val_pr_auc: 0.8981 - val_recall: 1.0000
# Epoch 33/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7410 - auc: 0.5113 - loss: 0.5945 - pr_auc: 0.7421 - recall: 1.0000
# Epoch 33: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5155 - loss: 0.5928 - pr_auc: 0.7453 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6957 - val_loss: 0.5876 - val_pr_auc: 0.8395 - val_recall: 1.0000
# Epoch 34/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7363 - auc: 0.5277 - loss: 0.5965 - pr_auc: 0.7532 - recall: 1.0000
# Epoch 34: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5153 - loss: 0.5920 - pr_auc: 0.7534 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7053 - val_loss: 0.5875 - val_pr_auc: 0.8462 - val_recall: 1.0000
# Epoch 35/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7371 - auc: 0.4903 - loss: 0.6006 - pr_auc: 0.7437 - recall: 1.0000
# Epoch 35: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5043 - loss: 0.5937 - pr_auc: 0.7525 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7414 - val_loss: 0.5874 - val_pr_auc: 0.8663 - val_recall: 1.0000
# Epoch 36/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7436 - auc: 0.5196 - loss: 0.5902 - pr_auc: 0.7517 - recall: 1.0000
# Epoch 36: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5082 - loss: 0.5933 - pr_auc: 0.7455 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7062 - val_loss: 0.5872 - val_pr_auc: 0.8513 - val_recall: 1.0000
# Epoch 37/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7518 - auc: 0.5263 - loss: 0.5803 - pr_auc: 0.7711 - recall: 1.0000
# Epoch 37: val_pr_auc did not improve from 0.91672
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7421 - auc: 0.5104 - loss: 0.5924 - pr_auc: 0.7513 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7390 - val_loss: 0.5872 - val_pr_auc: 0.9076 - val_recall: 1.0000
# Epoch 38/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - auc: 0.5258 - loss: 0.5871 - pr_auc: 0.7562 - recall: 1.0000
# Epoch 38: val_pr_auc improved from 0.91672 to 0.91958, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5241 - loss: 0.5911 - pr_auc: 0.7532 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7977 - val_loss: 0.5870 - val_pr_auc: 0.9196 - val_recall: 1.0000
# Epoch 39/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7354 - auc: 0.5021 - loss: 0.5998 - pr_auc: 0.7427 - recall: 1.0000
# Epoch 39: val_pr_auc did not improve from 0.91958
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5102 - loss: 0.5923 - pr_auc: 0.7489 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7907 - val_loss: 0.5869 - val_pr_auc: 0.9033 - val_recall: 1.0000
# Epoch 40/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7484 - auc: 0.5038 - loss: 0.5858 - pr_auc: 0.7576 - recall: 1.0000
# Epoch 40: val_pr_auc did not improve from 0.91958
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.4922 - loss: 0.5942 - pr_auc: 0.7414 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.6835 - val_loss: 0.5868 - val_pr_auc: 0.8749 - val_recall: 1.0000
# Epoch 41/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7463 - auc: 0.5187 - loss: 0.5867 - pr_auc: 0.7635 - recall: 1.0000
# Epoch 41: val_pr_auc did not improve from 0.91958
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5272 - loss: 0.5900 - pr_auc: 0.7597 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7435 - val_loss: 0.5867 - val_pr_auc: 0.9089 - val_recall: 1.0000
# Epoch 42/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7536 - auc: 0.5045 - loss: 0.5809 - pr_auc: 0.7582 - recall: 1.0000
# Epoch 42: val_pr_auc improved from 0.91958 to 0.92022, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.4991 - loss: 0.5936 - pr_auc: 0.7451 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7941 - val_loss: 0.5864 - val_pr_auc: 0.9202 - val_recall: 1.0000
# Epoch 43/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7360 - auc: 0.4843 - loss: 0.6027 - pr_auc: 0.7255 - recall: 1.0000
# Epoch 43: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5042 - loss: 0.5933 - pr_auc: 0.7430 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7209 - val_loss: 0.5865 - val_pr_auc: 0.8654 - val_recall: 1.0000
# Epoch 44/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7392 - auc: 0.4775 - loss: 0.5995 - pr_auc: 0.7242 - recall: 1.0000
# Epoch 44: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.4887 - loss: 0.5945 - pr_auc: 0.7386 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7358 - val_loss: 0.5864 - val_pr_auc: 0.8686 - val_recall: 1.0000
# Epoch 45/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7426 - auc: 0.5141 - loss: 0.5913 - pr_auc: 0.7508 - recall: 1.0000
# Epoch 45: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5282 - loss: 0.5895 - pr_auc: 0.7569 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7236 - val_loss: 0.5863 - val_pr_auc: 0.8686 - val_recall: 1.0000
# Epoch 46/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7375 - auc: 0.4762 - loss: 0.6010 - pr_auc: 0.7245 - recall: 1.0000
# Epoch 46: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.4966 - loss: 0.5933 - pr_auc: 0.7390 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7217 - val_loss: 0.5862 - val_pr_auc: 0.8830 - val_recall: 1.0000
# Epoch 47/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7305 - auc: 0.5075 - loss: 0.6038 - pr_auc: 0.7388 - recall: 1.0000
# Epoch 47: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7421 - auc: 0.5111 - loss: 0.5911 - pr_auc: 0.7497 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7362 - val_loss: 0.5862 - val_pr_auc: 0.9055 - val_recall: 1.0000
# Epoch 48/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7352 - auc: 0.5272 - loss: 0.5961 - pr_auc: 0.7520 - recall: 1.0000
# Epoch 48: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5158 - loss: 0.5907 - pr_auc: 0.7495 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7209 - val_loss: 0.5861 - val_pr_auc: 0.8940 - val_recall: 1.0000
# Epoch 49/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7479 - auc: 0.5231 - loss: 0.5837 - pr_auc: 0.7564 - recall: 1.0000
# Epoch 49: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5077 - loss: 0.5919 - pr_auc: 0.7455 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7304 - val_loss: 0.5859 - val_pr_auc: 0.8815 - val_recall: 1.0000
# Epoch 50/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7421 - auc: 0.5134 - loss: 0.5912 - pr_auc: 0.7490 - recall: 1.0000
# Epoch 50: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5182 - loss: 0.5906 - pr_auc: 0.7468 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7296 - val_loss: 0.5858 - val_pr_auc: 0.8813 - val_recall: 1.0000
# Epoch 51/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7446 - auc: 0.5062 - loss: 0.5891 - pr_auc: 0.7510 - recall: 1.0000
# Epoch 51: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5077 - loss: 0.5920 - pr_auc: 0.7475 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7394 - val_loss: 0.5857 - val_pr_auc: 0.8780 - val_recall: 1.0000
# Epoch 52/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7317 - auc: 0.5278 - loss: 0.6004 - pr_auc: 0.7475 - recall: 1.0000
# Epoch 52: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5314 - loss: 0.5892 - pr_auc: 0.7579 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7316 - val_loss: 0.5858 - val_pr_auc: 0.9023 - val_recall: 1.0000
# Epoch 53/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7414 - auc: 0.5295 - loss: 0.5899 - pr_auc: 0.7546 - recall: 1.0000
# Epoch 53: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5278 - loss: 0.5892 - pr_auc: 0.7559 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7406 - val_loss: 0.5856 - val_pr_auc: 0.8870 - val_recall: 1.0000
# Epoch 54/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7431 - auc: 0.5053 - loss: 0.5903 - pr_auc: 0.7530 - recall: 1.0000
# Epoch 54: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5148 - loss: 0.5903 - pr_auc: 0.7546 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7365 - val_loss: 0.5855 - val_pr_auc: 0.8875 - val_recall: 1.0000
# Epoch 55/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7541 - auc: 0.5143 - loss: 0.5781 - pr_auc: 0.7664 - recall: 1.0000
# Epoch 55: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5204 - loss: 0.5896 - pr_auc: 0.7574 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8016 - val_loss: 0.5852 - val_pr_auc: 0.9141 - val_recall: 1.0000
# Epoch 56/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7417 - auc: 0.5223 - loss: 0.5893 - pr_auc: 0.7598 - recall: 1.0000
# Epoch 56: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5149 - loss: 0.5900 - pr_auc: 0.7554 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7519 - val_loss: 0.5853 - val_pr_auc: 0.8872 - val_recall: 1.0000
# Epoch 57/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7380 - auc: 0.5124 - loss: 0.5954 - pr_auc: 0.7382 - recall: 1.0000
# Epoch 57: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5151 - loss: 0.5905 - pr_auc: 0.7456 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7507 - val_loss: 0.5851 - val_pr_auc: 0.8938 - val_recall: 1.0000
# Epoch 58/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7460 - auc: 0.5121 - loss: 0.5861 - pr_auc: 0.7578 - recall: 1.0000
# Epoch 58: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5190 - loss: 0.5898 - pr_auc: 0.7546 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7616 - val_loss: 0.5851 - val_pr_auc: 0.9120 - val_recall: 1.0000
# Epoch 59/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7521 - auc: 0.5249 - loss: 0.5783 - pr_auc: 0.7770 - recall: 1.0000
# Epoch 59: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5188 - loss: 0.5899 - pr_auc: 0.7533 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7557 - val_loss: 0.5850 - val_pr_auc: 0.8976 - val_recall: 1.0000
# Epoch 60/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7400 - auc: 0.5026 - loss: 0.5933 - pr_auc: 0.7477 - recall: 1.0000
# Epoch 60: val_pr_auc did not improve from 0.92022
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5172 - loss: 0.5896 - pr_auc: 0.7553 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7659 - val_loss: 0.5849 - val_pr_auc: 0.8979 - val_recall: 1.0000
# Epoch 61/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7546 - auc: 0.5159 - loss: 0.5766 - pr_auc: 0.7610 - recall: 1.0000
# Epoch 61: val_pr_auc improved from 0.92022 to 0.92663, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5149 - loss: 0.5901 - pr_auc: 0.7465 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8081 - val_loss: 0.5847 - val_pr_auc: 0.9266 - val_recall: 1.0000
# Epoch 62/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7437 - auc: 0.5330 - loss: 0.5870 - pr_auc: 0.7661 - recall: 1.0000
# Epoch 62: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7421 - auc: 0.5253 - loss: 0.5891 - pr_auc: 0.7615 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7618 - val_loss: 0.5847 - val_pr_auc: 0.9018 - val_recall: 1.0000
# Epoch 63/100
# 583/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7390 - auc: 0.5040 - loss: 0.5948 - pr_auc: 0.7350 - recall: 1.0000
# Epoch 63: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5107 - loss: 0.5906 - pr_auc: 0.7463 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7596 - val_loss: 0.5848 - val_pr_auc: 0.9086 - val_recall: 1.0000
# Epoch 64/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7292 - auc: 0.5567 - loss: 0.5974 - pr_auc: 0.7633 - recall: 1.0000
# Epoch 64: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5411 - loss: 0.5862 - pr_auc: 0.7673 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8150 - val_loss: 0.5848 - val_pr_auc: 0.9242 - val_recall: 1.0000
# Epoch 65/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7444 - auc: 0.5230 - loss: 0.5860 - pr_auc: 0.7645 - recall: 1.0000
# Epoch 65: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5281 - loss: 0.5879 - pr_auc: 0.7676 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7738 - val_loss: 0.5845 - val_pr_auc: 0.9163 - val_recall: 1.0000
# Epoch 66/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7376 - auc: 0.5502 - loss: 0.5910 - pr_auc: 0.7707 - recall: 1.0000
# Epoch 66: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5481 - loss: 0.5860 - pr_auc: 0.7725 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7705 - val_loss: 0.5845 - val_pr_auc: 0.9106 - val_recall: 1.0000
# Epoch 67/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7399 - auc: 0.5444 - loss: 0.5885 - pr_auc: 0.7665 - recall: 1.0000
# Epoch 67: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5368 - loss: 0.5871 - pr_auc: 0.7592 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7743 - val_loss: 0.5844 - val_pr_auc: 0.9184 - val_recall: 1.0000
# Epoch 68/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7441 - auc: 0.5173 - loss: 0.5868 - pr_auc: 0.7620 - recall: 1.0000
# Epoch 68: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5200 - loss: 0.5888 - pr_auc: 0.7581 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7729 - val_loss: 0.5843 - val_pr_auc: 0.9168 - val_recall: 1.0000
# Epoch 69/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7320 - auc: 0.5273 - loss: 0.5982 - pr_auc: 0.7588 - recall: 1.0000
# Epoch 69: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5246 - loss: 0.5880 - pr_auc: 0.7594 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7951 - val_loss: 0.5844 - val_pr_auc: 0.9230 - val_recall: 1.0000
# Epoch 70/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7442 - auc: 0.5220 - loss: 0.5864 - pr_auc: 0.7593 - recall: 1.0000
# Epoch 70: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5304 - loss: 0.5877 - pr_auc: 0.7629 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7791 - val_loss: 0.5842 - val_pr_auc: 0.9158 - val_recall: 1.0000
# Epoch 71/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7553 - auc: 0.5370 - loss: 0.5729 - pr_auc: 0.7790 - recall: 1.0000
# Epoch 71: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5201 - loss: 0.5887 - pr_auc: 0.7588 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8154 - val_loss: 0.5841 - val_pr_auc: 0.9253 - val_recall: 1.0000
# Epoch 72/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7324 - auc: 0.5149 - loss: 0.5988 - pr_auc: 0.7473 - recall: 1.0000
# Epoch 72: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7421 - auc: 0.5291 - loss: 0.5872 - pr_auc: 0.7625 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7770 - val_loss: 0.5841 - val_pr_auc: 0.9177 - val_recall: 1.0000
# Epoch 73/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7486 - auc: 0.5172 - loss: 0.5829 - pr_auc: 0.7517 - recall: 1.0000
# Epoch 73: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5266 - loss: 0.5884 - pr_auc: 0.7543 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7831 - val_loss: 0.5840 - val_pr_auc: 0.9176 - val_recall: 1.0000
# Epoch 74/100
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7506 - auc: 0.5193 - loss: 0.5794 - pr_auc: 0.7594 - recall: 1.0000
# Epoch 74: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5199 - loss: 0.5889 - pr_auc: 0.7497 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8065 - val_loss: 0.5838 - val_pr_auc: 0.9253 - val_recall: 1.0000
# Epoch 75/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7457 - auc: 0.5584 - loss: 0.5801 - pr_auc: 0.7814 - recall: 1.0000
# Epoch 75: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5485 - loss: 0.5851 - pr_auc: 0.7731 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7759 - val_loss: 0.5838 - val_pr_auc: 0.9100 - val_recall: 1.0000
# Epoch 76/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7389 - auc: 0.5076 - loss: 0.5934 - pr_auc: 0.7539 - recall: 1.0000
# Epoch 76: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5119 - loss: 0.5894 - pr_auc: 0.7524 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8121 - val_loss: 0.5837 - val_pr_auc: 0.9265 - val_recall: 1.0000
# Epoch 77/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7330 - auc: 0.5464 - loss: 0.5950 - pr_auc: 0.7637 - recall: 1.0000
# Epoch 77: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5384 - loss: 0.5868 - pr_auc: 0.7647 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7771 - val_loss: 0.5838 - val_pr_auc: 0.9104 - val_recall: 1.0000
# Epoch 78/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7389 - auc: 0.5256 - loss: 0.5916 - pr_auc: 0.7472 - recall: 1.0000
# Epoch 78: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5338 - loss: 0.5869 - pr_auc: 0.7586 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7749 - val_loss: 0.5838 - val_pr_auc: 0.9173 - val_recall: 1.0000
# Epoch 79/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7402 - auc: 0.5310 - loss: 0.5892 - pr_auc: 0.7594 - recall: 1.0000
# Epoch 79: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5335 - loss: 0.5874 - pr_auc: 0.7589 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7827 - val_loss: 0.5837 - val_pr_auc: 0.9203 - val_recall: 1.0000
# Epoch 80/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7454 - auc: 0.5248 - loss: 0.5844 - pr_auc: 0.7703 - recall: 1.0000
# Epoch 80: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5194 - loss: 0.5885 - pr_auc: 0.7600 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7829 - val_loss: 0.5836 - val_pr_auc: 0.9125 - val_recall: 1.0000
# Epoch 81/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7409 - auc: 0.5212 - loss: 0.5893 - pr_auc: 0.7601 - recall: 1.0000
# Epoch 81: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5185 - loss: 0.5887 - pr_auc: 0.7558 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7801 - val_loss: 0.5836 - val_pr_auc: 0.9206 - val_recall: 1.0000
# Epoch 82/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7391 - auc: 0.5126 - loss: 0.5923 - pr_auc: 0.7557 - recall: 1.0000
# Epoch 82: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7421 - auc: 0.5291 - loss: 0.5872 - pr_auc: 0.7647 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7817 - val_loss: 0.5835 - val_pr_auc: 0.9157 - val_recall: 1.0000
# Epoch 83/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7455 - auc: 0.5334 - loss: 0.5835 - pr_auc: 0.7621 - recall: 1.0000
# Epoch 83: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5311 - loss: 0.5874 - pr_auc: 0.7594 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7894 - val_loss: 0.5835 - val_pr_auc: 0.9247 - val_recall: 1.0000
# Epoch 84/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7424 - auc: 0.5290 - loss: 0.5865 - pr_auc: 0.7619 - recall: 1.0000
# Epoch 84: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5358 - loss: 0.5863 - pr_auc: 0.7683 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7878 - val_loss: 0.5835 - val_pr_auc: 0.9233 - val_recall: 1.0000
# Epoch 85/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7422 - auc: 0.5361 - loss: 0.5865 - pr_auc: 0.7642 - recall: 1.0000
# Epoch 85: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5292 - loss: 0.5874 - pr_auc: 0.7611 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7856 - val_loss: 0.5834 - val_pr_auc: 0.9211 - val_recall: 1.0000
# Epoch 86/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7385 - auc: 0.5138 - loss: 0.5934 - pr_auc: 0.7422 - recall: 1.0000
# Epoch 86: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5232 - loss: 0.5885 - pr_auc: 0.7514 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7815 - val_loss: 0.5834 - val_pr_auc: 0.9204 - val_recall: 1.0000
# Epoch 87/100
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7415 - auc: 0.5319 - loss: 0.5863 - pr_auc: 0.7707 - recall: 1.0000
# Epoch 87: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5276 - loss: 0.5869 - pr_auc: 0.7634 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7831 - val_loss: 0.5833 - val_pr_auc: 0.9187 - val_recall: 1.0000
# Epoch 88/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7455 - auc: 0.5359 - loss: 0.5830 - pr_auc: 0.7737 - recall: 1.0000
# Epoch 88: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5413 - loss: 0.5861 - pr_auc: 0.7685 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7810 - val_loss: 0.5834 - val_pr_auc: 0.9207 - val_recall: 1.0000
# Epoch 89/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7439 - auc: 0.5522 - loss: 0.5822 - pr_auc: 0.7782 - recall: 1.0000
# Epoch 89: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5350 - loss: 0.5861 - pr_auc: 0.7676 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7972 - val_loss: 0.5832 - val_pr_auc: 0.9194 - val_recall: 1.0000
# Epoch 90/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7495 - auc: 0.5193 - loss: 0.5809 - pr_auc: 0.7572 - recall: 1.0000
# Epoch 90: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5217 - loss: 0.5883 - pr_auc: 0.7518 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7808 - val_loss: 0.5832 - val_pr_auc: 0.9167 - val_recall: 1.0000
# Epoch 91/100
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7455 - auc: 0.4934 - loss: 0.5875 - pr_auc: 0.7437 - recall: 1.0000
# Epoch 91: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5049 - loss: 0.5899 - pr_auc: 0.7442 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7870 - val_loss: 0.5832 - val_pr_auc: 0.9148 - val_recall: 1.0000
# Epoch 92/100
# 580/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7567 - auc: 0.5349 - loss: 0.5712 - pr_auc: 0.7809 - recall: 1.0000
# Epoch 92: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5322 - loss: 0.5866 - pr_auc: 0.7658 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8011 - val_loss: 0.5830 - val_pr_auc: 0.9212 - val_recall: 1.0000
# Epoch 93/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7369 - auc: 0.5240 - loss: 0.5931 - pr_auc: 0.7568 - recall: 1.0000
# Epoch 93: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5254 - loss: 0.5877 - pr_auc: 0.7625 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8023 - val_loss: 0.5830 - val_pr_auc: 0.9219 - val_recall: 1.0000
# Epoch 94/100
# 581/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7520 - auc: 0.5423 - loss: 0.5754 - pr_auc: 0.7839 - recall: 1.0000
# Epoch 94: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5403 - loss: 0.5859 - pr_auc: 0.7708 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.8069 - val_loss: 0.5829 - val_pr_auc: 0.9244 - val_recall: 1.0000
# Epoch 95/100
# 579/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7451 - auc: 0.5387 - loss: 0.5830 - pr_auc: 0.7774 - recall: 1.0000
# Epoch 95: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5381 - loss: 0.5859 - pr_auc: 0.7684 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7904 - val_loss: 0.5829 - val_pr_auc: 0.9227 - val_recall: 1.0000
# Epoch 96/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7357 - auc: 0.5191 - loss: 0.5940 - pr_auc: 0.7538 - recall: 1.0000
# Epoch 96: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7421 - auc: 0.5244 - loss: 0.5872 - pr_auc: 0.7648 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7922 - val_loss: 0.5830 - val_pr_auc: 0.9252 - val_recall: 1.0000
# Epoch 97/100
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7361 - auc: 0.5489 - loss: 0.5910 - pr_auc: 0.7710 - recall: 1.0000
# Epoch 97: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5400 - loss: 0.5856 - pr_auc: 0.7689 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7914 - val_loss: 0.5831 - val_pr_auc: 0.9259 - val_recall: 1.0000
# Epoch 98/100
# 582/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7495 - auc: 0.5275 - loss: 0.5789 - pr_auc: 0.7719 - recall: 1.0000
# Epoch 98: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7421 - auc: 0.5187 - loss: 0.5880 - pr_auc: 0.7572 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7963 - val_loss: 0.5829 - val_pr_auc: 0.9185 - val_recall: 1.0000
# Epoch 99/100
# 584/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7356 - auc: 0.5239 - loss: 0.5934 - pr_auc: 0.7454 - recall: 1.0000
# Epoch 99: val_pr_auc did not improve from 0.92663
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7421 - auc: 0.5240 - loss: 0.5871 - pr_auc: 0.7568 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7938 - val_loss: 0.5829 - val_pr_auc: 0.9260 - val_recall: 1.0000
# Epoch 100/100
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7402 - auc: 0.5112 - loss: 0.5911 - pr_auc: 0.7517 - recall: 1.0000
# Epoch 100: val_pr_auc improved from 0.92663 to 0.92744, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7421 - auc: 0.5282 - loss: 0.5867 - pr_auc: 0.7641 - recall: 1.0000 - val_accuracy: 0.7424 - val_auc: 0.7960 - val_loss: 0.5829 - val_pr_auc: 0.9274 - val_recall: 1.0000
# Restoring model weights from the end of the best epoch: 100.

# %% [markdown]
# ### 4.5.2 Fine-Tuning (Base Unfrozen)
#
# After Stage 1 stabilizes the classification head, we proceed to **unfreeze the entire base model** (`base_model.trainable = True`).
#
# To prevent the destruction of the pre-trained weights, the model is **recompiled** with a **significantly lower learning rate** ($\mathbf{10^{-5}}$). This low rate ensures the training process only makes small, careful adjustments to the base model's weights, adapting them to the X-ray domain while maintaining a focus on high validation PR-AUC. The learning rate scheduler and early stopping continue to manage the process.

# %%
print("\n--- STAGE 2: Fine-Tuning (Base Unfrozen) ---")

# Unfreeze the base model
base_model.trainable = True

# Fine-tune only the top N layers if full unfreeze is too unstable
# for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.compile(
    # 10x or 100x smaller LR
    optimizer=AdamW(learning_rate=1e-5,
    weight_decay=1e-4), # type: ignore
    loss="binary_crossentropy",
    metrics=["accuracy", AUC(name="auc"), AUC(curve="PR", name="pr_auc"), Recall(name="recall")]
)

# Continue training
# Note: initial_epoch ensures the plot continuity
total_epochs = 150
history_fine = model.fit(
    TRAIN_DS,
    validation_data=VAL_DS,
    epochs=total_epochs,
    initial_epoch=history_stage1.epoch[-1], 
    callbacks=[best_model_callback, early_stopping, lr_scheduler],
    # class_weight=class_weights_dict
)
# Out:
# --- STAGE 2: Fine-Tuning (Base Unfrozen) ---
# Epoch 100/150
# 2025-11-29 00:48:47.025642: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:48:47.175473: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7267 - auc: 0.8361 - loss: 0.5676 - pr_auc: 0.9290 - recall: 0.6809
# 2025-11-29 00:49:12.845689: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-29 00:49:12.993456: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7269 - auc: 0.8362 - loss: 0.5674 - pr_auc: 0.9291 - recall: 0.6812
# Epoch 100: val_pr_auc improved from 0.92744 to 0.99576, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 57ms/step - accuracy: 0.8369 - auc: 0.9040 - loss: 0.4290 - pr_auc: 0.9613 - recall: 0.8409 - val_accuracy: 0.9370 - val_auc: 0.9878 - val_loss: 0.2083 - val_pr_auc: 0.9958 - val_recall: 0.9332 - learning_rate: 1.0000e-05
# Epoch 101/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9168 - auc: 0.9670 - loss: 0.2286 - pr_auc: 0.9873 - recall: 0.9473
# Epoch 101: val_pr_auc improved from 0.99576 to 0.99871, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9278 - auc: 0.9749 - loss: 0.2031 - pr_auc: 0.9908 - recall: 0.9531 - val_accuracy: 0.9656 - val_auc: 0.9963 - val_loss: 0.1063 - val_pr_auc: 0.9987 - val_recall: 0.9666 - learning_rate: 1.0000e-05
# Epoch 102/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9552 - auc: 0.9853 - loss: 0.1498 - pr_auc: 0.9932 - recall: 0.9705
# Epoch 102: val_pr_auc improved from 0.99871 to 0.99920, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9550 - auc: 0.9878 - loss: 0.1426 - pr_auc: 0.9954 - recall: 0.9691 - val_accuracy: 0.9714 - val_auc: 0.9977 - val_loss: 0.0816 - val_pr_auc: 0.9992 - val_recall: 0.9820 - learning_rate: 1.0000e-05
# Epoch 103/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9668 - auc: 0.9942 - loss: 0.1076 - pr_auc: 0.9980 - recall: 0.9791
# Epoch 103: val_pr_auc improved from 0.99920 to 0.99967, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9652 - auc: 0.9931 - loss: 0.1138 - pr_auc: 0.9976 - recall: 0.9777 - val_accuracy: 0.9866 - val_auc: 0.9990 - val_loss: 0.0600 - val_pr_auc: 0.9997 - val_recall: 0.9923 - learning_rate: 1.0000e-05
# Epoch 104/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9697 - auc: 0.9948 - loss: 0.1024 - pr_auc: 0.9982 - recall: 0.9794
# Epoch 104: val_pr_auc improved from 0.99967 to 0.99977, saving model to best_model_checkpoint.keras
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9698 - auc: 0.9955 - loss: 0.0975 - pr_auc: 0.9985 - recall: 0.9794 - val_accuracy: 0.9847 - val_auc: 0.9993 - val_loss: 0.0554 - val_pr_auc: 0.9998 - val_recall: 0.9923 - learning_rate: 1.0000e-05
# Epoch 105/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9818 - auc: 0.9965 - loss: 0.0716 - pr_auc: 0.9994 - recall: 0.9870
# Epoch 105: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9807 - auc: 0.9976 - loss: 0.0726 - pr_auc: 0.9992 - recall: 0.9863 - val_accuracy: 0.9847 - val_auc: 0.9987 - val_loss: 0.0574 - val_pr_auc: 0.9995 - val_recall: 0.9974 - learning_rate: 1.0000e-05
# Epoch 106/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9822 - auc: 0.9966 - loss: 0.0651 - pr_auc: 0.9994 - recall: 0.9877
# Epoch 106: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9809 - auc: 0.9980 - loss: 0.0682 - pr_auc: 0.9993 - recall: 0.9871 - val_accuracy: 0.9847 - val_auc: 0.9989 - val_loss: 0.0531 - val_pr_auc: 0.9996 - val_recall: 0.9949 - learning_rate: 1.0000e-05
# Epoch 107/150
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9913 - auc: 0.9994 - loss: 0.0472 - pr_auc: 0.9998 - recall: 0.9944
# Epoch 107: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9877 - auc: 0.9988 - loss: 0.0552 - pr_auc: 0.9996 - recall: 0.9917 - val_accuracy: 0.9847 - val_auc: 0.9991 - val_loss: 0.0501 - val_pr_auc: 0.9997 - val_recall: 0.9923 - learning_rate: 1.0000e-05
# Epoch 108/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - auc: 0.9992 - loss: 0.0521 - pr_auc: 0.9997 - recall: 0.9918
# Epoch 108: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9875 - auc: 0.9990 - loss: 0.0538 - pr_auc: 0.9996 - recall: 0.9923 - val_accuracy: 0.9828 - val_auc: 0.9955 - val_loss: 0.0592 - val_pr_auc: 0.9970 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 109/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9925 - auc: 0.9996 - loss: 0.0418 - pr_auc: 0.9999 - recall: 0.9936
# Epoch 109: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9917 - auc: 0.9996 - loss: 0.0417 - pr_auc: 0.9999 - recall: 0.9937 - val_accuracy: 0.7882 - val_auc: 0.9485 - val_loss: 0.6983 - val_pr_auc: 0.9685 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 110/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9885 - auc: 0.9993 - loss: 0.0456 - pr_auc: 0.9998 - recall: 0.9904
# Epoch 110: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9921 - auc: 0.9996 - loss: 0.0393 - pr_auc: 0.9999 - recall: 0.9940 - val_accuracy: 0.9866 - val_auc: 0.9991 - val_loss: 0.0507 - val_pr_auc: 0.9997 - val_recall: 0.9974 - learning_rate: 1.0000e-05
# Epoch 111/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9949 - auc: 0.9998 - loss: 0.0340 - pr_auc: 0.9999 - recall: 0.9974
# Epoch 111: val_pr_auc did not improve from 0.99977
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9917 - auc: 0.9996 - loss: 0.0393 - pr_auc: 0.9999 - recall: 0.9951 - val_accuracy: 0.9752 - val_auc: 0.9944 - val_loss: 0.0757 - val_pr_auc: 0.9963 - val_recall: 0.9743 - learning_rate: 1.0000e-05
# Epoch 112/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9920 - auc: 0.9997 - loss: 0.0349 - pr_auc: 0.9999 - recall: 0.9929
# Epoch 112: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9947 - auc: 0.9997 - loss: 0.0318 - pr_auc: 0.9999 - recall: 0.9957 - val_accuracy: 0.9866 - val_auc: 0.9950 - val_loss: 0.0658 - val_pr_auc: 0.9968 - val_recall: 0.9949 - learning_rate: 5.0000e-06
# Epoch 113/150
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9960 - auc: 0.9999 - loss: 0.0310 - pr_auc: 1.0000 - recall: 0.9962
# Epoch 113: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9970 - auc: 0.9998 - loss: 0.0294 - pr_auc: 0.9999 - recall: 0.9974 - val_accuracy: 0.9885 - val_auc: 0.9954 - val_loss: 0.0520 - val_pr_auc: 0.9970 - val_recall: 0.9923 - learning_rate: 5.0000e-06
# Epoch 114/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9963 - auc: 0.9999 - loss: 0.0286 - pr_auc: 1.0000 - recall: 0.9975
# Epoch 114: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9962 - auc: 0.9999 - loss: 0.0289 - pr_auc: 1.0000 - recall: 0.9974 - val_accuracy: 0.9771 - val_auc: 0.9884 - val_loss: 0.1152 - val_pr_auc: 0.9921 - val_recall: 1.0000 - learning_rate: 5.0000e-06
# Epoch 115/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9937 - auc: 0.9996 - loss: 0.0342 - pr_auc: 0.9998 - recall: 0.9962
# Epoch 115: val_pr_auc did not improve from 0.99977
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9955 - auc: 0.9994 - loss: 0.0320 - pr_auc: 0.9996 - recall: 0.9971 - val_accuracy: 0.9866 - val_auc: 0.9914 - val_loss: 0.0743 - val_pr_auc: 0.9943 - val_recall: 0.9974 - learning_rate: 5.0000e-06
# Epoch 116/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9965 - auc: 0.9999 - loss: 0.0265 - pr_auc: 1.0000 - recall: 0.9977
# Epoch 116: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9953 - auc: 0.9999 - loss: 0.0282 - pr_auc: 1.0000 - recall: 0.9971 - val_accuracy: 0.9885 - val_auc: 0.9956 - val_loss: 0.0517 - val_pr_auc: 0.9971 - val_recall: 0.9974 - learning_rate: 2.5000e-06
# Epoch 117/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - auc: 0.9999 - loss: 0.0275 - pr_auc: 1.0000 - recall: 0.9978
# Epoch 117: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9968 - auc: 0.9999 - loss: 0.0273 - pr_auc: 1.0000 - recall: 0.9983 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0486 - val_pr_auc: 0.9971 - val_recall: 0.9974 - learning_rate: 2.5000e-06
# Epoch 118/150
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9965 - auc: 0.9998 - loss: 0.0284 - pr_auc: 0.9999 - recall: 0.9982
# Epoch 118: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9977 - auc: 0.9999 - loss: 0.0258 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9866 - val_auc: 0.9958 - val_loss: 0.0543 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 2.5000e-06
# Epoch 119/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9971 - auc: 0.9979 - loss: 0.0284 - pr_auc: 0.9999 - recall: 0.9983
# Epoch 119: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9972 - auc: 0.9998 - loss: 0.0257 - pr_auc: 0.9999 - recall: 0.9983 - val_accuracy: 0.9866 - val_auc: 0.9958 - val_loss: 0.0599 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 2.5000e-06
# Epoch 120/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9969 - auc: 1.0000 - loss: 0.0246 - pr_auc: 1.0000 - recall: 0.9975
# Epoch 120: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.0239 - pr_auc: 1.0000 - recall: 0.9983 - val_accuracy: 0.9847 - val_auc: 0.9958 - val_loss: 0.0564 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 2.5000e-06
# Epoch 121/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9959 - auc: 0.9999 - loss: 0.0291 - pr_auc: 0.9999 - recall: 0.9983
# Epoch 121: val_pr_auc did not improve from 0.99977
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9968 - auc: 0.9999 - loss: 0.0263 - pr_auc: 1.0000 - recall: 0.9980 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0629 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 2.5000e-06
# Epoch 122/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0232 - pr_auc: 1.0000 - recall: 0.9995
# Epoch 122: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0237 - pr_auc: 1.0000 - recall: 0.9994 - val_accuracy: 0.9866 - val_auc: 0.9956 - val_loss: 0.0539 - val_pr_auc: 0.9971 - val_recall: 0.9949 - learning_rate: 1.2500e-06
# Epoch 123/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9981 - auc: 0.9999 - loss: 0.0230 - pr_auc: 1.0000 - recall: 0.9985
# Epoch 123: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9970 - auc: 0.9998 - loss: 0.0254 - pr_auc: 0.9999 - recall: 0.9977 - val_accuracy: 0.9866 - val_auc: 0.9956 - val_loss: 0.0669 - val_pr_auc: 0.9971 - val_recall: 0.9974 - learning_rate: 1.2500e-06
# Epoch 124/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9974 - auc: 1.0000 - loss: 0.0237 - pr_auc: 1.0000 - recall: 0.9988
# Epoch 124: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0232 - pr_auc: 1.0000 - recall: 0.9989 - val_accuracy: 0.9885 - val_auc: 0.9958 - val_loss: 0.0485 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.2500e-06
# Epoch 125/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9972 - auc: 0.9999 - loss: 0.0248 - pr_auc: 1.0000 - recall: 0.9984
# Epoch 125: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9970 - auc: 0.9999 - loss: 0.0251 - pr_auc: 1.0000 - recall: 0.9983 - val_accuracy: 0.9866 - val_auc: 0.9957 - val_loss: 0.0525 - val_pr_auc: 0.9971 - val_recall: 0.9949 - learning_rate: 1.2500e-06
# Epoch 126/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9973 - auc: 0.9995 - loss: 0.0260 - pr_auc: 0.9997 - recall: 0.9987
# Epoch 126: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9970 - auc: 0.9995 - loss: 0.0260 - pr_auc: 0.9997 - recall: 0.9986 - val_accuracy: 0.9885 - val_auc: 0.9959 - val_loss: 0.0588 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.2500e-06
# Epoch 127/150
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0220 - pr_auc: 1.0000 - recall: 0.9993
# Epoch 127: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0228 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0512 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.2500e-06
# Epoch 128/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9969 - auc: 0.9997 - loss: 0.0257 - pr_auc: 0.9999 - recall: 0.9974
# Epoch 128: val_pr_auc did not improve from 0.99977
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1e-06.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9972 - auc: 0.9998 - loss: 0.0246 - pr_auc: 0.9999 - recall: 0.9980 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0525 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.2500e-06
# Epoch 129/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0195 - pr_auc: 1.0000 - recall: 0.9992
# Epoch 129: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9985 - auc: 1.0000 - loss: 0.0209 - pr_auc: 1.0000 - recall: 0.9989 - val_accuracy: 0.9885 - val_auc: 0.9956 - val_loss: 0.0627 - val_pr_auc: 0.9971 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 130/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9975 - auc: 0.9999 - loss: 0.0245 - pr_auc: 1.0000 - recall: 0.9981
# Epoch 130: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9979 - auc: 0.9999 - loss: 0.0242 - pr_auc: 1.0000 - recall: 0.9986 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0612 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 131/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9986 - auc: 0.9983 - loss: 0.0209 - pr_auc: 1.0000 - recall: 0.9989
# Epoch 131: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0208 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9847 - val_auc: 0.9955 - val_loss: 0.0631 - val_pr_auc: 0.9971 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Epoch 132/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 0.0210 - pr_auc: 1.0000 - recall: 0.9992
# Epoch 132: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0216 - pr_auc: 1.0000 - recall: 0.9989 - val_accuracy: 0.9866 - val_auc: 0.9957 - val_loss: 0.0542 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Epoch 133/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.0225 - pr_auc: 1.0000 - recall: 0.9991
# Epoch 133: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.0233 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9885 - val_auc: 0.9958 - val_loss: 0.0483 - val_pr_auc: 0.9972 - val_recall: 0.9949 - learning_rate: 1.0000e-06
# Epoch 134/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9978 - auc: 0.9992 - loss: 0.0241 - pr_auc: 0.9995 - recall: 0.9985
# Epoch 134: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9979 - auc: 0.9994 - loss: 0.0240 - pr_auc: 0.9996 - recall: 0.9986 - val_accuracy: 0.9866 - val_auc: 0.9957 - val_loss: 0.0516 - val_pr_auc: 0.9972 - val_recall: 0.9949 - learning_rate: 1.0000e-06
# Epoch 135/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9981 - auc: 1.0000 - loss: 0.0217 - pr_auc: 1.0000 - recall: 0.9988
# Epoch 135: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9981 - auc: 1.0000 - loss: 0.0222 - pr_auc: 1.0000 - recall: 0.9986 - val_accuracy: 0.9905 - val_auc: 0.9957 - val_loss: 0.0494 - val_pr_auc: 0.9971 - val_recall: 0.9949 - learning_rate: 1.0000e-06
# Epoch 136/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0218 - pr_auc: 1.0000 - recall: 0.9992
# Epoch 136: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9987 - auc: 0.9995 - loss: 0.0229 - pr_auc: 0.9997 - recall: 0.9994 - val_accuracy: 0.9866 - val_auc: 0.9959 - val_loss: 0.0582 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 137/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - auc: 1.0000 - loss: 0.0241 - pr_auc: 1.0000 - recall: 0.9980
# Epoch 137: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.0224 - pr_auc: 1.0000 - recall: 0.9989 - val_accuracy: 0.9885 - val_auc: 0.9958 - val_loss: 0.0582 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 138/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0210 - pr_auc: 1.0000 - recall: 0.9986
# Epoch 138: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9985 - auc: 1.0000 - loss: 0.0207 - pr_auc: 1.0000 - recall: 0.9986 - val_accuracy: 0.9885 - val_auc: 0.9956 - val_loss: 0.0721 - val_pr_auc: 0.9971 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 139/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9990 - auc: 1.0000 - loss: 0.0203 - pr_auc: 1.0000 - recall: 0.9997
# Epoch 139: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0219 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9885 - val_auc: 0.9957 - val_loss: 0.0580 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 140/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 0.0197 - pr_auc: 1.0000 - recall: 0.9997
# Epoch 140: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9972 - auc: 0.9995 - loss: 0.0250 - pr_auc: 0.9997 - recall: 0.9989 - val_accuracy: 0.9847 - val_auc: 0.9957 - val_loss: 0.0813 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 141/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - auc: 0.9983 - loss: 0.0221 - pr_auc: 1.0000 - recall: 0.9982
# Epoch 141: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0214 - pr_auc: 1.0000 - recall: 0.9983 - val_accuracy: 0.9847 - val_auc: 0.9955 - val_loss: 0.0705 - val_pr_auc: 0.9971 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Epoch 142/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - auc: 1.0000 - loss: 0.0219 - pr_auc: 1.0000 - recall: 0.9999
# Epoch 142: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0214 - pr_auc: 1.0000 - recall: 0.9994 - val_accuracy: 0.9905 - val_auc: 0.9958 - val_loss: 0.0528 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 143/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 0.0206 - pr_auc: 1.0000 - recall: 0.9990
# Epoch 143: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0201 - pr_auc: 1.0000 - recall: 0.9991 - val_accuracy: 0.9885 - val_auc: 0.9958 - val_loss: 0.0584 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 144/150
# 587/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9989 - auc: 0.9999 - loss: 0.0205 - pr_auc: 1.0000 - recall: 0.9993
# Epoch 144: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9985 - auc: 0.9995 - loss: 0.0247 - pr_auc: 0.9997 - recall: 0.9994 - val_accuracy: 0.9866 - val_auc: 0.9957 - val_loss: 0.0494 - val_pr_auc: 0.9971 - val_recall: 0.9923 - learning_rate: 1.0000e-06
# Epoch 145/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9966 - auc: 0.9998 - loss: 0.0235 - pr_auc: 0.9999 - recall: 0.9973
# Epoch 145: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9968 - auc: 0.9991 - loss: 0.0265 - pr_auc: 0.9994 - recall: 0.9980 - val_accuracy: 0.9905 - val_auc: 0.9958 - val_loss: 0.0520 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Epoch 146/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9980 - auc: 1.0000 - loss: 0.0223 - pr_auc: 1.0000 - recall: 0.9985
# Epoch 146: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0227 - pr_auc: 1.0000 - recall: 0.9983 - val_accuracy: 0.9905 - val_auc: 0.9958 - val_loss: 0.0573 - val_pr_auc: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 147/150
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0205 - pr_auc: 1.0000 - recall: 0.9999
# Epoch 147: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9981 - auc: 1.0000 - loss: 0.0210 - pr_auc: 1.0000 - recall: 0.9997 - val_accuracy: 0.9924 - val_auc: 0.9958 - val_loss: 0.0477 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Epoch 148/150
# 586/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - auc: 0.9998 - loss: 0.0195 - pr_auc: 0.9999 - recall: 0.9990
# Epoch 148: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9983 - auc: 0.9996 - loss: 0.0209 - pr_auc: 0.9997 - recall: 0.9989 - val_accuracy: 0.9866 - val_auc: 0.9958 - val_loss: 0.0490 - val_pr_auc: 0.9972 - val_recall: 0.9949 - learning_rate: 1.0000e-06
# Epoch 149/150
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9985 - auc: 0.9983 - loss: 0.0212 - pr_auc: 1.0000 - recall: 0.9988
# Epoch 149: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9981 - auc: 1.0000 - loss: 0.0212 - pr_auc: 1.0000 - recall: 0.9986 - val_accuracy: 0.9905 - val_auc: 0.9958 - val_loss: 0.0475 - val_pr_auc: 0.9972 - val_recall: 0.9949 - learning_rate: 1.0000e-06
# Epoch 150/150
# 585/589 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.0227 - pr_auc: 1.0000 - recall: 0.9977
# Epoch 150: val_pr_auc did not improve from 0.99977
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0229 - pr_auc: 1.0000 - recall: 0.9980 - val_accuracy: 0.9905 - val_auc: 0.9958 - val_loss: 0.0511 - val_pr_auc: 0.9972 - val_recall: 0.9974 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 149.

# %% [markdown]
# &#160;

# %% [markdown]
# # 5. Evaluation
#
# ---

# %% [markdown]
# In this section, the final model is evaluated on a held-out test set using clinically relevant classification metrics (accuracy, precision, recall, F1-score and AUC), together with confusion matrices, Precision–Recall analysis and threshold-based error summaries. We also inspect the loss and accuracy curves over epochs to verify that training converged without severe overfitting before selecting the best checkpoint for testing.

# %%
# --- 1. Combine History Data ---

# Function to safely combine history logs
def combine_history(h1, h2):
    combined = {}
    # Iterate over all metrics (e.g., 'loss', 'val_loss', 'pr_auc', 'val_pr_auc', etc.)
    for key in h1.history.keys():
        # Concatenate the lists from Stage 1 and Stage 2
        combined[key] = h1.history[key] + h2.history[key]
    return combined

# Create the combined history dictionary
combined_history = combine_history(history_stage1, history_fine)


# --- 2. Plotting Combined History ---

plt.figure(figsize=(14, 5))

# 1. PR-AUC Plot
plt.subplot(1, 2, 1)
# Plot using the combined data
plt.plot(combined_history['pr_auc'], label='Training PR-AUC')
plt.plot(combined_history['val_pr_auc'], label='Validation PR-AUC') 
plt.title('Model PR-AUC Over Epochs (Two Stages)')
plt.xlabel('Epoch')
plt.ylabel('PR-AUC')
plt.axvline(x=len(history_stage1.epoch) - 1, color='gray', linestyle='--', label='End of Stage 1')
plt.legend(loc='lower right')


# 2. Loss Plot
plt.subplot(1, 2, 2)
# Plot using the combined data
plt.plot(combined_history['loss'], label='Training Loss')
plt.plot(combined_history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs (Two Stages)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.axvline(x=len(history_stage1.epoch) - 1, color='gray', linestyle='--', label='End of Stage 1')
plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig('training_curves_pr_auc_loss_combined.png')
plt.show()

# %% [markdown]
# **Figure 5.1** - Training and validation accuracy and loss curves over epochs for the CNN model.

# %%
# Load the best model saved by the callback
print(f"Load the best model from: {CHECKPOINT_PATH}")
best_model = models.load_model(CHECKPOINT_PATH)

# Report metrics
# CORRECTED: Use TEST_DS instead of test_dataset_gray
results = best_model.evaluate(TEST_DS, verbose=2, return_dict=True)

print("\n=== Test Set Evaluation Results ===")
for k,v in results.items():
	print(f"{k}: {v:.4f}")
print("=" * 35)
# Out:
# Load the best model from: best_model_checkpoint.keras
# 78/78 - 5s - 63ms/step - accuracy: 0.7404 - auc: 0.9101 - loss: 0.8612 - pr_auc: 0.9125 - recall: 1.0000
#
# === Test Set Evaluation Results ===
# accuracy: 0.7404
# auc: 0.9101
# loss: 0.8612
# pr_auc: 0.9125
# recall: 1.0000
# ===================================

# %%
# Load the best model saved by the callback
print(f"Load the best model from: {CHECKPOINT_PATH}")
best_model = models.load_model(CHECKPOINT_PATH) # Assuming CHECKPOINT_PATH is defined

print("Generating predictions...")

# Use the correct dataset variable TEST_DS for predictions
y_pred_probs = best_model.predict(TEST_DS, verbose=1).flatten()

# Extract true labels from the dataset
y_true = []
# Use the correct dataset variable TEST_DS to iterate
for _, labels in TEST_DS.unbatch():
    y_true.append(labels.numpy())
y_true = np.array(y_true)

print(f"\nTotal test samples: {len(y_true)}")
print(f"Pneumonia cases: {sum(y_true)} ({sum(y_true)/len(y_true)*100:.1f}%)")
print(f"Normal cases: {len(y_true) - sum(y_true)} ({(len(y_true)-sum(y_true))/len(y_true)*100:.1f}%)")

# Trade-off descriptions helper
def describe_tradeoff(threshold, recall, precision):
    # This function uses recall and precision, but they are not used in the return string.
    # The logic below is maintained for context, but you may want to refine the description.
    if threshold <= 0.2:
        return "Very low threshold; maximize coverage (High Recall, low Precision)"
    elif threshold <= 0.3:
        return "Maximum coverage; few missed cases (High Recall, moderate Precision)"
    elif threshold <= 0.5:
        return "Strong balance (Balanced Recall and Precision)"
    elif threshold <= 0.6:
        return "More conservative (Higher Precision, lower Recall)"
    elif threshold <= 0.8:
        return "Very selective (High Precision, low Recall)"
    else:
        return "Extremely selective; only strongest positives (Highest Precision, lowest Recall)"

# Test thresholds from 0.1 to 0.9 (step 0.1)
thresholds_to_test = [round(t, 1) for t in np.arange(0.1, 1.0, 0.1)]

print("\n" + "="*30)
print("THRESHOLD ANALYSIS")
print("="*30)

results = []
for threshold in thresholds_to_test:
    y_pred = (y_pred_probs >= threshold).astype(int)
    
    # Calculate confusion matrix components
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Calculate metrics
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    results.append({
        'threshold': threshold,
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'recall': recall,
        'precision': precision,
        'accuracy': accuracy,
        'f1': f1
    })
    
    print(f"\nThreshold: {threshold}")
    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")
    print(f"  Trade-off: {describe_tradeoff(threshold, recall, precision)}")
    print(f"  ---")
    print(f"  True Positives (Pneumonia correctly identified):  {tp}")
    print(f"  False Negatives (Pneumonia MISSED):               {fn}")
    print(f"  False Positives (Normal incorrectly flagged):     {fp}")
    print(f"  True Negatives (Normal correctly identified):     {tn}")

# Classification Report
y_pred_default = (y_pred_probs >= 0.5).astype(int)
cm = confusion_matrix(y_true, y_pred_default)

print("\nDetailed Classification Report (Threshold = 0.5):")
print(classification_report(
    y_true,
    y_pred_default,
    target_names=['Normal', 'Pneumonia'],
    digits=4
))
# Out:
# Load the best model from: best_model_checkpoint.keras
# Generating predictions...
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#
# Total test samples: 624
# Pneumonia cases: 390.0 (62.5%)
# Normal cases: 234.0 (37.5%)
#
# ==============================
# THRESHOLD ANALYSIS
# ==============================
#
# Threshold: 0.1
#   Accuracy:  0.6827
#   Precision: 0.6633
#   Recall:    1.0000
#   F1-Score:  0.7975
#   Trade-off: Very low threshold; maximize coverage (High Recall, low Precision)
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     198
#   True Negatives (Normal correctly identified):     36
#
# Threshold: 0.2
#   Accuracy:  0.7019
#   Precision: 0.6771
#   Recall:    1.0000
#   F1-Score:  0.8075
#   Trade-off: Very low threshold; maximize coverage (High Recall, low Precision)
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     186
#   True Negatives (Normal correctly identified):     48
#
# Threshold: 0.3
#   Accuracy:  0.7196
#   Precision: 0.6903
#   Recall:    1.0000
#   F1-Score:  0.8168
#   Trade-off: Maximum coverage; few missed cases (High Recall, moderate Precision)
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     175
#   True Negatives (Normal correctly identified):     59
#
# Threshold: 0.4
#   Accuracy:  0.7276
#   Precision: 0.6964
#   Recall:    1.0000
#   F1-Score:  0.8211
#   Trade-off: Strong balance (Balanced Recall and Precision)
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     170
#   True Negatives (Normal correctly identified):     64
#
# Threshold: 0.5
#   Accuracy:  0.7404
#   Precision: 0.7065
#   Recall:    1.0000
#   F1-Score:  0.8280
#   Trade-off: Strong balance (Balanced Recall and Precision)
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     162
#   True Negatives (Normal correctly identified):     72
#
# Threshold: 0.6
#   Accuracy:  0.7580
#   Precision: 0.7225
#   Recall:    0.9949
#   F1-Score:  0.8371
#   Trade-off: More conservative (Higher Precision, lower Recall)
#   ---
#   True Positives (Pneumonia correctly identified):  388
#   False Negatives (Pneumonia MISSED):               2
#   False Positives (Normal incorrectly flagged):     149
#   True Negatives (Normal correctly identified):     85
#
# Threshold: 0.7
#   Accuracy:  0.7821
#   Precision: 0.7433
#   Recall:    0.9949
#   F1-Score:  0.8509
#   Trade-off: Very selective (High Precision, low Recall)
#   ---
#   True Positives (Pneumonia correctly identified):  388
#   False Negatives (Pneumonia MISSED):               2
#   False Positives (Normal incorrectly flagged):     134
#   True Negatives (Normal correctly identified):     100
#
# Threshold: 0.8
#   Accuracy:  0.8029
#   Precision: 0.7623
#   Recall:    0.9949
#   F1-Score:  0.8632
#   Trade-off: Very selective (High Precision, low Recall)
#   ---
#   True Positives (Pneumonia correctly identified):  388
#   False Negatives (Pneumonia MISSED):               2
#   False Positives (Normal incorrectly flagged):     121
#   True Negatives (Normal correctly identified):     113
#
# Threshold: 0.9
#   Accuracy:  0.8381
#   Precision: 0.8004
#   Recall:    0.9872
#   F1-Score:  0.8840
#   Trade-off: Extremely selective; only strongest positives (Highest Precision, lowest Recall)
#   ---
#   True Positives (Pneumonia correctly identified):  385
#   False Negatives (Pneumonia MISSED):               5
#   False Positives (Normal incorrectly flagged):     96
#   True Negatives (Normal correctly identified):     138
#
# Detailed Classification Report (Threshold = 0.5):
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.3077    0.4706       234
#    Pneumonia     0.7065    1.0000    0.8280       390
#
#     accuracy                         0.7404       624
#    macro avg     0.8533    0.6538    0.6493       624
# weighted avg     0.8166    0.7404    0.6940       624
# 2025-11-29 00:56:54.436041: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# &#160;

# %% [markdown]
# # 6. Conclusions
#
# ---

# %%
# 0.1, 0.2, ..., 0.9
thresholds = [0.1 * i for i in range(1, 10)]

fig, axes = plt.subplots(3, 3, figsize=(12, 10))

for ax, thr in zip(axes.ravel(), thresholds):
    y_pred_thr = (y_pred_probs >= thr).astype(int)
    cm_thr = confusion_matrix(y_true, y_pred_thr)

    sns.heatmap(
        cm_thr,
        annot=True,
        fmt='d',
        cmap='Blues',
        cbar=False,
        xticklabels=['Normal', 'Pneumonia'],
        yticklabels=['Normal', 'Pneumonia'],
        ax=ax
    )

    ax.set_title(f'Threshold = {thr:.1f}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 6.1** - Confusion matrices on the test set for thresholds

# %%
thresholds = [r['threshold'] for r in results]
recalls = [r['recall'] for r in results]
precisions = [r['precision'] for r in results]
f1_scores = [r['f1'] for r in results]

plt.figure(figsize=(8, 5))

plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, f1_scores, label='F1-score')

# Highlight recommended threshold
recommended_threshold = 0.6
plt.axvline(recommended_threshold, linestyle='--', label='Recommended threshold (0.6)')

plt.xlabel('Threshold')
plt.ylabel('Metric value')
plt.ylim(0, 1.05)
plt.title("Effect of Threshold on Recall, Precision and F1-score\n")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 6.2** - Recall, precision and F1-score on the test set as a function of threshold.

# %%
# Generate the precision-recall curve data
precision_curve, recall_curve, _ = precision_recall_curve(y_true, y_pred_probs)

# Convert to the right format for plotting (need to reverse the order for proper plotting)
recall_curve = np.flip(recall_curve)
precision_curve = np.flip(precision_curve)

# Precision-Recall curve and Recall/Precision vs Threshold
plt.figure(figsize=(13, 5))

# Left plot: Precision-Recall curve
plt.subplot(1, 2, 1)
plt.plot(recall_curve, precision_curve, linewidth=2, color='#2E86AB')
plt.xlabel('Recall', fontsize=11)
plt.ylabel('Precision', fontsize=11)
plt.title('Precision-Recall Curve\n', fontsize=12)
plt.grid(True, alpha=0.3)

# Mark the tested thresholds (0.1 to 0.9) on the PR curve
for r in results:
    plt.plot(r['recall'], r['precision'], marker='o', markersize=6, color="#E45555")
    plt.annotate(
        f"{r['threshold']:.1f}",
        xy=(r['recall'], r['precision']),
        xytext=(-22, -3),
        textcoords='offset points'
    )

# Right plot: Recall & Precision vs Threshold
plt.subplot(1, 2, 2)
plt.plot(thresholds, recalls, color='#2E86AB', marker='o', linewidth=2, label='Recall', markersize=6)
plt.plot(thresholds, precisions, color='#F18F01', marker='o', linewidth=2, label='Precision', markersize=6)
plt.xlabel('Threshold', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.title('Recall & Precision vs Threshold\n', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 6.3** - Precision–recall curve and recall/precision vs threshold on the test set.

# %% [markdown]
# ## 6.1 Pneumonia Cases Missed

# %%
# Find missed pneumonia cases at THRESHOLD
THRESHOLD = 0.9

# After generating predictions
predictions = model.predict(TEST_DS)

# Get labels from the original arrays
y_test_array = np.array([1.0 if label == 'PNEUMONIA' else 0.0 for label in y_test])

missed_pneumonia_idx = np.where(
    (y_test_array == 1) &  # True pneumonia
    (predictions.flatten() < THRESHOLD)  # Predicted normal
)[0]

print(f"\nMissed pneumonia cases at THRESHOLD {THRESHOLD}:")
print(f"Total missed: {len(missed_pneumonia_idx)}")

# Plot all missed cases
n_missed = len(missed_pneumonia_idx)

if n_missed > 0:
    cols = min(3, n_missed)
    rows = (n_missed + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=(5*cols, 5*rows))
    
    if n_missed == 1:
        axes = np.array([axes])
    axes = axes.flatten()
    
    for i, idx in enumerate(missed_pneumonia_idx):
        prediction_score = predictions[idx][0]
        filepath = X_test.iloc[idx]
        
        # Load and display image
        img = Image.open(filepath)
        axes[i].imshow(img, cmap='gray')
        axes[i].axis('off')
        
        # Label BELOW the image
        axes[i].text(
            0.5, -0.05,
            f'Missed #{i+1}\nPrediction: {prediction_score:.4f}\n(Threshold: {THRESHOLD})',
            transform=axes[i].transAxes,
            fontsize=10,
            color='red',
            fontweight='bold',
            ha='center',
            va='top'
        )
    
    # Hide unused subplots
    for i in range(n_missed, len(axes)):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.suptitle(f'False Negatives: Missed Pneumonia Cases (Threshold={THRESHOLD})', 
                 fontsize=14, fontweight='bold')
    plt.show()
else:
    print("No missed pneumonia cases at this threshold!")
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#
# Missed pneumonia cases at THRESHOLD 0.9:
# Total missed: 1

# %%
# Show false positives at THRESHOLD
THRESHOLD = 0.8
# Set -1 to show all, or a specific number like 12
n = 24  

# Find false positives
false_positive_idx = np.where(
    (y_test_array == 0) &  # True normal
    (predictions.flatten() >= THRESHOLD)  # Predicted pneumonia
)[0]

print(f"\nFalse positive cases at THRESHOLD {THRESHOLD}:")
print(f"Total false positives: {len(false_positive_idx)}")

# Determine how many to show
if n == -1:
    n_fp_to_show = len(false_positive_idx)
else:
    n_fp_to_show = min(n, len(false_positive_idx))

print(f"Showing: {n_fp_to_show}")

# Plot false positives
if n_fp_to_show > 0:
    cols = min(4, n_fp_to_show)
    rows = (n_fp_to_show + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=(4*cols, 4*rows))
    
    if n_fp_to_show == 1:
        axes = np.array([axes])
    axes = axes.flatten()
    
    for i in range(n_fp_to_show):
        idx = false_positive_idx[i]
        prediction_score = predictions[idx][0]
        filepath = X_test.iloc[idx]
        
        # Load and display image
        img = Image.open(filepath)
        axes[i].imshow(img, cmap='gray')
        axes[i].axis('off')
        
        # Label BELOW the image
        axes[i].text(
            0.5, -0.05,
            f'FP #{i+1}\nPrediction: {prediction_score:.4f}\nTrue: NORMAL',
            transform=axes[i].transAxes,
            fontsize=9,
            color='orange',
            fontweight='bold',
            ha='center',
            va='top'
        )
    
    # Hide unused subplots
    for i in range(n_fp_to_show, len(axes)):
        axes[i].axis('off')
    
    plt.tight_layout()
    
    if n == -1:
        plt.suptitle(f'False Positives: Normal Incorrectly Flagged (Threshold={THRESHOLD}, All {len(false_positive_idx)} cases)', 
                     fontsize=12, fontweight='bold')
    else:
        plt.suptitle(f'False Positives: Normal Incorrectly Flagged (Threshold={THRESHOLD}, Showing {n_fp_to_show}/{len(false_positive_idx)})', 
                     fontsize=12, fontweight='bold')
    
    plt.show()
else:
    print("No false positives at this threshold!")
# Out:
# False positive cases at THRESHOLD 0.8:
# Total false positives: 124
# Showing: 24

# %% [markdown]
# ## 6.3 Specificity and Case Volume Reduction

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
# Assuming 'predictions' (the raw scores from model.predict(TEST_DS)) 
# and 'y_test_array' (the 0/1 true labels) are already defined in notebook.

# --- 1. Define Variables for Calculation ---
# Use the variables defined in visualization code
# NOTE: Ensure 'predictions' is the output of model.predict(TEST_DS)
# NOTE: Ensure 'y_test_array' is the 0/1 array of true test labels
y_pred_proba = predictions.flatten() 
y_true = y_test_array

# --- 2. Calculate Comparison Metrics ---
# Target Recall levels from the study
TARGET_RECALLS = [0.999, 0.990, 0.980]

# Total number of negative (Unremarkable/Normal) cases in the test set
Total_Negatives = (y_true == 0).sum()

# Iterate through a dense range of possible thresholds 
thresholds = np.linspace(0, 1, 1000)

print("--- Comparison to Clinical Study (Specificity at High Recall) ---")
print(f"Total Test Samples: {len(y_true)}")
print(f"Total Unremarkable (Negative) Cases: {Total_Negatives}\n")

for target_recall in TARGET_RECALLS:
    best_specificity = 0
    best_threshold = 0
    
    # Iterate through all thresholds to find the one that meets the target recall
    for tau in thresholds:
        # Convert probabilities to binary predictions
        y_pred_binary = (y_pred_proba >= tau).astype(int)
        
        # Calculate confusion matrix for this threshold
        # Labels: 0 (Normal/Unremarkable) is Negative, 1 (Pneumonia/Pathology) is Positive
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred_binary).ravel()
        
        # Calculate current Recall (Sensitivity)
        # Note: (tp + fn) is the Total Positives
        current_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        
        # We want the threshold that meets or exceeds the target recall
        if current_recall >= target_recall:
            # Calculate Specificity: TN / (TN + FP)
            # Note: (tn + fp) is the Total Negatives
            current_specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            
            # Out of all thresholds that meet the recall target, we choose the one 
            # that maximizes specificity (maximizing case reduction)
            if current_specificity > best_specificity:
                best_specificity = current_specificity
                best_threshold = tau

    # Translate Specificity into Case Volume Reduction
    # Case Volume Reduction = Specificity * (Proportion of Negative Cases)
    proportion_negatives = Total_Negatives / len(y_true)
    case_volume_reduction = best_specificity * proportion_negatives * 100

    print(f"\nTarget Recall (Safety Threshold): {target_recall:.1%}")
    print(f"  - Optimal Threshold (τ): {best_threshold:.4f}")
    print(f"  - Specificity Achieved: {best_specificity:.1%}")
    print(f"  - Estimated Case Volume Reduction: {case_volume_reduction:.1f}%")
# Out:
# --- Comparison to Clinical Study (Specificity at High Recall) ---
# Total Test Samples: 624
# Total Unremarkable (Negative) Cases: 234
#
#
# Target Recall (Safety Threshold): 99.9%
#   - Optimal Threshold (τ): 0.2112
#   - Specificity Achieved: 32.5%
#   - Estimated Case Volume Reduction: 12.2%
#
# Target Recall (Safety Threshold): 99.0%
#   - Optimal Threshold (τ): 0.9379
#   - Specificity Achieved: 53.4%
#   - Estimated Case Volume Reduction: 20.0%
#
# Target Recall (Safety Threshold): 98.0%
#   - Optimal Threshold (τ): 0.9790
#   - Specificity Achieved: 58.5%
#   - Estimated Case Volume Reduction: 22.0%

# %% [markdown]
# ## 6.4 Comparison of Model Performance to a Clinical AI Study

# %% [markdown]
# PubMed Article, in National Library of Medicine: [Using AI to Identify Unremarkable Chest Radiographs for Automatic Reporting](https://pubmed.ncbi.nlm.nih.gov/39162628/)
#
# Radiology 2024 Aug;312(2):e240272. doi: 10.1148/radiol.240272.

# %%
# --- 1. DATA SETUP: DYNAMIC MODEL RESULTS ---
# NOTE: Ensure 'predictions' (raw scores from model.predict(TEST_DS)) 
#       and 'y_test_array' (the 0/1 true labels) are already defined.

# Define the variables for the calculation
y_pred_proba = predictions.flatten() 
y_true = y_test_array

# Target Recall levels from the study
TARGET_RECALLS = [0.999, 0.990, 0.980]

# Initializers for storing dynamic results
my_specificities = []
my_cvrs = []

# Total counts needed for Specificity and CVR calculation
Total_Negatives = (y_true == 0).sum()
Total_Samples = len(y_true)
proportion_negatives = Total_Negatives / Total_Samples
thresholds = np.linspace(0, 1, 1000)

print("--- Calculating Dynamic Model Metrics ---")

for target_recall in TARGET_RECALLS:
    best_specificity = 0
    best_threshold = 0
    
    # Iterate through all thresholds to find the one that meets the target recall
    for tau in thresholds:
        y_pred_binary = (y_pred_proba >= tau).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred_binary).ravel()
        
        current_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        
        # Find the threshold that meets or exceeds the target recall
        if current_recall >= target_recall:
            current_specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            
            # Maximize Specificity at the required Recall level
            if current_specificity > best_specificity:
                best_specificity = current_specificity
                best_threshold = tau

    # Store the results
    case_volume_reduction = best_specificity * proportion_negatives
    my_specificities.append(best_specificity)
    my_cvrs.append(case_volume_reduction)
    
    print(f"Recall {target_recall:.1%}: Spec={best_specificity:.1%} (CVR={case_volume_reduction:.1%})")


# --- 2. DATA SETUP: ARTICLE (STATIC) AND FINAL DATAFRAMES ---

# Hardcoded Article Results (Source: Article Text)
ARTICLE_RESULTS = {
    'Recall': TARGET_RECALLS,
    'Specificity': [0.245, 0.471, 0.527], 
    'CVR': [0.091, 0.175, 0.196]
}

# Dynamic Model Results
OUR_RESULTS = {
    'Recall': TARGET_RECALLS,
    'Specificity': my_specificities,
    'CVR': my_cvrs
}

# Create DataFrames for plotting
df_our = pd.DataFrame(OUR_RESULTS).set_index('Recall')
df_article = pd.DataFrame(ARTICLE_RESULTS).set_index('Recall')

df_comp_specificity = pd.DataFrame({
    'Our Model': df_our['Specificity'],
    'Article AI': df_article['Specificity']
})

df_comp_cvr = pd.DataFrame({
    'Our Model': df_our['CVR'],
    'Article AI': df_article['CVR']
})

# Format index for plot labels
df_comp_specificity.index = [f'{r*100:.1f}%' for r in df_comp_specificity.index]
df_comp_cvr.index = [f'{r*100:.1f}%' for r in df_comp_cvr.index]


# --- 3. PLOT GENERATION ---

plt.style.use('default') 
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --- Plot 1: Specificity Comparison ---
df_comp_specificity.plot(
    kind='bar', 
    ax=axes[0], 
    rot=0, 
    color=['#007ACC', '#F08080']
)
axes[0].set_title('Specificity Comparison at High Recall Thresholds', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Sensitivity (Recall) Threshold', fontsize=12)
axes[0].set_ylabel('Specificity (Proportion of Unremarkable Excluded)', fontsize=12)
axes[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.1%}'))
axes[0].legend(title='Model')
axes[0].grid(axis='y', linestyle='--', alpha=0.6)

for p in axes[0].patches:
    axes[0].annotate(f'{p.get_height()*100:.1f}%', 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=9)


# --- Plot 2: Case Volume Reduction (CVR) Comparison ---
df_comp_cvr.plot(
    kind='bar', 
    ax=axes[1], 
    rot=0, 
    color=['#007ACC', '#F08080']
)
axes[1].set_title('Case Volume Reduction (CVR) Comparison', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Sensitivity (Recall) Threshold', fontsize=12)
axes[1].set_ylabel('Estimated Reduction in Radiologist Workload', fontsize=12)
axes[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.1%}'))
axes[1].legend(title='Model')
axes[1].grid(axis='y', linestyle='--', alpha=0.6)

for p in axes[1].patches:
    axes[1].annotate(f'{p.get_height()*100:.1f}%', 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=9)

plt.tight_layout()
plt.suptitle('Comparison of Model Performance to a Clinical AI Study', y=1.03, fontsize=16, fontweight='heavy')
plt.savefig("dynamic_clinical_comparison_plots.png")


# --- 4. PRINT DETAILED METRIC COMPARISON TABLE ---
print("\n--- Detailed Metric Comparison Table ---")
comp_table = pd.DataFrame({
    'Recall': [f'{r*100:.1f}%' for r in OUR_RESULTS['Recall']],
    'Our Specificity': [f'{s*100:.1f}%' for s in OUR_RESULTS['Specificity']],
    'Article Specificity': [f'{s*100:.1f}%' for s in ARTICLE_RESULTS['Specificity']],
    'Our CVR': [f'{c*100:.1f}%' for c in OUR_RESULTS['CVR']],
    'Article CVR': [f'{c*100:.1f}%' for c in ARTICLE_RESULTS['CVR']],
})
print(comp_table.to_string(index=False))
# Out:
# --- Calculating Dynamic Model Metrics ---
# Recall 99.9%: Spec=32.5% (CVR=12.2%)
# Recall 99.0%: Spec=53.4% (CVR=20.0%)
# Recall 98.0%: Spec=58.5% (CVR=22.0%)
#
# --- Detailed Metric Comparison Table ---
# Recall Our Specificity Article Specificity Our CVR Article CVR
#  99.9%           32.5%               24.5%   12.2%        9.1%
#  99.0%           53.4%               47.1%   20.0%       17.5%
#  98.0%           58.5%               52.7%   22.0%       19.6%

# %% [markdown]
# ___
