# %% [markdown]
# # Deep Learning for Computer Vision
#
# ## Project 1 - Image Classification
#
# **Authors:** António Cruz (140129), David Isaac (120064), Erik Daskalyuk (120062), Ivan Magalhães (106586), Ricardo Pereira (120052)
#
# **Date:** 2025-11-09

# %% [markdown]
# # 0. Project Scope and Objectives
#
# ---

# %% [markdown]
# ## Scope
#
# This project focuses on developing an AI classification model to automatically analyze chest X-ray images and identify patients with a history of pneumonia. The solution leverages deep learning techniques to design, train and validate a convolutional neural network optimized for high recall, reflecting the clinical priority of not missing pneumonia cases.
#
# Through systematic experimentation with the model architecture and training configuration, the project evaluates different design choices (such as the number of convolutional filters, the use of Batch Normalization, Dropout and L2 regularization, and the learning rate strategy) and selects a final model that performs reliably on a held-out test set. Particular emphasis is placed on understanding how the decision threshold affects recall, precision and the pattern of false negatives and false positives.
#
# The system will:
#
# * Process and classify chest X-ray images into two categories: Normal and Pneumonia.
# * Enable the hospital to proactively identify at-risk patients for targeted awareness and preventive care in a retrospective screening setting.
#
# ## Objectives
#
# 1. Develop a baseline model
#    Implement an initial convolutional neural network for binary classification of chest X-ray images, providing a reference point for subsequent improvements.
#
# 2. Optimize model architecture and training configuration
#    Refine the network structure (number of filters, pooling strategy, dense head) and training setup (optimizer, learning rate, class weights) to improve performance while keeping the model relatively simple and interpretable.
#
# 3. Implement regularization and stabilization techniques
#    Apply L2 regularization, Batch Normalization, Dropout, class weighting, early stopping and learning rate scheduling to reduce overfitting and improve generalization to unseen data.
#
# 4. Evaluate and interpret model performance
#    Assess the final model using metrics such as accuracy, AUC, PR-AUC, precision, recall and F1-score, analyze confusion matrices and threshold-dependent behavior, and justify the choice of the recommended operating threshold.
#
# 5. Deliver a functional and documented solution
#    Provide a well-documented Python codebase and a report detailing the dataset, methodology, model architecture, training process, evaluation results and rationale behind the selected model and threshold strategy.
#
# Overall, the project aims to deliver a practical and recall-focused AI model that can assist healthcare professionals in the retrospective identification of patients with pneumonia history, supporting early preventive interventions and reduction of recurrence risk.

# %% [markdown]
# # 1. Introduction
#
# ---

# %% [markdown]
# This project addresses the healthcare challenge of identifying patients with a history of pneumonia from historical X-ray records, enabling targeted preventive care and reducing recurrence risk. Using Python and deep learning libraries, we developed a binary classification model explicitly optimized for high recall, prioritizing the detection of true pneumonia cases over minimizing false positives. This design aligns with the hospital’s goal of secondary prevention, where missing vulnerable patients (false negatives) poses a greater risk than contacting healthy individuals (false positives).
#
# The solution integrates data preprocessing, convolutional neural network design and systematic performance evaluation, with an emphasis on flexibility and robustness. In particular, the model is designed to support post-training threshold adjustments, allowing the hospital to choose operating points that balance recall and precision according to operational needs, from more comprehensive coverage to more resource-efficient outreach.
#
# ## 1.1 Environment Setup
#
# The project uses the following key libraries:
#
# * Scikit-learn: for evaluation and metric computation, including F1-score, confusion matrices and classification reports.
# * Keras and TensorFlow: for model definition, training and optimization, including layers, regularizers, callbacks and custom metrics.
# * Matplotlib, NumPy and Seaborn: for data visualization, analysis and exploratory data understanding.
#
# In the following sections, we describe the dataset and preprocessing pipeline, then present the model architecture, training procedure, evaluation strategy and final conclusions.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve
from sklearn.utils import class_weight as sk_class_weight

import tensorflow as tf
from keras import Input, models, layers, regularizers
from keras.callbacks import ModelCheckpoint
from keras.utils import image_dataset_from_directory
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping
from keras.optimizers import AdamW
from keras.metrics import AUC, Precision, Recall

# %%
# Global configuration
SEED = 42                                        # Fixed random seed for reproducibility
BATCH_SIZE = 32                                  # Number of images per training batch
LEARNING_RATE = 1e-4                             # Initial learning rate for the optimizer
CHECKPOINT_PATH = "best_model_checkpoint.keras"  # File path to save the best model

# Set random seeds for reproducibility across libraries
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # 2. Data Understanding
#
# ---

# %% [markdown]
# ## 2.1 Dataset Overview
#
# The Chest X-Ray Images (Pneumonia) dataset is a widely used medical imaging dataset curated for the detection and classification of pneumonia from chest X-ray images. It was originally made available by Daniel Kermany et al. (2018) on Kaggle and is derived from pediatric patients (aged approximately 1–5 years) treated at the Guangzhou Women and Children’s Medical Center.
#
# This dataset is intended to support research in medical image analysis, especially for developing and evaluating deep learning models for automated pneumonia detection. In this project, the images are converted to standardized grayscale inputs of 256×256 pixels, and separate subsets are constructed for training, validation and testing to allow for fair performance estimation on unseen data.

# %% [markdown]
# ## 2.2 Data Description
#
# The dataset contains chest X-ray images categorized into two primary classes:
#
# * Normal: X-ray scans of patients with no radiological signs of pneumonia.
# * Pneumonia: X-ray scans showing lung opacities consistent with pneumonia.
#
# Within the Pneumonia label, the original dataset distinguishes two subcategories:
#
# * Bacterial pneumonia
# * Viral pneumonia
#
# For the purposes of this project, these subcategories are treated as a single Pneumonia class, since the clinical objective is to identify patients with a history of pneumonia in general, regardless of the specific etiology.

# %% [markdown]
# ## 2.3 Data Characteristics
#
# * Format: JPEG chest X-ray images
# * Classes: 2 (Normal, Pneumonia)
# * Label encoding used in this project:
#
#   * 0 → Normal
#   * 1 → Pneumonia
#
# All images are loaded in grayscale mode and resized to a fixed resolution of 256×256 pixels before being fed to the model, ensuring consistent input shape across the dataset.

# %% [markdown]
# ## 2.4 Data Processing

# %%
# Set paths for train and test datasets
train_dir = "./chest_xray/train"
test_dir = "./chest_xray/test"

# %%
# Parameters
batch_size = BATCH_SIZE
img_size = (256, 256)

# %%
# Load datasets first without batching
train_dataset_unbatched = image_dataset_from_directory(
	train_dir,
	labels='inferred',
	label_mode='int',
	image_size=img_size,
	color_mode='grayscale',
	batch_size=None,
	shuffle=False,
	class_names=['NORMAL','PNEUMONIA']
)

test_dataset_unbatched = image_dataset_from_directory(
	test_dir,
	labels='inferred',
	label_mode='int',
	image_size=img_size,
	color_mode='grayscale',
	batch_size=None,
	shuffle=False,
	class_names=['NORMAL','PNEUMONIA']
)

# Convert to grayscale
# (loaded directly as grayscale above)
train_dataset_gray = train_dataset_unbatched.cache()
test_dataset_gray = test_dataset_unbatched.cache()
# Out:
# Found 5232 files belonging to 2 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763930758.857586    3201 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21456 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 624 files belonging to 2 classes.

# %%
# Helper function to extract one image by class label
def get_example_by_label(dataset, label):
    for image, lbl in dataset:
        if lbl.numpy() == label:
            return image.numpy().squeeze(), lbl.numpy()
    return None, None

# Get one NORMAL (0) and one PNEUMONIA (1) image from train and test sets
train_normal_img, _ = get_example_by_label(train_dataset_unbatched, 0)
train_pneumonia_img, _ = get_example_by_label(train_dataset_unbatched, 1)
test_normal_img, _ = get_example_by_label(test_dataset_unbatched, 0)
test_pneumonia_img, _ = get_example_by_label(test_dataset_unbatched, 1)

# Plot all 4 images in a single row
plt.figure(figsize=(16, 4))

titles = [
    'Train - NORMAL',
    'Train - PNEUMONIA',
    'Test - NORMAL',
    'Test - PNEUMONIA'
]

images = [
    train_normal_img,
    train_pneumonia_img,
    test_normal_img,
    test_pneumonia_img
]

for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 1** - Chest X-ray examples from the training and test sets (NORMAL and PNEUMONIA classes).

# %% [markdown]
# To gain a deeper understanding of the model's performance, it's essential to analyze the weight distribution of each class across the entire dataset.

# %%
# Collect labels from the training dataset
all_labels = []

for _, y in train_dataset_gray:   # or train_dataset if you've already split
	y_np = y.numpy().astype("int32").ravel()
	all_labels.extend(y_np.tolist())

all_labels = np.array(all_labels)

classes = np.array([0, 1])

# Compute balanced class weights
class_weights_array = sk_class_weight.compute_class_weight(
	class_weight="balanced",
	classes=classes,
	y=all_labels
)

# Put them in a dict for Keras
class_weight_dict = {int(cls): float(w) for cls, w in zip(classes, class_weights_array)}

print("Class counts:", {c: int((all_labels == c).sum()) for c in classes})
print("Class weights:", class_weight_dict)
# Out:
# Class counts: {np.int64(0): 1349, np.int64(1): 3883}
# Class weights: {0: 1.939214232765011, 1: 0.6737058975019315}
# 2025-11-23 20:46:02.620052: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# In the following plot, the weight distribution across each class in the dataset is clearly shown. The dataset consists of 26% images of the NORMAL class and 74% images of the PNEUMONIA class.
#
# This class imbalance could negatively impact model performance, as the model may become biased toward classifying images as PNEUMONIA, potentially leading to poorer performance on the NORMAL class.

# %%
# Prepare data for plotting
classes = ['NORMAL', 'PNEUMONIA']
class_indices = [0, 1]

# Compute counts from all_labels
class_counts = {c: int((all_labels == c).sum()) for c in class_indices}
counts = [class_counts[0], class_counts[1]]

# Extract weights from dict
weights = [class_weight_dict[0], class_weight_dict[1]]

# Plotting (unchanged)
fig, ax1 = plt.subplots(figsize=(6.5, 4.5))

ax1.bar(
	classes,
	counts,
	color='skyblue',
	alpha=0.7,
	label="Class Distribution",
	width=0.4,
	align='center'
)

ax2 = ax1.twinx()
ax2.plot(
	classes,
	weights,
	color='red',
	marker='o',
	label="Class Weights",
	linewidth=2
)

ax1.set_title('Class Distribution and Weights in Training Dataset\n', fontsize=14)
ax1.set_xlabel('Class', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax2.set_ylabel('Class Weights', fontsize=12)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 2** - Class distribution and corresponding training weights for NORMAL and PNEUMONIA in the training dataset.

# %% [markdown]
# In this step, we split the training data to create a validation set, allowing us to monitor and evaluate the model's performance throughout the training process.

# %%
# After the class_weight cell where you built all_labels
total = len(all_labels)  # number of samples in train_dataset_gray

# Shuffle and split 10% validation
val_samples = int(0.10 * total)

shuffled_dataset = train_dataset_gray.shuffle(
	buffer_size=min(total, 10_000),
	seed=SEED,
	reshuffle_each_iteration=False  # stable split
)

val_dataset = shuffled_dataset.take(val_samples)
train_dataset = shuffled_dataset.skip(val_samples)

# %%
# Define normalization
def normalize_images(images, labels):
	images = tf.math.truediv(tf.cast(images, tf.float32), 255.0)
	return images, labels

# %% [markdown]
# We apply normalization to each dataset in order to enhance model generalization and improve its robustness during training.

# %%
# Normalize all the splits
train_dataset = train_dataset.map(
	normalize_images, num_parallel_calls=tf.data.AUTOTUNE
)
val_dataset = val_dataset.map(
	normalize_images, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset_gray = test_dataset_gray.map(
	normalize_images, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# We prepare the datasets for training and evaluation by batching and prefetching the data using the `tf.data` API.
#
# * Batching:
#   The training, validation and test datasets are batched with the chosen `batch_size`, so that examples are grouped into manageable chunks for efficient processing on the GPU/CPU. In this step:
#
#   * `train_for_fit_dataset`, `val_dataset_gray` and `test_dataset_gray` are all converted into batched datasets.
#
# * Prefetching:
#   To improve performance, we call `.prefetch(tf.data.AUTOTUNE)` on each dataset. This allows the input pipeline to prepare the next batch in the background while the model is training or evaluating on the current batch, reducing idle time and improving throughput.
#
# After batching and prefetching, we validate the setup by inspecting one batch from the training and validation datasets, checking the batch shapes and the range of pixel values. This confirms that the data is being fed to the model with the expected dimensions and normalization.

# %%
# Batch
train_for_fit_dataset = train_dataset.batch(batch_size)
val_dataset_gray = val_dataset.batch(batch_size)
test_dataset_gray = test_dataset_gray.batch(batch_size)

# Prefetch for performance
train_for_fit_dataset = train_for_fit_dataset.prefetch(tf.data.AUTOTUNE)
val_dataset_gray = val_dataset_gray.prefetch(tf.data.AUTOTUNE)
test_dataset_gray = test_dataset_gray.prefetch(tf.data.AUTOTUNE)

# %%
# Validate setup
print("\n=== Dataset Verification ===")
for images, labels in train_for_fit_dataset.take(1):
	print(f"Training batch shape: {images.shape}")
	print(f"Training labels shape: {labels.shape}")
	print(f"Training image range: [{tf.reduce_min(images):.3f}, {tf.reduce_max(images):.3f}]")

for images, labels in val_dataset_gray.take(1):
	print(f"Validation batch shape: {images.shape}")
	print(f"Validation labels shape: {labels.shape}")
	print(f"Validation image range: [{tf.reduce_min(images):.3f}, {tf.reduce_max(images):.3f}]")
# Out:
# === Dataset Verification ===
# Training batch shape: (32, 256, 256, 1)
# Training labels shape: (32,)
# Training image range: [0.000, 1.000]
# Validation batch shape: (32, 256, 256, 1)
# Validation labels shape: (32,)
# Validation image range: [0.000, 1.000]
# 2025-11-23 20:46:03.339795: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # 3. Training
#
# ---

# %% [markdown]
# ## 3.1 Training Configuration and Callbacks
#
# In this section, we build and train a Convolutional Neural Network (CNN) to classify chest X-ray images into two categories: Normal and Pneumonia. The model is trained on the preprocessed grayscale dataset using the AdamW optimizer, L2 regularization, Batch Normalization and Dropout. To improve generalization and avoid overfitting, we use three Keras callbacks: ModelCheckpoint, EarlyStopping and ReduceLROnPlateau.
#
# ModelCheckpoint and EarlyStopping monitor the validation PR-AUC (`val_pr_auc`), which is well suited for imbalanced problems and directly reflects the balance between precision and recall. ReduceLROnPlateau monitors the validation loss (val_loss) and reduces the learning rate when progress stalls, helping the optimizer make finer updates later in training.
#
# The main callback parameters used in this project are summarized below.
#
# **Table 1** – Model callback parameter descriptions
#
# | Parameter              | Meaning                                                                                                                                                                                |
# | :--------------------- | :------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `monitor`              | Metric being tracked to decide whether there is an improvement. In this project: `val_pr_auc` for model checkpointing and early stopping, and `val_loss` for learning rate scheduling. |
# | `patience`             | Number of epochs to wait without improvement in the monitored metric before stopping or reducing the learning rate.                                                                    |
# | `mode`                 | Direction of optimization for the monitored metric. For `val_pr_auc` we use `"max"` (higher is better); for `val_loss` we use `"min"` (lower is better).                               |
# | `save_best_only`       | When `True`, only saves the checkpoint corresponding to the best observed value of the monitored metric.                                                                               |
# | `save_weights_only`    | When `False`, saves the full model (architecture and weights) instead of just the weights.                                                                                             |
# | `verbose`              | Controls how much logging is printed during training when the callback is triggered.                                                                                                   |
# | `restore_best_weights` | When `True`, restores the model weights from the epoch with the best monitored metric after early stopping.                                                                            |
# | `min_lr`               | Minimum learning rate allowed by the scheduler; prevents the learning rate from being reduced too far.                                                                                 |
# | `factor`               | Multiplicative factor used to reduce the learning rate when the monitored metric stops improving.                                                                                      |

# %% [markdown]
# ## 3.2 Model Checkpoint Saving
#
# We set up a callback to save the best model during training based on validation PR-AUC rather than raw accuracy. This is more appropriate for an imbalanced, clinically oriented problem where the balance between precision and recall is more important than overall accuracy.
#
# The ModelCheckpoint callback:
#
# * Saves the model to the file path defined by `CHECKPOINT_PATH`.
# * Monitors the `val_pr_auc` metric on the validation set.
# * Keeps only the model corresponding to the highest observed `val_pr_auc` during training.
#
# By saving the best validation-PR-AUC checkpoint instead of simply using the weights from the final epoch, we reduce the risk of overfitting. If performance on the validation set starts to degrade after a certain point, we still retain the version of the model that showed the best generalization according to the chosen metric.

# %%
# Best model checkpoint saving
best_model_callback = ModelCheckpoint(
    filepath=CHECKPOINT_PATH,
    monitor="val_pr_auc",
    mode="max",
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

# %% [markdown]
# ## 3.3 Early Stopping
#
# We also use an EarlyStopping callback to automatically stop training when further epochs no longer improve the model’s performance on the validation set.
#
# In this project:
#
# * EarlyStopping monitors the validation PR-AUC (`val_pr_auc`), not the training metrics.
# * If `val_pr_auc` does not improve for a specified number of epochs (the patience value), training is stopped.
# * With `restore_best_weights=True`, the model weights are rolled back to those from the epoch with the highest `val_pr_auc`.
#
# This prevents wasting epochs once the model has effectively converged and reduces overfitting by avoiding continued training after validation performance has stopped improving, while still keeping the best-performing version of the model for subsequent evaluation.

# %%
# Early stopping
early_stopping = EarlyStopping(
    monitor="val_pr_auc",
    mode="max",
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# ## 3.4 Learning Rate
#
# The learning rate is a key hyperparameter that controls how much the model weights are updated during training. If it is too high, the optimizer may overshoot good minima and converge to a suboptimal solution; if it is too low, training can become very slow or get stuck.
#
# In this project, we use the AdamW optimizer with an initial learning rate defined by `LEARNING_RATE`, together with a learning rate scheduler based on the `ReduceLROnPlateau` callback. The scheduler:
#
# * Monitors the validation loss (`val_loss`).
# * If `val_loss` does not improve for a certain number of epochs (patience), it reduces the learning rate by a given factor.
# * Ensures that the learning rate never goes below a specified minimum (`min_lr`).
#
# This strategy allows the model to make relatively large updates in the early stages of training, then gradually switch to smaller, finer updates once progress slows. In practice, this helps the model converge more reliably and can improve final validation performance without manual tuning of the learning rate schedule.

# %%
# Learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    mode="min",
    factor=0.5,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

# %% [markdown]
# ## 3.5 Build and Compile
#
# The CNN model is created using the Keras Sequential API to perform binary classification of 256×256 grayscale chest X-ray images into Normal and Pneumonia. It combines three convolutional blocks, global average pooling and a small dense head with L2 regularization, Batch Normalization, Dropout and AdamW optimization. The main architectural and training choices are summarized in Table 2.
#
#
# **Table 2** - Summary of the CNN architecture, training configuration and optimization components
#
# | Component              | Description                                                                                                                                                                                                                                                                                    |
# | ---------------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Input layer            | Accepts grayscale images of size 256×256 pixels, with input shape (256, 256, 1).                                                                                                                                                                                                               |
# | Convolutional layers   | Three convolutional layers with 64, 128 and 256 filters, respectively, using 3×3 kernels and ReLU activation. Each convolutional layer is followed by Batch Normalization and a MaxPooling2D layer to reduce spatial dimensions and improve training stability.                                |
# | Global average pooling | A GlobalAveragePooling2D layer reduces the final feature maps to a single feature vector per image by averaging each feature map. This greatly reduces the number of parameters compared with Flatten, helps prevent overfitting and preserves the most salient information from each channel. |
# | Dense layers           | A fully connected layer with 128 neurons and ReLU activation, followed by a Dropout layer with rate 0.33, and an output layer with 1 neuron and sigmoid activation for binary classification (probability of Pneumonia).                                                                       |
# | Regularization         | L2 regularization is applied to the convolutional and dense layers. Batch Normalization after each convolutional layer and Dropout after the dense layer further help to stabilize training and reduce overfitting.                                                                            |
# | Optimizer              | Uses the AdamW optimizer with a specified learning rate and weight decay to improve convergence and regularization of the weights.                                                                                                                                                             |
# | Metrics                | During training and validation the model is monitored using accuracy, AUC, PR-AUC, precision and recall.                                                                                                                                                                                       |
# | Callbacks              | Includes model checkpointing (monitoring validation PR-AUC), early stopping (also on validation PR-AUC) and learning rate scheduling (monitoring validation loss) to adapt the learning rate during training and prevent overfitting.                                                          |
# | Training               | The model is trained on the training dataset, validated on a separate validation set, and class weights are used to compensate for the imbalance between Normal and Pneumonia cases.                                                                                                           |
# | Final result           | The training process is monitored with the callbacks, and the model checkpoint with the best validation PR-AUC is saved for later evaluation on the held-out test dataset.                                                                                                                     |

# %%
model = models.Sequential([

	# Input layer for grayscale images (256x256x1)
    Input(shape=(256, 256, 1)),

    # First convolutional block: 64 filters, same padding to keep spatial size
	layers.Conv2D(64, (3, 3),
               activation="relu",
               kernel_initializer="he_uniform",
               kernel_regularizer=regularizers.l2(1e-4),
               padding="same"
    ),

	# Batch normalization to stabilize and speed up training
    layers.BatchNormalization(), 

    # Max pooling to downsample feature maps
	layers.MaxPooling2D((2, 2)),


	# Second convolutional block: 128 filters
    layers.Conv2D(128, (3, 3),
               activation="relu",
               kernel_initializer="he_uniform",
               kernel_regularizer=regularizers.l2(1e-4),
               padding="same"), 
	layers.BatchNormalization(),
	layers.MaxPooling2D((2, 2)),


	# Third convolutional block: 256 filters
    layers.Conv2D(256, (3, 3),
               activation="relu",
               kernel_initializer="he_uniform",
               kernel_regularizer=regularizers.l2(1e-4),
               padding="same"
    ),
	layers.BatchNormalization(),
	layers.MaxPooling2D((2, 2)),


	# Global average pooling to reduce each feature map to a single value
	layers.GlobalAveragePooling2D(),


    # Dense layer before output
	layers.Dense(128,
              activation="relu",
              kernel_initializer="he_uniform",
              kernel_regularizer=regularizers.l2(1e-4)),
    # Dropout for additional regularization
    layers.Dropout(0.33),


	# Output layer for binary classification (Normal vs Pneumonia)
    layers.Dense(1, activation="sigmoid"),
])

# ReLU is used in hidden layers to introduce non-linearity and support deep training.
# Sigmoid in the output layer produces a probability for the positive class (Pneumonia).
# He uniform initialization is suited to ReLU activations and helps stable signal propagation.
# L2 regularization penalizes large weights in conv and dense layers to help prevent overfitting.

model.compile(
	optimizer=AdamW(
        learning_rate=LEARNING_RATE,
        weight_decay=1e-4
    ),
    # Binary cross-entropy is appropriate for binary classification with sigmoid outputs.
    loss="binary_crossentropy",
	# Metrics used to monitor training and validation performance.
    metrics=[ 
        "accuracy",
        AUC(name="auc"),
        AUC(curve="PR", name="pr_auc"),
        Recall(name="recall"),
        Precision(name="precision")
    ]
)

# Train the model on the training dataset and validate on the validation dataset.
history = model.fit( 
    train_for_fit_dataset,
    validation_data=val_dataset_gray,
    epochs=100,
    callbacks=[
        best_model_callback,
        lr_scheduler,
        early_stopping,
    ],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# 2025-11-23 20:46:04.812479: I external/local_xla/xla/service/service.cc:163] XLA service 0x76322c006930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-23 20:46:04.812511: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-11-23 20:46:04.880309: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-23 20:46:05.107629: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-11-23 20:46:05.201502: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-23 20:46:05.201536: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-23 20:46:05.201543: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-23 20:46:05.567022: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1248', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-23 20:46:05.675861: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2168', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-23 20:46:05.770192: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1248', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-23 20:46:08.005208: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-11-23 20:46:08.366959: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.361807994s
# Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
#   1/148 ━━━━━━━━━━━━━━━━━━━━ 24:28 10s/step - accuracy: 0.4688 - auc: 0.7660 - loss: 0.7219 - pr_auc: 0.9401 - precision: 1.0000 - recall: 0.3462
# I0000 00:00:1763930773.527388    3336 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7873 - auc: 0.8981 - loss: 0.5181 - pr_auc: 0.9579 - precision: 0.9543 - recall: 0.7479
# Epoch 1: val_pr_auc improved from None to 0.89457, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.8490 - auc: 0.9336 - loss: 0.4421 - pr_auc: 0.9761 - precision: 0.9690 - recall: 0.8226 - val_accuracy: 0.7514 - val_auc: 0.7421 - val_loss: 0.7452 - val_pr_auc: 0.8946 - val_precision: 0.7514 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 2/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8991 - auc: 0.9602 - loss: 0.3619 - pr_auc: 0.9854 - precision: 0.9742 - recall: 0.8877
# Epoch 2: val_pr_auc improved from 0.89457 to 0.97919, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.9000 - auc: 0.9638 - loss: 0.3481 - pr_auc: 0.9873 - precision: 0.9788 - recall: 0.8842 - val_accuracy: 0.7514 - val_auc: 0.9385 - val_loss: 0.8689 - val_pr_auc: 0.9792 - val_precision: 0.7514 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9159 - auc: 0.9716 - loss: 0.3237 - pr_auc: 0.9896 - precision: 0.9778 - recall: 0.9074
# Epoch 3: val_pr_auc improved from 0.97919 to 0.98975, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - accuracy: 0.9146 - auc: 0.9733 - loss: 0.3166 - pr_auc: 0.9902 - precision: 0.9789 - recall: 0.9043 - val_accuracy: 0.7514 - val_auc: 0.9676 - val_loss: 0.6725 - val_pr_auc: 0.9898 - val_precision: 0.7524 - val_recall: 0.9975 - learning_rate: 1.0000e-04
# Epoch 4/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9261 - auc: 0.9772 - loss: 0.3005 - pr_auc: 0.9918 - precision: 0.9787 - recall: 0.9205
# Epoch 4: val_pr_auc improved from 0.98975 to 0.99314, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.9240 - auc: 0.9783 - loss: 0.2954 - pr_auc: 0.9920 - precision: 0.9795 - recall: 0.9166 - val_accuracy: 0.8681 - val_auc: 0.9779 - val_loss: 0.3769 - val_pr_auc: 0.9931 - val_precision: 0.8537 - val_recall: 0.9949 - learning_rate: 1.0000e-04
# Epoch 5/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9301 - auc: 0.9808 - loss: 0.2812 - pr_auc: 0.9929 - precision: 0.9794 - recall: 0.9254
# Epoch 5: val_pr_auc improved from 0.99314 to 0.99438, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 104ms/step - accuracy: 0.9269 - auc: 0.9810 - loss: 0.2807 - pr_auc: 0.9932 - precision: 0.9816 - recall: 0.9186 - val_accuracy: 0.9388 - val_auc: 0.9817 - val_loss: 0.2620 - val_pr_auc: 0.9944 - val_precision: 0.9640 - val_recall: 0.9542 - learning_rate: 1.0000e-04
# Epoch 6/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9410 - auc: 0.9833 - loss: 0.2676 - pr_auc: 0.9943 - precision: 0.9811 - recall: 0.9385
# Epoch 6: val_pr_auc improved from 0.99438 to 0.99439, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.9393 - auc: 0.9838 - loss: 0.2660 - pr_auc: 0.9942 - precision: 0.9828 - recall: 0.9344 - val_accuracy: 0.9350 - val_auc: 0.9819 - val_loss: 0.2589 - val_pr_auc: 0.9944 - val_precision: 0.9591 - val_recall: 0.9542 - learning_rate: 1.0000e-04
# Epoch 7/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9432 - auc: 0.9866 - loss: 0.2554 - pr_auc: 0.9954 - precision: 0.9824 - recall: 0.9403
# Epoch 7: val_pr_auc improved from 0.99439 to 0.99484, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - accuracy: 0.9414 - auc: 0.9871 - loss: 0.2529 - pr_auc: 0.9956 - precision: 0.9837 - recall: 0.9364 - val_accuracy: 0.9369 - val_auc: 0.9833 - val_loss: 0.2533 - val_pr_auc: 0.9948 - val_precision: 0.9615 - val_recall: 0.9542 - learning_rate: 1.0000e-04
# Epoch 8/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9494 - auc: 0.9876 - loss: 0.2463 - pr_auc: 0.9957 - precision: 0.9857 - recall: 0.9457
# Epoch 8: val_pr_auc improved from 0.99484 to 0.99532, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - accuracy: 0.9495 - auc: 0.9881 - loss: 0.2436 - pr_auc: 0.9959 - precision: 0.9868 - recall: 0.9444 - val_accuracy: 0.9426 - val_auc: 0.9850 - val_loss: 0.2448 - val_pr_auc: 0.9953 - val_precision: 0.9618 - val_recall: 0.9618 - learning_rate: 1.0000e-04
# Epoch 9/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9506 - auc: 0.9894 - loss: 0.2360 - pr_auc: 0.9962 - precision: 0.9850 - recall: 0.9478
# Epoch 9: val_pr_auc improved from 0.99532 to 0.99558, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.9507 - auc: 0.9897 - loss: 0.2350 - pr_auc: 0.9964 - precision: 0.9860 - recall: 0.9470 - val_accuracy: 0.9426 - val_auc: 0.9860 - val_loss: 0.2483 - val_pr_auc: 0.9956 - val_precision: 0.9789 - val_recall: 0.9440 - learning_rate: 1.0000e-04
# Epoch 10/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9547 - auc: 0.9906 - loss: 0.2281 - pr_auc: 0.9967 - precision: 0.9869 - recall: 0.9515
# Epoch 10: val_pr_auc improved from 0.99558 to 0.99570, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 21s 81ms/step - accuracy: 0.9526 - auc: 0.9905 - loss: 0.2290 - pr_auc: 0.9967 - precision: 0.9880 - recall: 0.9476 - val_accuracy: 0.9426 - val_auc: 0.9862 - val_loss: 0.2447 - val_pr_auc: 0.9957 - val_precision: 0.9789 - val_recall: 0.9440 - learning_rate: 1.0000e-04
# Epoch 11/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9566 - auc: 0.9918 - loss: 0.2187 - pr_auc: 0.9972 - precision: 0.9868 - recall: 0.9543
# Epoch 11: val_pr_auc improved from 0.99570 to 0.99635, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.9554 - auc: 0.9920 - loss: 0.2189 - pr_auc: 0.9973 - precision: 0.9872 - recall: 0.9521 - val_accuracy: 0.9484 - val_auc: 0.9884 - val_loss: 0.2281 - val_pr_auc: 0.9964 - val_precision: 0.9741 - val_recall: 0.9567 - learning_rate: 1.0000e-04
# Epoch 12/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9598 - auc: 0.9922 - loss: 0.2147 - pr_auc: 0.9973 - precision: 0.9880 - recall: 0.9575
# Epoch 12: val_pr_auc did not improve from 0.99635
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9590 - auc: 0.9923 - loss: 0.2137 - pr_auc: 0.9974 - precision: 0.9887 - recall: 0.9556 - val_accuracy: 0.9484 - val_auc: 0.9878 - val_loss: 0.2285 - val_pr_auc: 0.9962 - val_precision: 0.9766 - val_recall: 0.9542 - learning_rate: 1.0000e-04
# Epoch 13/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9637 - auc: 0.9937 - loss: 0.2044 - pr_auc: 0.9978 - precision: 0.9918 - recall: 0.9590
# Epoch 13: val_pr_auc did not improve from 0.99635
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 20s 76ms/step - accuracy: 0.9622 - auc: 0.9936 - loss: 0.2045 - pr_auc: 0.9978 - precision: 0.9914 - recall: 0.9573 - val_accuracy: 0.9446 - val_auc: 0.9883 - val_loss: 0.2268 - val_pr_auc: 0.9963 - val_precision: 0.9596 - val_recall: 0.9669 - learning_rate: 1.0000e-04
# Epoch 14/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9635 - auc: 0.9945 - loss: 0.1952 - pr_auc: 0.9982 - precision: 0.9902 - recall: 0.9603
# Epoch 14: val_pr_auc improved from 0.99635 to 0.99649, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.9622 - auc: 0.9941 - loss: 0.1987 - pr_auc: 0.9980 - precision: 0.9899 - recall: 0.9587 - val_accuracy: 0.9465 - val_auc: 0.9888 - val_loss: 0.2357 - val_pr_auc: 0.9965 - val_precision: 0.9867 - val_recall: 0.9415 - learning_rate: 1.0000e-04
# Epoch 15/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9689 - auc: 0.9955 - loss: 0.1895 - pr_auc: 0.9985 - precision: 0.9909 - recall: 0.9669
# Epoch 15: val_pr_auc improved from 0.99649 to 0.99722, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.9667 - auc: 0.9955 - loss: 0.1892 - pr_auc: 0.9985 - precision: 0.9912 - recall: 0.9636 - val_accuracy: 0.9503 - val_auc: 0.9911 - val_loss: 0.2212 - val_pr_auc: 0.9972 - val_precision: 0.9920 - val_recall: 0.9415 - learning_rate: 1.0000e-04
# Epoch 16/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9709 - auc: 0.9961 - loss: 0.1820 - pr_auc: 0.9987 - precision: 0.9916 - recall: 0.9691
# Epoch 16: val_pr_auc did not improve from 0.99722
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9686 - auc: 0.9957 - loss: 0.1842 - pr_auc: 0.9986 - precision: 0.9923 - recall: 0.9650 - val_accuracy: 0.9484 - val_auc: 0.9898 - val_loss: 0.2167 - val_pr_auc: 0.9968 - val_precision: 0.9692 - val_recall: 0.9618 - learning_rate: 1.0000e-04
# Epoch 17/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9751 - auc: 0.9965 - loss: 0.1760 - pr_auc: 0.9988 - precision: 0.9935 - recall: 0.9728
# Epoch 17: val_pr_auc improved from 0.99722 to 0.99743, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.9718 - auc: 0.9963 - loss: 0.1771 - pr_auc: 0.9988 - precision: 0.9932 - recall: 0.9685 - val_accuracy: 0.9465 - val_auc: 0.9918 - val_loss: 0.2294 - val_pr_auc: 0.9974 - val_precision: 0.9919 - val_recall: 0.9364 - learning_rate: 1.0000e-04
# Epoch 18/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9746 - auc: 0.9974 - loss: 0.1671 - pr_auc: 0.9991 - precision: 0.9922 - recall: 0.9734
# Epoch 18: val_pr_auc did not improve from 0.99743
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.9739 - auc: 0.9965 - loss: 0.1732 - pr_auc: 0.9988 - precision: 0.9936 - recall: 0.9711 - val_accuracy: 0.9637 - val_auc: 0.9906 - val_loss: 0.2171 - val_pr_auc: 0.9971 - val_precision: 0.9921 - val_recall: 0.9593 - learning_rate: 1.0000e-04
# Epoch 19/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9758 - auc: 0.9969 - loss: 0.1684 - pr_auc: 0.9990 - precision: 0.9936 - recall: 0.9737
# Epoch 19: val_pr_auc improved from 0.99743 to 0.99798, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.9735 - auc: 0.9968 - loss: 0.1705 - pr_auc: 0.9989 - precision: 0.9933 - recall: 0.9708 - val_accuracy: 0.9522 - val_auc: 0.9935 - val_loss: 0.2384 - val_pr_auc: 0.9980 - val_precision: 1.0000 - val_recall: 0.9364 - learning_rate: 1.0000e-04
# Epoch 20/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9783 - auc: 0.9978 - loss: 0.1586 - pr_auc: 0.9993 - precision: 0.9963 - recall: 0.9744
# Epoch 20: val_pr_auc did not improve from 0.99798
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9766 - auc: 0.9973 - loss: 0.1634 - pr_auc: 0.9991 - precision: 0.9962 - recall: 0.9722 - val_accuracy: 0.9503 - val_auc: 0.9930 - val_loss: 0.2376 - val_pr_auc: 0.9978 - val_precision: 0.9946 - val_recall: 0.9389 - learning_rate: 1.0000e-04
# Epoch 21/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9798 - auc: 0.9980 - loss: 0.1557 - pr_auc: 0.9994 - precision: 0.9946 - recall: 0.9781
# Epoch 21: val_pr_auc improved from 0.99798 to 0.99812, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9788 - auc: 0.9981 - loss: 0.1559 - pr_auc: 0.9994 - precision: 0.9953 - recall: 0.9759 - val_accuracy: 0.9484 - val_auc: 0.9936 - val_loss: 0.2568 - val_pr_auc: 0.9981 - val_precision: 1.0000 - val_recall: 0.9313 - learning_rate: 5.0000e-05
# Epoch 22/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9834 - auc: 0.9985 - loss: 0.1468 - pr_auc: 0.9995 - precision: 0.9955 - recall: 0.9821
# Epoch 22: val_pr_auc improved from 0.99812 to 0.99864, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9807 - auc: 0.9983 - loss: 0.1494 - pr_auc: 0.9994 - precision: 0.9959 - recall: 0.9779 - val_accuracy: 0.9598 - val_auc: 0.9957 - val_loss: 0.2215 - val_pr_auc: 0.9986 - val_precision: 1.0000 - val_recall: 0.9466 - learning_rate: 5.0000e-05
# Epoch 23/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9859 - auc: 0.9989 - loss: 0.1422 - pr_auc: 0.9996 - precision: 0.9966 - recall: 0.9844
# Epoch 23: val_pr_auc improved from 0.99864 to 0.99867, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9836 - auc: 0.9987 - loss: 0.1460 - pr_auc: 0.9996 - precision: 0.9968 - recall: 0.9811 - val_accuracy: 0.9598 - val_auc: 0.9958 - val_loss: 0.2196 - val_pr_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.9466 - learning_rate: 5.0000e-05
# Epoch 24/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9843 - auc: 0.9989 - loss: 0.1406 - pr_auc: 0.9996 - precision: 0.9974 - recall: 0.9815
# Epoch 24: val_pr_auc did not improve from 0.99867
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.9828 - auc: 0.9988 - loss: 0.1432 - pr_auc: 0.9996 - precision: 0.9980 - recall: 0.9788 - val_accuracy: 0.9484 - val_auc: 0.9939 - val_loss: 0.2665 - val_pr_auc: 0.9982 - val_precision: 1.0000 - val_recall: 0.9313 - learning_rate: 5.0000e-05
# Epoch 25/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9863 - auc: 0.9992 - loss: 0.1375 - pr_auc: 0.9997 - precision: 0.9967 - recall: 0.9848
# Epoch 25: val_pr_auc improved from 0.99867 to 0.99874, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.9847 - auc: 0.9991 - loss: 0.1390 - pr_auc: 0.9997 - precision: 0.9980 - recall: 0.9814 - val_accuracy: 0.9618 - val_auc: 0.9960 - val_loss: 0.1937 - val_pr_auc: 0.9987 - val_precision: 0.9973 - val_recall: 0.9517 - learning_rate: 2.5000e-05
# Epoch 26/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9879 - auc: 0.9991 - loss: 0.1349 - pr_auc: 0.9997 - precision: 0.9983 - recall: 0.9853
# Epoch 26: val_pr_auc improved from 0.99874 to 0.99882, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.9849 - auc: 0.9989 - loss: 0.1385 - pr_auc: 0.9996 - precision: 0.9977 - recall: 0.9819 - val_accuracy: 0.9656 - val_auc: 0.9962 - val_loss: 0.1967 - val_pr_auc: 0.9988 - val_precision: 1.0000 - val_recall: 0.9542 - learning_rate: 2.5000e-05
# Epoch 27/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9870 - auc: 0.9994 - loss: 0.1335 - pr_auc: 0.9998 - precision: 0.9979 - recall: 0.9846
# Epoch 27: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.9866 - auc: 0.9993 - loss: 0.1355 - pr_auc: 0.9998 - precision: 0.9983 - recall: 0.9837 - val_accuracy: 0.9637 - val_auc: 0.9961 - val_loss: 0.1993 - val_pr_auc: 0.9988 - val_precision: 1.0000 - val_recall: 0.9517 - learning_rate: 2.5000e-05
# Epoch 28/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9876 - auc: 0.9994 - loss: 0.1318 - pr_auc: 0.9998 - precision: 0.9988 - recall: 0.9845
# Epoch 28: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.9868 - auc: 0.9993 - loss: 0.1343 - pr_auc: 0.9998 - precision: 0.9988 - recall: 0.9834 - val_accuracy: 0.9656 - val_auc: 0.9955 - val_loss: 0.2032 - val_pr_auc: 0.9986 - val_precision: 1.0000 - val_recall: 0.9542 - learning_rate: 2.5000e-05
# Epoch 29/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9898 - auc: 0.9995 - loss: 0.1300 - pr_auc: 0.9998 - precision: 0.9986 - recall: 0.9876
# Epoch 29: val_pr_auc did not improve from 0.99882
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - accuracy: 0.9877 - auc: 0.9994 - loss: 0.1326 - pr_auc: 0.9998 - precision: 0.9983 - recall: 0.9851 - val_accuracy: 0.9579 - val_auc: 0.9945 - val_loss: 0.2195 - val_pr_auc: 0.9984 - val_precision: 1.0000 - val_recall: 0.9440 - learning_rate: 2.5000e-05
# Epoch 30/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9902 - auc: 0.9996 - loss: 0.1279 - pr_auc: 0.9999 - precision: 0.9986 - recall: 0.9882
# Epoch 30: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.9887 - auc: 0.9994 - loss: 0.1311 - pr_auc: 0.9998 - precision: 0.9983 - recall: 0.9865 - val_accuracy: 0.9598 - val_auc: 0.9955 - val_loss: 0.2079 - val_pr_auc: 0.9986 - val_precision: 1.0000 - val_recall: 0.9466 - learning_rate: 1.2500e-05
# Epoch 31/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9906 - auc: 0.9996 - loss: 0.1264 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9878
# Epoch 31: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - accuracy: 0.9896 - auc: 0.9995 - loss: 0.1290 - pr_auc: 0.9998 - precision: 0.9994 - recall: 0.9865 - val_accuracy: 0.9618 - val_auc: 0.9947 - val_loss: 0.2031 - val_pr_auc: 0.9985 - val_precision: 1.0000 - val_recall: 0.9491 - learning_rate: 1.2500e-05
# Epoch 32/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9895 - auc: 0.9995 - loss: 0.1285 - pr_auc: 0.9998 - precision: 0.9990 - recall: 0.9869
# Epoch 32: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9896 - auc: 0.9995 - loss: 0.1297 - pr_auc: 0.9998 - precision: 0.9991 - recall: 0.9868 - val_accuracy: 0.9618 - val_auc: 0.9955 - val_loss: 0.1960 - val_pr_auc: 0.9986 - val_precision: 0.9947 - val_recall: 0.9542 - learning_rate: 1.2500e-05
# Epoch 33/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9901 - auc: 0.9995 - loss: 0.1274 - pr_auc: 0.9998 - precision: 0.9989 - recall: 0.9877
# Epoch 33: val_pr_auc did not improve from 0.99882
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - accuracy: 0.9894 - auc: 0.9995 - loss: 0.1292 - pr_auc: 0.9998 - precision: 0.9986 - recall: 0.9871 - val_accuracy: 0.9598 - val_auc: 0.9946 - val_loss: 0.2053 - val_pr_auc: 0.9984 - val_precision: 0.9973 - val_recall: 0.9491 - learning_rate: 1.2500e-05
# Epoch 34/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9909 - auc: 0.9997 - loss: 0.1252 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9883
# Epoch 34: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.9909 - auc: 0.9996 - loss: 0.1274 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9888 - val_accuracy: 0.9675 - val_auc: 0.9956 - val_loss: 0.1939 - val_pr_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 35/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9893 - auc: 0.9997 - loss: 0.1245 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9862
# Epoch 35: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9913 - auc: 0.9996 - loss: 0.1259 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9888 - val_accuracy: 0.9656 - val_auc: 0.9957 - val_loss: 0.1856 - val_pr_auc: 0.9987 - val_precision: 0.9973 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 36/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9905 - auc: 0.9996 - loss: 0.1257 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9880
# Epoch 36: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.9900 - auc: 0.9996 - loss: 0.1272 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9874 - val_accuracy: 0.9656 - val_auc: 0.9956 - val_loss: 0.1852 - val_pr_auc: 0.9987 - val_precision: 0.9973 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 37/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9905 - auc: 0.9996 - loss: 0.1255 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9878
# Epoch 37: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.9898 - auc: 0.9996 - loss: 0.1271 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9871 - val_accuracy: 0.9637 - val_auc: 0.9956 - val_loss: 0.1854 - val_pr_auc: 0.9987 - val_precision: 0.9947 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 38/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9908 - auc: 0.9997 - loss: 0.1238 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9887
# Epoch 38: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9904 - auc: 0.9996 - loss: 0.1264 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9880 - val_accuracy: 0.9656 - val_auc: 0.9956 - val_loss: 0.1862 - val_pr_auc: 0.9987 - val_precision: 0.9973 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 39/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9901 - auc: 0.9996 - loss: 0.1247 - pr_auc: 0.9999 - precision: 0.9990 - recall: 0.9876
# Epoch 39: val_pr_auc did not improve from 0.99882
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.9904 - auc: 0.9996 - loss: 0.1260 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9883 - val_accuracy: 0.9675 - val_auc: 0.9958 - val_loss: 0.1969 - val_pr_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 40/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9914 - auc: 0.9997 - loss: 0.1228 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9890
# Epoch 40: val_pr_auc did not improve from 0.99882
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.9913 - auc: 0.9996 - loss: 0.1254 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9888 - val_accuracy: 0.9675 - val_auc: 0.9957 - val_loss: 0.1936 - val_pr_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.9567 - learning_rate: 6.2500e-06
# Epoch 41/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9899 - auc: 0.9995 - loss: 0.1257 - pr_auc: 0.9998 - precision: 0.9995 - recall: 0.9869
# Epoch 41: val_pr_auc improved from 0.99882 to 0.99889, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9909 - auc: 0.9995 - loss: 0.1262 - pr_auc: 0.9998 - precision: 0.9994 - recall: 0.9883 - val_accuracy: 0.9637 - val_auc: 0.9965 - val_loss: 0.1781 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9618 - learning_rate: 3.1250e-06
# Epoch 42/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9933 - auc: 0.9997 - loss: 0.1224 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9915
# Epoch 42: val_pr_auc did not improve from 0.99889
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.1246 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9903 - val_accuracy: 0.9637 - val_auc: 0.9965 - val_loss: 0.1727 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9618 - learning_rate: 3.1250e-06
# Epoch 43/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9918 - auc: 0.9997 - loss: 0.1227 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9894
# Epoch 43: val_pr_auc did not improve from 0.99889
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.1243 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9900 - val_accuracy: 0.9637 - val_auc: 0.9965 - val_loss: 0.1747 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9618 - learning_rate: 3.1250e-06
# Epoch 44/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1226 - pr_auc: 0.9999 - precision: 0.9992 - recall: 0.9901
# Epoch 44: val_pr_auc did not improve from 0.99889
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.9921 - auc: 0.9996 - loss: 0.1250 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9903 - val_accuracy: 0.9637 - val_auc: 0.9965 - val_loss: 0.1741 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9618 - learning_rate: 3.1250e-06
# Epoch 45/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9906 - auc: 0.9996 - loss: 0.1232 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9880
# Epoch 45: val_pr_auc improved from 0.99889 to 0.99890, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9913 - auc: 0.9996 - loss: 0.1245 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9891 - val_accuracy: 0.9618 - val_auc: 0.9965 - val_loss: 0.1774 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9593 - learning_rate: 3.1250e-06
# Epoch 46/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9908 - auc: 0.9996 - loss: 0.1242 - pr_auc: 0.9999 - precision: 0.9990 - recall: 0.9885
# Epoch 46: val_pr_auc did not improve from 0.99890
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9915 - auc: 0.9996 - loss: 0.1254 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9894 - val_accuracy: 0.9637 - val_auc: 0.9965 - val_loss: 0.1734 - val_pr_auc: 0.9989 - val_precision: 0.9895 - val_recall: 0.9618 - learning_rate: 3.1250e-06
# Epoch 47/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9904 - auc: 0.9997 - loss: 0.1233 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9875
# Epoch 47: val_pr_auc did not improve from 0.99890
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9919 - auc: 0.9997 - loss: 0.1240 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9894 - val_accuracy: 0.9675 - val_auc: 0.9965 - val_loss: 0.1698 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9669 - learning_rate: 1.5625e-06
# Epoch 48/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9909 - auc: 0.9998 - loss: 0.1206 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9882
# Epoch 48: val_pr_auc did not improve from 0.99890
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9919 - auc: 0.9998 - loss: 0.1222 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9894 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1675 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.5625e-06
# Epoch 49/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9909 - auc: 0.9997 - loss: 0.1219 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9884
# Epoch 49: val_pr_auc did not improve from 0.99890
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.9911 - auc: 0.9997 - loss: 0.1230 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9888 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1688 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.5625e-06
# Epoch 50/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1220 - pr_auc: 0.9999 - precision: 0.9998 - recall: 0.9896
# Epoch 50: val_pr_auc improved from 0.99890 to 0.99891, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9917 - auc: 0.9997 - loss: 0.1237 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9894 - val_accuracy: 0.9656 - val_auc: 0.9965 - val_loss: 0.1696 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9644 - learning_rate: 1.5625e-06
# Epoch 51/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9911 - auc: 0.9997 - loss: 0.1213 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9886
# Epoch 51: val_pr_auc did not improve from 0.99891
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - accuracy: 0.9909 - auc: 0.9997 - loss: 0.1227 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9885 - val_accuracy: 0.9694 - val_auc: 0.9964 - val_loss: 0.1688 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.5625e-06
# Epoch 52/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9918 - auc: 0.9997 - loss: 0.1214 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9895
# Epoch 52: val_pr_auc did not improve from 0.99891
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-06.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.9919 - auc: 0.9997 - loss: 0.1228 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9894 - val_accuracy: 0.9656 - val_auc: 0.9965 - val_loss: 0.1711 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9644 - learning_rate: 1.5625e-06
# Epoch 53/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9911 - auc: 0.9996 - loss: 0.1219 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9885
# Epoch 53: val_pr_auc did not improve from 0.99891
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9917 - auc: 0.9997 - loss: 0.1229 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9891 - val_accuracy: 0.9694 - val_auc: 0.9964 - val_loss: 0.1678 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 54/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9899 - auc: 0.9998 - loss: 0.1221 - pr_auc: 0.9999 - precision: 0.9989 - recall: 0.9875
# Epoch 54: val_pr_auc did not improve from 0.99891
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9900 - auc: 0.9997 - loss: 0.1239 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9874 - val_accuracy: 0.9694 - val_auc: 0.9964 - val_loss: 0.1682 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 55/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9917 - auc: 0.9998 - loss: 0.1206 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9888
# Epoch 55: val_pr_auc did not improve from 0.99891
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9926 - auc: 0.9998 - loss: 0.1221 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9900 - val_accuracy: 0.9675 - val_auc: 0.9965 - val_loss: 0.1700 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9669 - learning_rate: 1.0000e-06
# Epoch 56/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9912 - auc: 0.9994 - loss: 0.1221 - pr_auc: 0.9998 - precision: 0.9993 - recall: 0.9889
# Epoch 56: val_pr_auc improved from 0.99891 to 0.99892, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 116ms/step - accuracy: 0.9915 - auc: 0.9996 - loss: 0.1225 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9894 - val_accuracy: 0.9675 - val_auc: 0.9966 - val_loss: 0.1700 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9669 - learning_rate: 1.0000e-06
# Epoch 57/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9908 - auc: 0.9997 - loss: 0.1219 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9889
# Epoch 57: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9909 - auc: 0.9997 - loss: 0.1229 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9888 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1678 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 58/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9908 - auc: 0.9996 - loss: 0.1222 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9882
# Epoch 58: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9919 - auc: 0.9997 - loss: 0.1229 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9897 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1684 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 59/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9911 - auc: 0.9997 - loss: 0.1214 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9886
# Epoch 59: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9911 - auc: 0.9997 - loss: 0.1230 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9885 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1694 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 60/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9917 - auc: 0.9996 - loss: 0.1212 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9893
# Epoch 60: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1226 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9897 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1684 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 61/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9908 - auc: 0.9997 - loss: 0.1213 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9883
# Epoch 61: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.9907 - auc: 0.9996 - loss: 0.1236 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9885 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1682 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 62/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9918 - auc: 0.9997 - loss: 0.1219 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9902
# Epoch 62: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9915 - auc: 0.9997 - loss: 0.1233 - pr_auc: 0.9999 - precision: 0.9986 - recall: 0.9900 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1690 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 63/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9908 - auc: 0.9998 - loss: 0.1216 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9881
# Epoch 63: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - accuracy: 0.9911 - auc: 0.9998 - loss: 0.1216 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9885 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1693 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 64/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9923 - auc: 0.9998 - loss: 0.1202 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9904
# Epoch 64: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - accuracy: 0.9926 - auc: 0.9997 - loss: 0.1222 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9905 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1683 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 65/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9923 - auc: 0.9997 - loss: 0.1207 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9901
# Epoch 65: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.1227 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9900 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1686 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 66/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9916 - auc: 0.9998 - loss: 0.1198 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9886
# Epoch 66: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 104ms/step - accuracy: 0.9919 - auc: 0.9998 - loss: 0.1211 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9891 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1676 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 67/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9917 - auc: 0.9998 - loss: 0.1198 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9889
# Epoch 67: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9919 - auc: 0.9998 - loss: 0.1213 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9894 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1684 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 68/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.1198 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9903
# Epoch 68: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9928 - auc: 0.9998 - loss: 0.1203 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9905 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1664 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 69/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9920 - auc: 0.9999 - loss: 0.1191 - pr_auc: 1.0000 - precision: 0.9990 - recall: 0.9902
# Epoch 69: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.1211 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9905 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1683 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 70/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9920 - auc: 0.9995 - loss: 0.1210 - pr_auc: 0.9998 - precision: 0.9995 - recall: 0.9897
# Epoch 70: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.1208 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9900 - val_accuracy: 0.9713 - val_auc: 0.9965 - val_loss: 0.1661 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9720 - learning_rate: 1.0000e-06
# Epoch 71/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9920 - auc: 0.9998 - loss: 0.1196 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9898
# Epoch 71: val_pr_auc improved from 0.99892 to 0.99892, saving model to best_model_checkpoint.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - accuracy: 0.9926 - auc: 0.9998 - loss: 0.1214 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9908 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1686 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 72/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9908 - auc: 0.9998 - loss: 0.1203 - pr_auc: 0.9999 - precision: 0.9993 - recall: 0.9883
# Epoch 72: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.9915 - auc: 0.9998 - loss: 0.1214 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9891 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1686 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 73/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9910 - auc: 0.9998 - loss: 0.1203 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9884
# Epoch 73: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 19s 132ms/step - accuracy: 0.9921 - auc: 0.9998 - loss: 0.1215 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9900 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1669 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 74/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9926 - auc: 0.9998 - loss: 0.1186 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9906
# Epoch 74: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.9930 - auc: 0.9998 - loss: 0.1205 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9911 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1678 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 75/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9913 - auc: 0.9997 - loss: 0.1212 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9892
# Epoch 75: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.1220 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9903 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1686 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 76/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9914 - auc: 0.9998 - loss: 0.1209 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9889
# Epoch 76: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.1213 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9900 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1676 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 77/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.1182 - pr_auc: 0.9999 - precision: 0.9999 - recall: 0.9899
# Epoch 77: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1199 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9900 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1685 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 78/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9908 - auc: 0.9997 - loss: 0.1198 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9880
# Epoch 78: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.9915 - auc: 0.9997 - loss: 0.1208 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9888 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1688 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 79/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9906 - auc: 0.9997 - loss: 0.1207 - pr_auc: 0.9999 - precision: 0.9990 - recall: 0.9884
# Epoch 79: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9907 - auc: 0.9997 - loss: 0.1226 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9885 - val_accuracy: 0.9675 - val_auc: 0.9965 - val_loss: 0.1698 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9669 - learning_rate: 1.0000e-06
# Epoch 80/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9912 - auc: 0.9997 - loss: 0.1194 - pr_auc: 0.9999 - precision: 0.9996 - recall: 0.9885
# Epoch 80: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1216 - pr_auc: 0.9999 - precision: 0.9988 - recall: 0.9905 - val_accuracy: 0.9675 - val_auc: 0.9965 - val_loss: 0.1703 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9669 - learning_rate: 1.0000e-06
# Epoch 81/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9919 - auc: 0.9997 - loss: 0.1199 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9891
# Epoch 81: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.9917 - auc: 0.9997 - loss: 0.1210 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9888 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1678 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 82/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9940 - auc: 0.9998 - loss: 0.1193 - pr_auc: 0.9999 - precision: 0.9991 - recall: 0.9929
# Epoch 82: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9930 - auc: 0.9997 - loss: 0.1212 - pr_auc: 0.9999 - precision: 0.9994 - recall: 0.9911 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1666 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 83/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9911 - auc: 0.9998 - loss: 0.1201 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9885
# Epoch 83: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.1213 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9897 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1684 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 84/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9922 - auc: 0.9998 - loss: 0.1189 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9900
# Epoch 84: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 18s 124ms/step - accuracy: 0.9928 - auc: 0.9998 - loss: 0.1204 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9905 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1680 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 85/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9910 - auc: 0.9998 - loss: 0.1198 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9883
# Epoch 85: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.9915 - auc: 0.9998 - loss: 0.1209 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9888 - val_accuracy: 0.9694 - val_auc: 0.9965 - val_loss: 0.1661 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 86/100
# 147/148 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9915 - auc: 0.9998 - loss: 0.1198 - pr_auc: 0.9999 - precision: 0.9995 - recall: 0.9890
# Epoch 86: val_pr_auc did not improve from 0.99892
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 17s 118ms/step - accuracy: 0.9932 - auc: 0.9997 - loss: 0.1208 - pr_auc: 0.9999 - precision: 0.9997 - recall: 0.9911 - val_accuracy: 0.9694 - val_auc: 0.9966 - val_loss: 0.1678 - val_pr_auc: 0.9989 - val_precision: 0.9896 - val_recall: 0.9695 - learning_rate: 1.0000e-06
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 71.

# %% [markdown]
# # 4. Evaluation
#
# ---

# %% [markdown]
# In this section, the final model is evaluated on a held-out test set using clinically relevant classification metrics (accuracy, precision, recall, F1-score and AUC), together with confusion matrices, Precision–Recall analysis and threshold-based error summaries. We also inspect the loss and accuracy curves over epochs to verify that training converged without severe overfitting before selecting the best checkpoint for testing.

# %%
# Plot the validation accuracy and loss curves from training
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 3** - Training and validation accuracy and loss curves over epochs for the CNN model.

# %% [markdown]
# During training, the model’s learning curves show that it is able to fit the task without obvious instability. Training accuracy increases steadily while training loss decreases, and the validation curves, although noisier, improve in the same direction before stabilizing. The early-stopping and checkpoint callbacks, driven by the validation PR-AUC metric, prevent the model from overfitting and select the epoch that offers the best balance between fit and generalization.
#
# When the selected checkpoint is evaluated on the held-out test set using the _default_ decision threshold (0.5), the following metrics are obtained (F1-score computed from the reported precision and recall at threshold 0.5):
#
# **Table 3** - Test set performance of the selected model (threshold = 0.5).
#
# | Metric    | Value  |
# | --------- | ------ |
# | Accuracy  | 0.7949 |
# | Loss      | 0.9249 |
# | AUC       | 0.8979 |
# | PR-AUC    | 0.8959 |
# | Precision | 0.7529 |
# | Recall    | 1.0000 |
# | F1-score* | 0.8590 |
#
# These values summarize the baseline test performance before considering alternative operating thresholds, which are analyzed in detail in the following subsections.

# %%
# Load the best model saved by the callback
print(f"Load the best model from: {CHECKPOINT_PATH}")
best_model = models.load_model(CHECKPOINT_PATH)

# Report metrics
results = best_model.evaluate(test_dataset_gray, verbose=2, return_dict=True)
for k,v in results.items():
	print(f"{k}: {v:.4f}")
# Out:
# Load the best model from: best_model_checkpoint.keras
# 20/20 - 3s - 149ms/step - accuracy: 0.7949 - auc: 0.8979 - loss: 0.9249 - pr_auc: 0.8959 - precision: 0.7529 - recall: 1.0000
# accuracy: 0.7949
# auc: 0.8979
# loss: 0.9249
# pr_auc: 0.8959
# precision: 0.7529
# recall: 1.0000

# %% [markdown]
# On the held-out test set, the model achieves solid baseline performance at the default decision threshold of 0.5, with accuracy of 0.7949, AUC of 0.8979 and PR-AUC of 0.8959. The detailed classification report at this threshold shows that performance is strongly asymmetric between the two classes, reflecting both the class imbalance and the recall-focused behavior of the model:
#
# **Table 4** – Detailed test performance by class (_default_ threshold = 0.5)
#
# | Class     | Precision | Recall | F1-score | Support |
# | --------- | --------- | ------ | -------- | ------- |
# | Normal    | 1.0000    | 0.4530 | 0.6235   | 234     |
# | Pneumonia | 0.7529    | 1.0000 | 0.8590   | 390     |
#
# At this operating point, all 390 pneumonia cases in the test set are correctly identified (recall 1.0000), but this comes at the cost of misclassifying 128 out of 234 Normal cases as Pneumonia, which explains the relatively low recall for the Normal class. This behavior is consistent with the clinical objective of prioritizing sensitivity to pneumonia over perfectly preserving specificity in Normal cases.
#
# Because the retrospective screening program values missing as few pneumonia patients as possible more than avoiding outreach to healthy patients, the primary focus of evaluation is on recall and the pattern of false negatives versus false positives. To systematically explore this trade-off, we varied the classification threshold from 0.1 to 0.9 and computed accuracy, precision, recall, F1-score and confusion matrices at each point. The resulting threshold analysis, summarized in the next section, shows a wide range of thresholds where recall remains at 100% and motivates the recommended operating threshold of 0.6 used in the Conclusions.

# %%
# Get predictions and true labels
print("Generating predictions...")

# Instead of iterating through the dataset, predict directly on the entire test set
# This approach avoids the iterator issues that cause the warning
y_pred_probs = best_model.predict(test_dataset_gray, verbose=1).flatten()

# Extract true labels from the dataset
y_true = []
for images, labels in test_dataset_gray:
    y_true.extend(labels.numpy())
y_true = np.array(y_true)

print(f"\nTotal test samples: {len(y_true)}")
print(f"Pneumonia cases: {sum(y_true)} ({sum(y_true)/len(y_true)*100:.1f}%)")
print(f"Normal cases: {len(y_true) - sum(y_true)} ({(len(y_true)-sum(y_true))/len(y_true)*100:.1f}%)")

# Trade-off descriptions helper
def describe_tradeoff(threshold, recall, precision):
    if threshold <= 0.2:
        return "Very low threshold; maximize coverage"
    elif threshold <= 0.3:
        return "Maximum coverage; few missed cases"
    elif threshold <= 0.5:
        return "Strong balance"
    elif threshold <= 0.6:
        return "More conservative"
    elif threshold <= 0.8:
        return "Very selective"
    else:
        return "Extremely selective; only strongest positives"

# Test thresholds from 0.1 to 0.9 (step 0.1)
thresholds_to_test = [round(t, 1) for t in np.arange(0.1, 1.0, 0.1)]

print("\n" + "="*30)
print("THRESHOLD ANALYSIS")
print("="*30)

results = []
for threshold in thresholds_to_test:
    y_pred = (y_pred_probs >= threshold).astype(int)
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    recall = tp / (tp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    results.append({
        'threshold': threshold,
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'recall': recall,
        'precision': precision,
        'accuracy': accuracy,
        'f1': f1
    })
    
    print(f"\nThreshold: {threshold}")
    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")
    print(f"  ---")
    print(f"  True Positives (Pneumonia correctly identified):  {tp}")
    print(f"  False Negatives (Pneumonia MISSED):               {fn}")
    print(f"  False Positives (Normal incorrectly flagged):     {fp}")
    print(f"  True Negatives (Normal correctly identified):     {tn}")

# Classification Report
y_pred_default = (y_pred_probs >= 0.5).astype(int)
cm = confusion_matrix(y_true, y_pred_default)

print("\nDetailed Classification Report (Threshold = 0.5):")
print(classification_report(
    y_true,
    y_pred_default,
    target_names=['Normal', 'Pneumonia'],
    digits=4
))
# Out:
# Generating predictions...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
#
# Total test samples: 624
# Pneumonia cases: 390 (62.5%)
# Normal cases: 234 (37.5%)
#
# ==============================
# THRESHOLD ANALYSIS
# ==============================
#
# Threshold: 0.1
#   Accuracy:  0.7099
#   Precision: 0.6830
#   Recall:    1.0000
#   F1-Score:  0.8117
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     181
#   True Negatives (Normal correctly identified):     53
#
# Threshold: 0.2
#   Accuracy:  0.7356
#   Precision: 0.7027
#   Recall:    1.0000
#   F1-Score:  0.8254
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     165
#   True Negatives (Normal correctly identified):     69
#
# Threshold: 0.3
#   Accuracy:  0.7596
#   Precision: 0.7222
#   Recall:    1.0000
#   F1-Score:  0.8387
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     150
#   True Negatives (Normal correctly identified):     84
#
# Threshold: 0.4
#   Accuracy:  0.7708
#   Precision: 0.7317
#   Recall:    1.0000
#   F1-Score:  0.8451
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     143
#   True Negatives (Normal correctly identified):     91
#
# Threshold: 0.5
#   Accuracy:  0.7949
#   Precision: 0.7529
#   Recall:    1.0000
#   F1-Score:  0.8590
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     128
#   True Negatives (Normal correctly identified):     106
#
# Threshold: 0.6
#   Accuracy:  0.8077
#   Precision: 0.7647
#   Recall:    1.0000
#   F1-Score:  0.8667
#   ---
#   True Positives (Pneumonia correctly identified):  390
#   False Negatives (Pneumonia MISSED):               0
#   False Positives (Normal incorrectly flagged):     120
#   True Negatives (Normal correctly identified):     114
#
# Threshold: 0.7
#   Accuracy:  0.8317
#   Precision: 0.7890
#   Recall:    0.9974
#   F1-Score:  0.8811
#   ---
#   True Positives (Pneumonia correctly identified):  389
#   False Negatives (Pneumonia MISSED):               1
#   False Positives (Normal incorrectly flagged):     104
#   True Negatives (Normal correctly identified):     130
#
# Threshold: 0.8
#   Accuracy:  0.8381
#   Precision: 0.7992
#   Recall:    0.9897
#   F1-Score:  0.8843
#   ---
#   True Positives (Pneumonia correctly identified):  386
#   False Negatives (Pneumonia MISSED):               4
#   False Positives (Normal incorrectly flagged):     97
#   True Negatives (Normal correctly identified):     137
#
# Threshold: 0.9
#   Accuracy:  0.8558
#   Precision: 0.8261
#   Recall:    0.9744
#   F1-Score:  0.8941
#   ---
#   True Positives (Pneumonia correctly identified):  380
#   False Negatives (Pneumonia MISSED):               10
#   False Positives (Normal incorrectly flagged):     80
#   True Negatives (Normal correctly identified):     154
#
# Detailed Classification Report (Threshold = 0.5):
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.4530    0.6235       234
#    Pneumonia     0.7529    1.0000    0.8590       390
#
#     accuracy                         0.7949       624
#    macro avg     0.8764    0.7265    0.7413       624
# weighted avg     0.8456    0.7949    0.7707       624

# %% [markdown]
# # 5. Conclusions
#
# ---

# %% [markdown]
# ## 5.1 Key Findings
#
# The hospital's objective is to identify patients from historical X-ray records who had pneumonia, in order to contact them for preventive care and education to reduce recurrence risk. This is a retrospective screening program for secondary prevention.
#
# In this context, the consequences of classification errors are highly asymmetric:
#
# * A False Negative (FN) occurs when a patient who had pneumonia is not identified. This is a high-consequence error: the patient is missed and receives no preventive outreach, leaving them at elevated risk for recurrence, complications, or hospitalization.
# * A False Positive (FP) occurs when a healthy patient is incorrectly flagged. This is a low-consequence error, resulting in minor administrative overhead and a patient receiving generally useful health information.
#
# This asymmetry dictates our optimization strategy: we must prioritize high recall (catching true pneumonia cases) over high precision. Missing vulnerable patients is far more problematic than contacting some healthy individuals. During training, model checkpoints were selected using the validation PR-AUC metric, which balances precision and recall under class imbalance, and the final operating characteristics were analyzed in detail across multiple thresholds with particular attention to recall.
#
# The model outputs probability scores (0 to 1). The classification threshold determines the cutoff for classification:
#
# * Higher threshold (e.g., 0.7–0.9): more conservative, fewer patients flagged, but potentially more missed pneumonia cases.
# * Lower threshold (e.g., 0.1–0.3): more inclusive, more patients flagged, typically fewer or no missed pneumonia cases but more unnecessary contacts.
#
# ### 5.1.1 Results Across Different Thresholds
#
# Based on the test set evaluation (624 total samples: 390 Pneumonia, 234 Normal), the model demonstrates the following trade-offs:
#
# **Table 5** - Recall-precision trade-offs and error counts across decision thresholds on the test set
#
# | Threshold | Recall (Sensitivity) | Precision | Missed Cases (FN) | Unnecessary Contacts (FP) | Trade-off                                                                        |
# | :-------- | :------------------- | :-------- | :---------------- | :------------------------ | :------------------------------------------------------------------------------- |
# | 0.1       | 100.0% (390/390)     | 68.3%     | 0                 | 181                       | Very low threshold; maximum coverage, many unnecessary contacts                  |
# | 0.2       | 100.0% (390/390)     | 70.3%     | 0                 | 165                       | Very low threshold; maximum coverage, many unnecessary contacts                  |
# | 0.3       | 100.0% (390/390)     | 72.2%     | 0                 | 150                       | Inclusive; all pneumonia cases found, high number of unnecessary contacts        |
# | 0.4       | 100.0% (390/390)     | 73.2%     | 0                 | 143                       | Inclusive; all pneumonia cases found, slightly fewer unnecessary contacts        |
# | 0.5       | 100.0% (390/390)     | 75.3%     | 0                 | 128                       | Balanced; all pneumonia cases found, fewer unnecessary contacts                  |
# | 0.6       | 100.0% (390/390)     | 76.5%     | 0                 | 120                       | More conservative; all pneumonia cases found, fewer unnecessary contacts         |
# | 0.7       | 99.7% (389/390)      | 78.9%     | 1                 | 104                       | Conservative; one missed pneumonia case, fewer unnecessary contacts              |
# | 0.8       | 99.0% (386/390)      | 79.9%     | 4                 | 97                        | Very selective; a few missed cases, further reduction in unnecessary contacts    |
# | 0.9       | 97.4% (380/390)      | 82.6%     | 10                | 80                        | Extremely selective; more missed cases, substantially fewer unnecessary contacts |
#
# ### 5.1.2 Interpretation of Threshold Trade-offs
#
# Based on this data, our insights from the evaluation can be summarized as follows:
#
# 1. There is a wide plateau where recall remains at 100%.
#
#    * For thresholds between 0.1 and 0.6, the model achieves 100% recall (390 out of 390 pneumonia cases correctly identified) regardless of the exact threshold.
#    * Within this region, increasing the threshold mainly reduces unnecessary contacts. For example, raising the threshold from 0.3 to 0.6:
#
#      * Missed cases (FN): 0 → 0 (no change; all pneumonia cases are still found).
#      * Unnecessary contacts (FP): 150 → 120 (30 fewer healthy patients unnecessarily contacted).
#
# 2. Above roughly 0.7, we begin to trade recall for fewer unnecessary contacts.
#
#    * Moving from 0.6 to 0.9:
#
#      * Missed cases (FN): 0 → 10 (10 pneumonia patients no longer identified).
#      * Unnecessary contacts (FP): 120 → 80 (40 fewer healthy patients contacted).
#    * This illustrates the classic trade-off: higher thresholds reduce outreach workload but introduce a small number of missed pneumonia cases.
#
# 3. The recommended performance (threshold = 0.6) is strong and recall-focused.
#
#    * Recall: 100.0% – the model correctly identifies 390 out of 390 pneumonia cases, missing none.
#    * Precision: 76.5% – roughly three out of four flagged patients truly had pneumonia in the historical data.
#    * Unnecessary contacts: 120 healthy patients (out of 234 Normal cases) would be contacted, while 114 healthy patients would not be contacted.
#
# This recommended operating point offers full coverage of pneumonia cases on the test set, with a substantial reduction in unnecessary contacts compared to contacting everyone, while still leaving room to adjust the threshold if the hospital wishes to further reduce outreach volume at the cost of a small number of missed cases.
#
# ### 5.1.3 Confusion Matrices Across Thresholds
#
# Figure 4 shows a grid of confusion matrices for thresholds from 0.1 to 0.9 on the test set. This visualization makes it possible to see how the balance between false positives and false negatives changes as the threshold is adjusted.
#
# The panel labeled “Threshold = 0.6 (recommended)” corresponds to the operating point discussed above. At this threshold, all 390 pneumonia cases are correctly identified (0 missed), and among 234 normal cases, 114 are correctly not contacted and 120 are unnecessarily contacted. These counts match the values reported for threshold 0.6 in Table 3.

# %%
thresholds = [0.1 * i for i in range(1, 10)]  # 0.1, 0.2, ..., 0.9

fig, axes = plt.subplots(3, 3, figsize=(12, 10))

for ax, thr in zip(axes.ravel(), thresholds):
    y_pred_thr = (y_pred_probs >= thr).astype(int)
    cm_thr = confusion_matrix(y_true, y_pred_thr)

    sns.heatmap(
        cm_thr,
        annot=True,
        fmt='d',
        cmap='Blues',
        cbar=False,
        xticklabels=['Normal', 'Pneumonia'],
        yticklabels=['Normal', 'Pneumonia'],
        ax=ax
    )

    # Mark recommended threshold (0.6)
    if abs(thr - 0.6) < 1e-6:
        ax.set_title(f'Threshold = {thr:.1f} (recommended)', fontweight='bold', color='green')
    else:
        ax.set_title(f'Threshold = {thr:.1f}')

    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 4** - Confusion matrices on the test set for thresholds (0.6 shown as recommended threshold).

# %% [markdown]
# ### 5.1.4 Effect of Threshold on Global Metrics
#
# Figure 5 summarizes how recall, precision and F1-score evolve as the decision threshold varies from 0.1 to 0.9. Recall remains at 100% across a broad plateau between thresholds 0.1 and 0.6, confirming that all pneumonia cases are captured in this range regardless of the exact cutoff.
#
# Within this plateau, increasing the threshold gradually improves precision and F1-score by reducing the number of unnecessary contacts, without sacrificing coverage of pneumonia cases. Beyond approximately 0.7, recall starts to decrease as some pneumonia cases are missed, while precision continues to improve. The vertical dashed line marks the recommended threshold of 0.6, which lies at the upper end of the full-recall region and provides the best balance between maintaining 100% recall and minimizing false positives.

# %%
thresholds = [r['threshold'] for r in results]
recalls = [r['recall'] for r in results]
precisions = [r['precision'] for r in results]
f1_scores = [r['f1'] for r in results]

plt.figure(figsize=(8, 5))

plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, f1_scores, label='F1-score')

# Highlight recommended threshold
recommended_threshold = 0.6
plt.axvline(recommended_threshold, linestyle='--', label='Recommended threshold (0.6)')

plt.xlabel('Threshold')
plt.ylabel('Metric value')
plt.ylim(0, 1.05)
plt.title("Effect of Threshold on Recall, Precision and F1-score\n")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 5** - Recall, precision and F1-score on the test set as a function of threshold.

# %% [markdown]
# ## 5.2 Limitations
#
# The Precision–Recall curve and the threshold–metrics plot highlight the trade-off between recall and precision when choosing the decision threshold. In general, moving along the curve means exchanging fewer missed pneumonia cases for more unnecessary contacts, or vice versa. In our specific model, there is a wide plateau (thresholds 0.1 to 0.6) where recall remains at 100%, and only beyond approximately 0.7 does recall begin to decrease.
#
# * Lower thresholds (right side of the PR curve, higher recall): fewer missed patients but more unnecessary contacts (lower precision).
# * Higher thresholds (left side of the PR curve, lower recall): fewer unnecessary contacts (higher precision) but more missed patients, once we move beyond the full-recall region.

# %%
# Generate the precision-recall curve data
precision_curve, recall_curve, _ = precision_recall_curve(y_true, y_pred_probs)

# Convert to the right format for plotting (need to reverse the order for proper plotting)
recall_curve = np.flip(recall_curve)
precision_curve = np.flip(precision_curve)

# Precision-Recall curve and Recall/Precision vs Threshold
plt.figure(figsize=(13, 5))

# Left plot: Precision-Recall curve
plt.subplot(1, 2, 1)
plt.plot(recall_curve, precision_curve, linewidth=2, color='#2E86AB')
plt.xlabel('Recall', fontsize=11)
plt.ylabel('Precision', fontsize=11)
plt.title('Precision-Recall Curve\n', fontsize=12)
plt.grid(True, alpha=0.3)

# Mark the tested thresholds (0.1 to 0.9) on the PR curve
for r in results:
    plt.plot(r['recall'], r['precision'], marker='o', markersize=6, color="#E45555")
    plt.annotate(
        f"{r['threshold']:.1f}",
        xy=(r['recall'], r['precision']),
        xytext=(-22, -3),
        textcoords='offset points'
    )

# Right plot: Recall & Precision vs Threshold
plt.subplot(1, 2, 2)
plt.plot(thresholds, recalls, color='#2E86AB', marker='o', linewidth=2, label='Recall', markersize=6)
plt.plot(thresholds, precisions, color='#F18F01', marker='o', linewidth=2, label='Precision', markersize=6)
plt.xlabel('Threshold', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.title('Recall & Precision vs Threshold\n', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 6** - Precision–recall curve and recall/precision vs threshold on the test set.

# %% [markdown]
# ## 5.3 Recommendations
#
# The trained model enables post-training business decisions based on resource availability and risk tolerance. Given the high cost of false negatives, the primary constraint is to operate in a region where recall remains as close to 100% as possible. On the test set, thresholds between 0.1 and 0.6 all achieve 100% recall (390 out of 390 pneumonia cases correctly identified). Among these, threshold 0.6 yields the lowest number of false positives (120), with precision of 76.5% and no missed pneumonia cases, and is therefore recommended as the standard operating point.
#
# Based on these conclusions, a simple decision framework can be proposed, summarized in the following operational scenarios:
#
# **Scenario 1** - Conservative outreach (limited resources)
#
# * Threshold: **0.8**
# * Strategy: Contact only higher-confidence cases, accepting a small number of missed pneumonia patients in exchange for fewer unnecessary contacts.
# * Outcome: 99.0% recall (386 out of 390 pneumonia cases correctly identified, 4 missed) and 79.9% precision (97 unnecessary contacts among Normal patients).
# * Use case: Situations with limited staffing or budget where reducing outreach volume is important and a small number of missed cases is acceptable.
#
# **Scenario 2** - Balanced approach (**recommended**)
#
# * Threshold: **0.6**
# * Strategy: Maintain full coverage of pneumonia cases while reducing unnecessary contacts as much as possible within the 100%-recall region.
# * Outcome: 100.0% recall (390 out of 390 pneumonia cases correctly identified, 0 missed) and 76.5% precision, with 120 unnecessary contacts and 114 Normal patients correctly not contacted.
# * Use case: Standard operation for the retrospective screening program, aligning with the clinical goal of not missing pneumonia patients while keeping outreach workload manageable.
#
# **Scenario 3** - Aggressive outreach (maximum redundancy against missed cases)
#
# * Threshold: **0.3**
# * Strategy: Use a lower threshold to flag more patients, accepting additional unnecessary contacts while still maintaining 100% recall on the test set.
# * Outcome: 100.0% recall (390 out of 390 pneumonia cases correctly identified, 0 missed) and 72.2% precision, with 150 unnecessary contacts among Normal patients. Compared with the recommended threshold of 0.6, this corresponds to 30 additional healthy patients being contacted.
# * Use case: Periods of elevated concern (e.g., high-risk season or suspected data drift) where the hospital prefers to err further on the side of contacting more patients rather than risk overlooking potentially vulnerable cases.

# %% [markdown]
# ## 5.4 Summary
#
# In this project, generalization is understood as the model’s ability to maintain very high recall (few false negatives) on unseen data, even if this comes at the cost of additional false positives, reflecting the clinical priority of not missing pneumonia cases.
#
# On the held-out test set from the same retrospective screening population, the model achieves 100% recall across a wide range of thresholds (0.1 to 0.6). Within this full-recall region, threshold tuning allows the hospital to choose the level of outreach workload it is willing to accept. The recommended operating point at threshold 0.6 achieves 100% recall with the lowest number of false positives in this range, providing a strong balance between clinical safety and operational efficiency.
#
# Overall, the model trained with a focus on recall provides both high performance and operational flexibility. The hospital can make informed, data-driven decisions by adjusting the classification threshold to align with clinical priorities, resource constraints and evolving policies for preventive outreach. Future work could explore data augmentation and transfer learning to potentially improve performance further while preserving a recall-focused behavior.
